# %%
import pandas as pd
import numpy as np

# %%
results_df = pd.read_csv("../../VAD_MODEL_TREE/VAD_AE_results_CEDAR_10022021.csv")

# %%
ucsd1_results_df = results_df.where(results_df["Dataset"] == "UCSD1").dropna()

# %%
ucsd1_results_df = ucsd1_results_df.drop(columns="Model_Path").dropna()

# %%
ucsd1_results_df
# Out:
#                  Model                  Variant Dataset Image_Type  \
# 48      C2D_AE_128_3X3                   Normal   UCSD1     NORMAL
# 49      C2D_AE_128_3X3                   Normal   UCSD1     NORMAL
# 50      C2D_AE_128_3X3                   Normal   UCSD1     NORMAL
# 51      C2D_AE_128_3X3                   Normal   UCSD1     NORMAL
# 52      C2D_AE_128_3X3                   Normal   UCSD1     NORMAL
# 53      C2D_AE_128_3X3                   Normal   UCSD1     NORMAL
# 54  C2D_AE_128_3X3_AAC  AttentionAugmentedConvs   UCSD1     NORMAL
#
#     Resolution Loss Optimizer  DeNoising  Attention  \
# 48       128.0  MSE      ADAM        0.0        0.0
# 49       128.0  MSE      ADAM        0.0        1.0
# 50       128.0  MSE      ADAM        0.0        1.0
# 51       128.0  MSE      ADAM        0.0        1.0
# 52       128.0  MSE      ADAM        0.0        1.0
# 53       128.0  MSE      ADAM        0.0        1.0
# 54       128.0  MSE      ADAM        0.0        0.0
#
# ...

# %%
ucsd2_results_df = results_df.where(results_df["Dataset"] == "UCSD2").dropna()

# %%
ucsd2_results_df = ucsd2_results_df.drop(columns="Model_Path").dropna()

# %%
ucsd2_results_df
# Out:
#                    Model                  Variant Dataset Image_Type  \
# 55        C2D_AE_128_3X3                   Normal   UCSD2     NORMAL
# 56        C2D_AE_128_3X3                   Normal   UCSD2     NORMAL
# 57        C2D_AE_128_3X3                   Normal   UCSD2     NORMAL
# 58        C2D_AE_128_3X3                   Normal   UCSD2     NORMAL
# 59        C2D_AE_128_3X3                   Normal   UCSD2     NORMAL
# 60        C2D_AE_128_3X3                   Normal   UCSD2     NORMAL
# 61        C2D_AE_128_3X3                   Normal   UCSD2     NORMAL
# 62        C2D_AE_128_3X3                   Normal   UCSD2     NORMAL
# 63        C2D_AE_128_3X3                   Normal   UCSD2     NORMAL
# 64        C2D_AE_128_3X3                   Normal   UCSD2     NORMAL
# 65        C2D_AE_128_3X3                   Normal   UCSD2     NORMAL
# 66        C2D_AE_128_3X3                   Normal   UCSD2     NORMAL
# 67        C2D_AE_128_3X3                   Normal   UCSD2     NORMAL
# ...

# %%
avenue_results_df = results_df.where(results_df["Dataset"] == "AVENUE").dropna()

# %%
avenue_results_df = avenue_results_df.drop(columns="Model_Path").dropna()

# %%
avenue_results_df
# Out:
#                    Model                  Variant Dataset Image_Type  \
# 0         C2D_AE_128_3X3                   Normal  AVENUE     NORMAL
# 1         C2D_AE_128_3X3                   Normal  AVENUE     NORMAL
# 2         C2D_AE_128_3X3                   Normal  AVENUE     NORMAL
# 3         C2D_AE_128_3X3                   Normal  AVENUE     NORMAL
# 4         C2D_AE_128_3X3                   Normal  AVENUE     NORMAL
# 5         C2D_AE_128_3X3                   Normal  AVENUE     NORMAL
# 6         C2D_AE_128_3X3                   Normal  AVENUE     NORMAL
# 7         C2D_AE_128_3X3                   Normal  AVENUE     NORMAL
# 8         C2D_AE_128_3X3                   Normal  AVENUE     NORMAL
# 9         C2D_AE_128_3X3                   Normal  AVENUE     NORMAL
# 10        C2D_AE_128_3X3                   Normal  AVENUE     NORMAL
# 11        C2D_AE_128_3X3                   Normal  AVENUE     NORMAL
# 12        C2D_AE_128_3X3                   Normal  AVENUE     NORMAL
# ...

# %%
subway_ent_results_df = results_df.where(results_df["Dataset"] == "SUBWAY_ENTRANCE").dropna()

# %%
subway_ent_results_df = subway_ent_results_df.drop(columns="Model_Path").dropna()

# %%
subway_ent_results_df
# Out:
#                                       Model                  Variant  \
# 18   BICGRU_AE_128_3X3_L-4_RL-2_DISDECONV-Y                   Normal
# 19  BICLSTM_AE_128_3X3_L-4_RL-2_DISDECONV-Y                   Normal
# 20   BICRNN_AE_128_3X3_L-4_RL-2_DISDECONV-Y                   Normal
# 21                           C2D_AE_128_3X3                   Normal
# 22                           C2D_AE_128_3X3                   Normal
# 23                           C2D_AE_128_3X3                   Normal
# 24                           C2D_AE_128_3X3                   Normal
# 25                           C2D_AE_128_3X3                   Normal
# 26                           C2D_AE_128_3X3                   Normal
# 27                           C2D_AE_128_3X3                   Normal
# 28                           C2D_AE_128_3X3                   Normal
# 29                           C2D_AE_128_3X3                   Normal
# 30                           C2D_AE_128_3X3                   Normal
# ...

# %%
subway_ext_results_df = results_df.where(results_df["Dataset"] == "SUBWAY_EXIT").dropna()

# %%
subway_ext_results_df = subway_ext_results_df.drop(columns="Model_Path").dropna()

# %%
subway_ext_results_df
# Out:
#                                       Model                  Variant  \
# 33   BICGRU_AE_128_3X3_L-4_RL-2_DISDECONV-Y                   Normal
# 34  BICLSTM_AE_128_3X3_L-4_RL-2_DISDECONV-Y                   Normal
# 35   BICRNN_AE_128_3X3_L-4_RL-2_DISDECONV-Y                   Normal
# 36                           C2D_AE_128_3X3                   Normal
# 37                           C2D_AE_128_3X3                   Normal
# 38                           C2D_AE_128_3X3                   Normal
# 39                           C2D_AE_128_3X3                   Normal
# 40                           C2D_AE_128_3X3                   Normal
# 41                           C2D_AE_128_3X3                   Normal
# 42                           C2D_AE_128_3X3                   Normal
# 43                           C2D_AE_128_3X3                   Normal
# 44                           C2D_AE_128_3X3                   Normal
# 45                           C2D_AE_128_3X3                   Normal
# ...
