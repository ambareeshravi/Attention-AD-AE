# %% [markdown]
# # IMPORTS

# %%
import sys
sys.path.append("..")
import warnings

# %%
from C2D_Models import *

# %%
from general import *
from general.results_handler import *

# %%
from universal_tester import *

# %%
from SVDD_fine_tuning import *

# %% [markdown]
# # General

# %%
MODELS_PATH = "../../ATTN_PPR_MODELS/"
METRICS = ['absolute', 'squared', 'ssim', 'psnr']
IGNORE_KEYS = ['loss', 'regularity', 'flat_loss', 'flat_regularity', 'agg_regularity', 'auc_roc', 'pr_roc']
SAVE_PATH = "../../ATTN_PPR_RESULTS/"
IAD_DATASETS = ["HAM10000", "IR_DISTRACTION", "MV-TEC", "MV_TEC"]

# %%
dataset_channels = {
    'AVENUE': 3,
    'HAM10000': 3,
    'IR_DISTRACTION': 3,
    'MV_TEC': 3,
    'SUBWAY_ENTRANCE': 1,
    'SUBWAY_EXIT': 1,
    'UCSD1': 1,
    'UCSD2': 1
}

# %% [markdown]
# # Helper Functions

# %%
def get_model_att_ppr(model_path, channels, att_channels = None):
    model_path = model_path.lower()
    if "softmax_attention" in model_path:
        return SoftMaxConvAttentionWrapper(C2D_AE_128_3x3(channels = channels), channels = att_channels)
    elif "conv_attention" in model_path:
        return ConvAttentionWrapper(C2D_AE_128_3x3(channels = channels), channels = att_channels)
    elif "aac" in model_path:
        return C2D_AE_128_3x3_AAC(channels = channels)
    elif "sqzex" in model_path:
        return C2D_AE_128_3x3_SQZEX(channels = channels)
    else:
        return C2D_AE_128_3x3(channels = channels)
    
def replace_model_name(model_name):
    model_name = model_name.lower()
    if "softmax_attention" in model_name:
        return "Softmax Attention CAE"
    elif "conv_attention" in model_name:
        return "Conv Attention CAE"
    elif "aac" in model_name:
        return "Attention Augmented CAE"
    elif "sqzex" in model_name:
        return "Squeeze Excitation CAE"
    else:
        return "Baseline CAE"
    
def get_results_att_ppr(model, model_path, all_results, metric, scoring_type):
    metric_results = all_results[metric]
    results_dict = {
        "Dataset": ModelParser.getDatasetType(model_path),
        "Model": model.__name__,
        "AUC_ROC": round(metric_results["auc_roc_score"][scoring_type], 4),
        "EER": round(metric_results["eer"][scoring_type], 4),
        "AUC_PR": round(metric_results["pr_roc_score"][scoring_type], 4),
        "Precision": round(metric_results["best"][scoring_type]["classification_report"]["weighted avg"]["precision"], 4),
        "Recall": round(metric_results["best"][scoring_type]["classification_report"]["weighted avg"]["recall"], 4),
        "F1_Score": round(metric_results["best"][scoring_type]["classification_report"]["weighted avg"]["f1-score"], 4),
    }
    return results_dict

def generate_csvs():
    for metric in METRICS:
        for scoring_type in ["agg", "overall"]:
            df = pd.DataFrame(MAIN_RESULTS_DICT[metric][scoring_type])
            df = df.sort_values(["Dataset", "Model"])
            df.to_csv(join_paths([SAVE_PATH, "%s_%s.csv"%(metric, scoring_type)]), index = False)
            
def get_att_channels(model_path):
    if "_C1_" in model_path: return 1
    if "_C3_" in model_path: return 3
    return False

# %% [markdown]
# ----------------------------------------------------------------

# %% [markdown]
# # Main Results Generation Process

# %%
# MAIN_RESULTS_DICT = dict()
# for metric in METRICS:
#     MAIN_RESULTS_DICT[metric] = {
#         "agg": list(),
#         "overall": list()
#     }
    
# MAIN_RESULTS_DICT = load_pickle(join_paths([SAVE_PATH, "ATT_PPR_RESULTS.pkl"]))

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")

    for DATA_MODELS_PATH in read_directory_contents(MODELS_PATH):
        DATASET = ModelParser.getDatasetType(DATA_MODELS_PATH)
        INFO(DATASET)
        test_data, CHANNELS = select_dataset(
                DATASET.lower(),
                isTrain = False,
        )
        print("Data loaded\n")

        dataset_train_stats = dict()

        for MODEL_DIR in read_directory_contents(DATA_MODELS_PATH):
            print(MODEL_DIR)
            MODEL_PATH = join_paths([MODEL_DIR, MODEL_DIR.split("/")[-1] + ".pth.tar"])
            TRAIN_STATS_PKL = join_paths([MODEL_DIR, "train_stats.pkl"])

            MODEL = get_model_att_ppr(MODEL_PATH, channels = CHANNELS, att_channels = get_att_channels(MODEL_PATH))
            load_model(MODEL, MODEL_PATH)
            MODEL_NAME = MODEL.__name__
            dataset_train_stats[MODEL_NAME] = load_pickle(TRAIN_STATS_PKL)
            if "avenue" in DATASET.lower() and "sqzex" not in MODEL_DIR.lower(): continue
                
            tester = AutoEncoder_Tester(
                model = MODEL,
                dataset = test_data,
                model_file = MODEL_PATH,
                stackFrames = 64,
                regularity_type = "savgol",
                recordResults = True,
                printResults = False,
                forceNormalTest = True,
                useGPU = "AAC" not in MODEL_NAME
            )
            tester.test()
            RESULTS_FILE = join_paths([MODEL_DIR, MODEL_DIR.split("/")[-1] + ".pkl"])
            MODEL_RESULTS = load_pickle(RESULTS_FILE)
            for metric in METRICS:
                for scoring_type in ["agg", "overall"]:
                    r = get_results_att_ppr(MODEL, MODEL_PATH, MODEL_RESULTS, metric, scoring_type)
                    MAIN_RESULTS_DICT[metric][scoring_type].append(r)
            del MODEL, tester      
        print("-"*40)
        dump_pickle(dataset_train_stats, join_paths([SAVE_PATH, "%s_train_stats.pkl"%(DATASET)]))
        del test_data
        INFO("COMPLETED: " + DATASET)
# Out:
# 0it [00:00, ?it/s]
# ----------------------------------------
# [INFO]: AVENUE
# ----------------------------------------
# 0it [00:02, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-70999feb106c> in <module>
#       7         test_data, CHANNELS = select_dataset(
#       8                 DATASET.lower(),
# ----> 9                 isTrain = False,
#      10         )
#      11         print("Data loaded\n")
#
# ~/Documents/PROJECTS/THESIS_WORK/VideoAnomalyDetection/general/data.py in select_dataset(dataset, parent_path, isTrain, asImages, image_size, image_type, n_frames, frame_strides, sample_stride, getNormalized)
#    1025         return StreetScene(**kwargs), 3 if flow_channels == 0 else 1
#    1026     elif "avenue" in dataset:
# -> 1027         return Avenue(**kwargs), 3 if flow_channels == 0 else 1
#    1028     elif "shangai" in dataset:
#    1029         return ShangaiTech(**kwargs), 3 if flow_channels == 0 else 1
#
# ~/Documents/PROJECTS/THESIS_WORK/VideoAnomalyDetection/general/data.py in __init__(self, parent_path, isTrain, asImages, image_size, image_type, n_frames, frame_strides, sample_stride, getNormalized)
#     687         else:
#     688             self.read = self.read_video_data
# --> 689         self.create_dataset()
#     690         Attributes.__init__(self)
#     691
#
# ~/Documents/PROJECTS/THESIS_WORK/VideoAnomalyDetection/general/data.py in create_dataset(self)
#     734             try:
#     735                 files_in_dir = read_directory_contents(join_paths([video_directory, "*.png"]))
# --> 736                 data, labels = self.read(files_in_dir, idx)
#     737                 labels = labels[:len(data)]
#     738             except Exception as e:
#
# ~/Documents/PROJECTS/THESIS_WORK/VideoAnomalyDetection/general/data.py in read_image_data(self, files_in_dir, idx)
#     712     def read_image_data(self, files_in_dir, idx):
#     713         files_in_dir, indices = self.stride_through_frames(files_in_dir)
# --> 714         data = self.read_frames(files_in_dir)
#     715         if self.isTrain:
#     716             labels = [NORMAL_LABEL] * len(data)
#
# ~/Documents/PROJECTS/THESIS_WORK/VideoAnomalyDetection/general/data.py in read_normal(self, files)
#      52
#      53     def read_normal(self, files):
# ---> 54         return [self.data_transform(read_image(image_path)) for image_path in files]
#      55
#      56     def read_gray(self, files):
#
# ~/Documents/PROJECTS/THESIS_WORK/VideoAnomalyDetection/general/data.py in <listcomp>(.0)
#      52
#      53     def read_normal(self, files):
# ---> 54         return [self.data_transform(read_image(image_path)) for image_path in files]
#      55
#      56     def read_gray(self, files):
#
# ~/Documents/amb_venv/lib/python3.6/site-packages/torchvision/transforms/transforms.py in __call__(self, img)
#      65     def __call__(self, img):
#      66         for t in self.transforms:
# ---> 67             img = t(img)
#      68         return img
#      69
#
# ~/Documents/PROJECTS/THESIS_WORK/VideoAnomalyDetection/general/data.py in <lambda>(x)
#     654
#     655         transforms_list = list()
# --> 656         transforms_list += [lambda x: transforms.F.crop(x, 60, 0, 300, 640)]
#     657
#     658         if self.isTrain:
#
# ~/Documents/amb_venv/lib/python3.6/site-packages/torchvision/transforms/functional.py in crop(img, top, left, height, width)
#     379
#     380     if not isinstance(img, torch.Tensor):
# --> 381         return F_pil.crop(img, top, left, height, width)
#     382
#     383     return F_t.crop(img, top, left, height, width)
#
# ~/Documents/amb_venv/lib/python3.6/site-packages/torchvision/transforms/functional_pil.py in crop(img, top, left, height, width)
#     381         raise TypeError('img should be PIL Image. Got {}'.format(type(img)))
#     382
# --> 383     return img.crop((left, top, left + width, top + height))
#     384
#     385
#
# ~/Documents/amb_venv/lib/python3.6/site-packages/PIL/Image.py in crop(self, box)
#    1131             return self.copy()
#    1132
# -> 1133         self.load()
#    1134         return self._new(self._crop(self.im, box))
#    1135
#
# ~/Documents/amb_venv/lib/python3.6/site-packages/PIL/ImageFile.py in load(self)
#     249
#     250                             b = b + s
# --> 251                             n, err_code = decoder.decode(b)
#     252                             if n < 0:
#     253                                 break
#
# KeyboardInterrupt:

# %%
dump_pickle(MAIN_RESULTS_DICT, join_paths([SAVE_PATH, "ATT_PPR_RESULTS.pkl"]))
generate_csvs()
print("DONE")
# Out:
# True

# %% [markdown]
# # IAD Results

# %%
IAD_TAG = "IAD"

# %%
IAD_RESULTS_DICT = dict()
for metric in METRICS:
    IAD_RESULTS_DICT[metric] = {
        "agg": list(),
        "overall": list()
    }

# %%
def generate_iad_results(results_file):
    results = load_pickle(results_file)
    for metric in METRICS:
        ins_results = results[metric]
        for scoring_type in ["agg", "overall"]:
            model = get_model_att_ppr(results_file, channels = 3, att_channels = get_att_channels(results_file))
            extracted_results = {
                "Dataset": ModelParser.getDatasetType(results_file),
                "Model": model.__name__,
                "AUC_ROC": ins_results["auc_roc_score"][scoring_type],
                "MEAN_AUC_ROC": ins_results["auc_roc_score"]["mean"],
                "CLASS_AUC_ROC": ins_results["auc_roc"],
                "EER": ins_results["eer"][scoring_type],
                "AUC_PR": ins_results["pr_roc_score"][scoring_type],
                "CLASS_PR_ROC": ins_results["pr_roc"],
                "MEAN_AUC_PR": ins_results["pr_roc_score"]["mean"],
                "Pecision": ins_results["best"][scoring_type]['classification_report']['weighted avg']['precision'],
                "Recall": ins_results["best"][scoring_type]['classification_report']['weighted avg']['recall'],
                "F1-Score": ins_results["best"][scoring_type]['classification_report']['weighted avg']['f1-score'],
            }
            del model
            IAD_RESULTS_DICT[metric][scoring_type].append(extracted_results)

# %%
for DATA_MODELS_PATH in read_directory_contents(MODELS_PATH):
    DATASET = ModelParser.getDatasetType(DATA_MODELS_PATH)
    if DATASET not in IAD_DATASETS: continue
    INFO(DATASET)
    
    for MODEL_DIR in read_directory_contents(DATA_MODELS_PATH):
        print(MODEL_DIR)
        MODEL_RESULTS_FILE = join_paths([MODEL_DIR, MODEL_DIR.split("/")[-1] + ".pkl"])
        generate_iad_results(MODEL_RESULTS_FILE)
# Out:
# ----------------------------------------
# [INFO]: HAM10000
# ----------------------------------------
# ../../ATTN_PPR_MODELS/HAM10000/C2D_AE_128_3X3-_ADAM_MSE_HAM10000_NORMAL-{APE}
# ../../ATTN_PPR_MODELS/HAM10000/C2D_AE_128_3X3-_CONV_ATTENTION_P64_L1E-06_C1_ADAM_MSE_HAM10000_NORMAL-{APE}
# ../../ATTN_PPR_MODELS/HAM10000/C2D_AE_128_3X3-_CONV_ATTENTION_P64_L1E-06_C3_ADAM_MSE_HAM10000_NORMAL-{APE}
# ../../ATTN_PPR_MODELS/HAM10000/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C1_ADAM_MSE_HAM10000_NORMAL-{APE}
# ../../ATTN_PPR_MODELS/HAM10000/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_HAM10000_NORMAL-{APE}
# ../../ATTN_PPR_MODELS/HAM10000/C2D_AE_128_3X3_AAC-_ADAM_MSE_HAM10000_NORMAL-{APE}
# ../../ATTN_PPR_MODELS/HAM10000/C2D_AE_128_3X3_SQZEX-_ADAM_MSE_HAM10000_NORMAL-{APE}
# ----------------------------------------
# [INFO]: IR_DISTRACTION
# ----------------------------------------
# ../../ATTN_PPR_MODELS/IR_DISTRACTION/C2D_AE_128_3X3-_ADAM_MSE_IR_DISTRACTION_NORMAL-{APE}
# ../../ATTN_PPR_MODELS/IR_DISTRACTION/C2D_AE_128_3X3-_CONV_ATTENTION_P64_L1E-06_C1_ADAM_MSE_IR_DISTRACTION_NORMAL-{APE}
# ../../ATTN_PPR_MODELS/IR_DISTRACTION/C2D_AE_128_3X3-_CONV_ATTENTION_P64_L1E-06_C3_ADAM_MSE_IR_DISTRACTION_NORMAL-{APE}
# ../../ATTN_PPR_MODELS/IR_DISTRACTION/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C1_ADAM_MSE_IR_DISTRACTION_NORMAL-{APE}
# ../../ATTN_PPR_MODELS/IR_DISTRACTION/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_IR_DISTRACTION_NORMAL-{APE}
# ../../ATTN_PPR_MODELS/IR_DISTRACTION/C2D_AE_128_3X3_AAC-_ADAM_MSE_IR_DISTRACTION_NORMAL-{APE}
# ../../ATTN_PPR_MODELS/IR_DISTRACTION/C2D_AE_128_3X3_SQZEX-_ADAM_MSE_IR_DISTRACTION_NORMAL-{APE}
# ----------------------------------------
# [INFO]: MV_TEC
# ----------------------------------------
# ../../ATTN_PPR_MODELS/MV-TEC/C2D_AE_128_3X3-_ADAM_MSE_MV_TEC_NORMAL-{APE}
# ../../ATTN_PPR_MODELS/MV-TEC/C2D_AE_128_3X3-_CONV_ATTENTION_P64_L1E-06_C1_ADAM_MSE_MV_TEC_NORMAL-{APE}
# ../../ATTN_PPR_MODELS/MV-TEC/C2D_AE_128_3X3-_CONV_ATTENTION_P64_L1E-06_C3_ADAM_MSE_MV_TEC_NORMAL-{APE}
# ../../ATTN_PPR_MODELS/MV-TEC/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C1_ADAM_MSE_MV_TEC_NORMAL-{APE}
# ../../ATTN_PPR_MODELS/MV-TEC/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_MV_TEC_NORMAL-{APE}
# ../../ATTN_PPR_MODELS/MV-TEC/C2D_AE_128_3X3_AAC-_ADAM_MSE_MV_TEC_NORMAL-{APE}
# ../../ATTN_PPR_MODELS/MV-TEC/C2D_AE_128_3X3_SQZEX-_ADAM_MSE_MV_TEC_NORMAL-{APE}

# %%
dump_pickle(IAD_RESULTS_DICT, join_paths([SAVE_PATH, "IAD_results.pkl"]))
print("DONE")
# Out:
# True

# %%
IAD_RESULTS_DICT = load_pickle(join_paths([SAVE_PATH, "IAD_results.pkl"]))

# %%
df = pd.DataFrame(IAD_RESULTS_DICT["absolute"]["agg"])

# %%
df
# Out:
#            Dataset                                         Model   AUC_ROC  \
# 0         HAM10000                               C2D_AE_128_3x3-  0.686001
# 1         HAM10000  C2D_AE_128_3x3-_CONV_ATTENTION_P64_L1e-06_C1  0.685132
# 2         HAM10000  C2D_AE_128_3x3-_CONV_ATTENTION_P64_L1e-06_C3  0.690999
# 3         HAM10000      C2D_AE_128_3x3-_SOFTMAX_ATTENTION_P64_C1  0.571396
# 4         HAM10000      C2D_AE_128_3x3-_SOFTMAX_ATTENTION_P64_C3  0.701490
# 5         HAM10000                           C2D_AE_128_3x3_AAC-  0.687797
# 6         HAM10000                         C2D_AE_128_3x3_SQZEX-  0.693629
# 7   IR_DISTRACTION                               C2D_AE_128_3x3-  0.796222
# 8   IR_DISTRACTION  C2D_AE_128_3x3-_CONV_ATTENTION_P64_L1e-06_C1  0.795578
# 9   IR_DISTRACTION  C2D_AE_128_3x3-_CONV_ATTENTION_P64_L1e-06_C3  0.784956
# 10  IR_DISTRACTION      C2D_AE_128_3x3-_SOFTMAX_ATTENTION_P64_C1  0.478889
# 11  IR_DISTRACTION      C2D_AE_128_3x3-_SOFTMAX_ATTENTION_P64_C3  0.603800
# 12  IR_DISTRACTION                           C2D_AE_128_3x3_AAC-  0.835044
# 13  IR_DISTRACTION                         C2D_AE_128_3x3_SQZEX-  0.810500
# 14          MV_TEC                               C2D_AE_128_3x3-  0.613352
# 15          MV_TEC  C2D_AE_128_3x3-_CONV_ATTENTION_P64_L1e-06_C1  0.618505
# 16          MV_TEC  C2D_AE_128_3x3-_CONV_ATTENTION_P64_L1e-06_C3  0.638608
# 17          MV_TEC      C2D_AE_128_3x3-_SOFTMAX_ATTENTION_P64_C1  0.620045
# 18          MV_TEC      C2D_AE_128_3x3-_SOFTMAX_ATTENTION_P64_C3  0.561610
# 19          MV_TEC                           C2D_AE_128_3x3_AAC-  0.609543
# 20          MV_TEC                         C2D_AE_128_3x3_SQZEX-  0.617853
#
#     MEAN_AUC_ROC                                      CLASS_AUC_ROC       EER  \
# 0       0.702444  [0.8339449541284405, 0.709387159533074, 0.7182...  0.355000
# 1       0.703879  [0.8313761467889909, 0.705535019455253, 0.7185...  0.352601
# 2       0.708229  [0.8358256880733945, 0.7111964980544747, 0.722...  0.350833
# 3       0.570904  [0.5280275229357798, 0.580544747081712, 0.5866...  0.433333
# 4       0.753134  [0.8393883792048931, 0.7203599221789884, 0.738...  0.344451
# 5       0.702938  [0.8296636085626912, 0.7031128404669261, 0.715...  0.351934
# 6       0.709257  [0.8348776758409786, 0.7146400778210117, 0.722...  0.347375
# 7       0.794867               [0.6591, 0.7585, 0.9670000000000001]  0.300000
# 8       0.794800                            [0.6595, 0.7629, 0.962]  0.290000
# 9       0.787000               [0.6212, 0.7704, 0.9693999999999999]  0.263333
# 10      0.482133              [0.4943, 0.5473, 0.40480000000000005]  0.496667
# 11      0.602033                           [0.5561, 0.5534, 0.6966]  0.460000
# 12      0.839200   [0.7015000000000001, 0.8306, 0.9854999999999998]  0.243333
# 13      0.804800               [0.6614, 0.7793, 0.9737000000000001]  0.243333
# 14      0.639515  [0.8373015873015874, 0.704272863568216, 0.5807...  0.428266
# 15      0.641394  [0.8142857142857143, 0.690592203898051, 0.6067...  0.404053
# 16      0.654221  [0.8103174603174603, 0.700712143928036, 0.5895...  0.396146
# 17      0.644393  [0.7801587301587302, 0.7153298350824588, 0.628...  0.415103
# 18      0.637150  [0.8603174603174604, 0.6909670164917541, 0.504...  0.468998
# 19      0.660704  [0.8261904761904761, 0.6954647676161919, 0.578...  0.420509
# 20      0.646021  [0.8436507936507935, 0.7082083958020989, 0.554...  0.420985
#
#       AUC_PR                                       CLASS_PR_ROC  MEAN_AUC_PR  \
# 0   0.618653  [0.8102958834493114, 0.5998591277288121, 0.744...     0.707782
# 1   0.619000  [0.806280955129862, 0.6023549322192593, 0.7447...     0.711263
# 2   0.614332  [0.8144394711049829, 0.596743202232283, 0.7425...     0.713325
# 3   0.686102  [0.5938407994468471, 0.6726967844599026, 0.814...     0.686199
# 4   0.614819  [0.8046372852878263, 0.6097213521690048, 0.748...     0.738636
# 5   0.616170  [0.8056861479528674, 0.6026840036599632, 0.746...     0.712374
# 6   0.612619  [0.8149978383565307, 0.5931164029606546, 0.741...     0.712240
# 7   0.780611  [0.668895471502317, 0.7596022413833969, 0.9674...     0.798643
# 8   0.778865  [0.6558887309819585, 0.7727710844333873, 0.964...     0.797771
# 9   0.778071  [0.6473168416971862, 0.7877074023826396, 0.973...     0.802758
# 10  0.572195  [0.5570968825832607, 0.5253572839506221, 0.664...     0.582157
# 11  0.569859  [0.53276168559466, 0.5350842466002673, 0.70330...     0.590383
# 12  0.805835  [0.6643525487975639, 0.8267573190746549, 0.986...     0.825840
# 13  0.785844  [0.6690880032158317, 0.7732460530551477, 0.976...     0.806255
# 14  0.646279  [0.6311955584778812, 0.6251995733797795, 0.827...     0.727756
# 15  0.652113  [0.6105605999719228, 0.5789882490346153, 0.827...     0.731770
# 16  0.641296  [0.6176770988199485, 0.6142952423397358, 0.773...     0.732269
# 17  0.665844  [0.6580359547394332, 0.5794683123242571, 0.762...     0.744792
# 18  0.682607  [0.6458258809703076, 0.5697737543554883, 0.795...     0.745653
# 19  0.668167  [0.6621923595047565, 0.5818980348120949, 0.789...     0.725787
# 20  0.655437  [0.6464088214596422, 0.5851378621647195, 0.841...     0.718771
#
#     Pecision    Recall  F1-Score
# 0   0.720349  0.688528  0.700053
# 1   0.721198  0.658070  0.676029
# 2   0.725814  0.704980  0.713216
# 3   0.661182  0.565807  0.590806
# 4   0.733031  0.695643  0.708210
# 5   0.725998  0.709426  0.716255
# 6   0.725253  0.691863  0.703675
# 7   0.768125  0.750000  0.745702
# 8   0.748263  0.728333  0.722769
# 9   0.749333  0.748333  0.748081
# 10  0.530390  0.530000  0.528486
# 11  0.636998  0.611667  0.592846
# 12  0.816526  0.801667  0.799311
# 13  0.793773  0.790000  0.789323
# 14  0.691320  0.697971  0.694395
# 15  0.682410  0.605797  0.627031
# 16  0.688109  0.654493  0.667082
# 17  0.693418  0.500870  0.515727
# 18  0.649677  0.640580  0.644850
# 19  0.688516  0.506667  0.523711
# 20  0.686922  0.696232  0.691091

# %%
latex_string = "\n"

dataset = ""
old_dataset = ""
for idx, row in df.iterrows():
    dataset = " ".join(row["Dataset"].split("_"))
#     if "_C1" in str(row): continue
    if "ir_distraction" in str(row).lower(): continue
    model = replace_model_name(row["Model"])
    if dataset == "" or dataset != old_dataset:
        latex_string += "\t\hline\n\t\multirow{5}{*}{%s}"%(dataset)
    row = list(row[:3]) + list(row[5:7]) + list(row[9:])
    latex_string += "\t" + ("" if "soft" in str(row).lower() else "") + "& " + " & ".join(list(map(lambda x: "%0.2f"%(x*100) if isinstance(x, float) else str(x), [model] + list(row)[2:]))) + "\\\\\n"
    old_dataset = dataset
latex_string += "\t\hline\n"

# %%
print(latex_string)
# Out:
# 	\hline
# 	\multirow{5}{*}{HAM10000}	& Baseline CAE & 68.60 & 35.50 & 61.87 & 72.03 & 68.85 & 70.01\\
# 	& Conv Attention CAE & 68.51 & 35.26 & 61.90 & 72.12 & 65.81 & 67.60\\
# 	& Conv Attention CAE & 69.10 & 35.08 & 61.43 & 72.58 & 70.50 & 71.32\\
# 	& Softmax Attention CAE & 57.14 & 43.33 & 68.61 & 66.12 & 56.58 & 59.08\\
# 	& Softmax Attention CAE & 70.15 & 34.45 & 61.48 & 73.30 & 69.56 & 70.82\\
# 	& Attention Augmented CAE & 68.78 & 35.19 & 61.62 & 72.60 & 70.94 & 71.63\\
# 	& Squeeze Excitation CAE & 69.36 & 34.74 & 61.26 & 72.53 & 69.19 & 70.37\\
# 	\hline
# 	\multirow{5}{*}{MV TEC}	& Baseline CAE & 61.34 & 42.83 & 64.63 & 69.13 & 69.80 & 69.44\\
# 	& Conv Attention CAE & 61.85 & 40.41 & 65.21 & 68.24 & 60.58 & 62.70\\
# 	& Conv Attention CAE & 63.86 & 39.61 & 64.13 & 68.81 & 65.45 & 66.71\\
# 	& Softmax Attention CAE & 62.00 & 41.51 & 66.58 & 69.34 & 50.09 & 51.57\\
# 	& Softmax Attention CAE & 56.16 & 46.90 & 68.26 & 64.97 & 64.06 & 64.48\\
# 	& Attention Augmented CAE & 60.95 & 42.05 & 66.82 & 68.85 & 50.67 & 52.37\\
# 	& Squeeze Excitation CAE & 61.79 & 42.10 & 65.54 & 68.69 & 69.62 & 69.11\\
# 	\hline

# %% [markdown]
# # Results Table - VAD datasets - MSE Agg

# %%
read_directory_contents(join_paths(["../../ATTN_PPR_RESULTS/VAD_ResultsCSV/", "*.csv"]))
# Out:
# ['../../ATTN_PPR_RESULTS/VAD_ResultsCSV/absolute_agg.csv',
#  '../../ATTN_PPR_RESULTS/VAD_ResultsCSV/absolute_overall.csv',
#  '../../ATTN_PPR_RESULTS/VAD_ResultsCSV/psnr_agg.csv',
#  '../../ATTN_PPR_RESULTS/VAD_ResultsCSV/psnr_overall.csv',
#  '../../ATTN_PPR_RESULTS/VAD_ResultsCSV/squared_agg.csv',
#  '../../ATTN_PPR_RESULTS/VAD_ResultsCSV/squared_overall.csv',
#  '../../ATTN_PPR_RESULTS/VAD_ResultsCSV/ssim_agg.csv',
#  '../../ATTN_PPR_RESULTS/VAD_ResultsCSV/ssim_overall.csv']

# %%
df = pd.read_csv('../../ATTN_PPR_RESULTS/ResultsTables/VAD_results.csv')

# %%
adf = df.copy()
for ds in IAD_DATASETS:
    adf = adf[~adf.Dataset.str.contains(ds)]

# %%
adf.to_csv(join_paths([SAVE_PATH, "ResultsTables/VAD_results.csv"]))

# %%
latex_string = "\n"

dataset = ""
old_dataset = ""
for idx, row in adf.iterrows():
    dataset = " ".join(row["Dataset"].split("_"))
    if "avenue" in dataset.lower() and "_C1" in str(row): continue
    model = replace_model_name(row["Model"])
    if dataset == "" or dataset != old_dataset:
        latex_string += "\t\hline\n\t\multirow{5}{*}{%s}"%(dataset)
    latex_string += "\t" + ("\setrow{\\bfseries}" if "soft" in str(row).lower() else "") + "& " + " & ".join(list(map(lambda x: "%0.2f"%(x*100) if isinstance(x, float) else str(x), [model] + list(row)[2:]))) + "\\\\\n"
    old_dataset = dataset
latex_string += "\t\hline\n"

# %%
print(latex_string)
# Out:
# 	\hline
# 	\multirow{5}{*}{AVENUE}	& Baseline CAE & 81.60 & 25.97 & 80.15 & 75.28 & 74.38 & 74.47\\
# 	& Conv Attention CAE & 79.75 & 25.93 & 76.04 & 76.03 & 74.55 & 74.61\\
# 	\setrow{\bfseries}& Softmax Attention CAE & 89.67 & 15.76 & 89.66 & 85.44 & 85.46 & 85.43\\
# 	& Attention Augmented CAE & 78.08 & 27.84 & 72.62 & 73.31 & 72.44 & 72.54\\
# 	& Squeeze Excitation CAE & 80.52 & 24.86 & 75.94 & 76.50 & 75.80 & 75.89\\
# 	\hline
# 	\multirow{5}{*}{SUBWAY ENTRANCE}	& Baseline CAE & 74.28 & 33.38 & 99.03 & 96.38 & 61.15 & 73.47\\
# 	& Conv Attention CAE & 73.85 & 33.10 & 99.00 & 96.18 & 65.70 & 76.95\\
# 	\setrow{\bfseries}& Softmax Attention CAE & 74.88 & 31.41 & 99.12 & 96.53 & 64.46 & 75.99\\
# 	& Attention Augmented CAE & 74.61 & 33.28 & 99.05 & 96.28 & 62.65 & 74.65\\
# 	& Squeeze Excitation CAE & 72.08 & 32.13 & 98.86 & 96.21 & 66.63 & 77.62\\
# 	\hline
# 	\multirow{5}{*}{SUBWAY EXIT}	& Baseline CAE & 95.68 & 11.11 & 100.00 & 99.91 & 92.98 & 96.28\\
# 	& Conv Attention CAE & 95.60 & 11.11 & 100.00 & 99.91 & 93.03 & 96.31\\
# 	\setrow{\bfseries}& Softmax Attention CAE & 97.75 & 5.92 & 100.00 & 99.92 & 94.08 & 96.87\\
# 	& Attention Augmented CAE & 95.72 & 11.11 & 100.00 & 99.91 & 92.59 & 96.08\\
# 	& Squeeze Excitation CAE & 95.53 & 11.11 & 100.00 & 99.91 & 93.12 & 96.36\\
# 	\hline
# 	\multirow{5}{*}{UCSD1}	& Baseline CAE & 68.32 & 37.59 & 63.97 & 67.20 & 67.22 & 66.27\\
# 	& Conv Attention CAE & 67.54 & 38.00 & 63.16 & 66.31 & 66.29 & 65.10\\
# 	\setrow{\bfseries}& Softmax Attention CAE & 71.09 & 33.28 & 65.86 & 67.97 & 68.11 & 68.00\\
# 	& Attention Augmented CAE & 66.06 & 38.54 & 62.03 & 68.16 & 67.10 & 65.06\\
# 	& Squeeze Excitation CAE & 66.49 & 38.45 & 61.36 & 67.02 & 67.08 & 66.17\\
# 	\hline
# 	\multirow{5}{*}{UCSD2}	& Baseline CAE & 83.85 & 26.52 & 66.92 & 84.95 & 66.92 & 70.74\\
# 	& Conv Attention CAE & 86.89 & 19.36 & 66.24 & 86.56 & 80.35 & 82.11\\
# 	\setrow{\bfseries}& Softmax Attention CAE & 88.06 & 18.78 & 65.59 & 86.96 & 79.85 & 81.76\\
# 	& Attention Augmented CAE & 83.28 & 26.38 & 67.03 & 83.96 & 70.15 & 73.54\\
# 	& Squeeze Excitation CAE & 82.71 & 27.18 & 67.27 & 83.87 & 69.15 & 72.69\\
# 	\hline

# %% [markdown]
# # Results table - IAD squared agg

# %%
IAD_RESULTS_DICT = load_pickle("../../ATTN_PPR_RESULTS/IAD_results.pkl")

# %%
pd.DataFrame(IAD_RESULTS_DICT["absolute"]["overall"])
# Out:
#            Dataset                                         Model   AUC_ROC  \
# 0         HAM10000                               C2D_AE_128_3x3-  0.734262
# 1         HAM10000  C2D_AE_128_3x3-_CONV_ATTENTION_P64_L1e-06_C1  0.734189
# 2         HAM10000  C2D_AE_128_3x3-_CONV_ATTENTION_P64_L1e-06_C3  0.737902
# 3         HAM10000      C2D_AE_128_3x3-_SOFTMAX_ATTENTION_P64_C1  0.600017
# 4         HAM10000      C2D_AE_128_3x3-_SOFTMAX_ATTENTION_P64_C3  0.763978
# 5         HAM10000                           C2D_AE_128_3x3_AAC-  0.732071
# 6         HAM10000                         C2D_AE_128_3x3_SQZEX-  0.739506
# 7   IR_DISTRACTION                               C2D_AE_128_3x3-  0.794867
# 8   IR_DISTRACTION  C2D_AE_128_3x3-_CONV_ATTENTION_P64_L1e-06_C1  0.794800
# 9   IR_DISTRACTION  C2D_AE_128_3x3-_CONV_ATTENTION_P64_L1e-06_C3  0.787000
# 10  IR_DISTRACTION      C2D_AE_128_3x3-_SOFTMAX_ATTENTION_P64_C1  0.482133
# 11  IR_DISTRACTION      C2D_AE_128_3x3-_SOFTMAX_ATTENTION_P64_C3  0.602033
# 12  IR_DISTRACTION                           C2D_AE_128_3x3_AAC-  0.839200
# 13  IR_DISTRACTION                         C2D_AE_128_3x3_SQZEX-  0.804800
# 14          MV_TEC                               C2D_AE_128_3x3-  0.511893
# 15          MV_TEC  C2D_AE_128_3x3-_CONV_ATTENTION_P64_L1e-06_C1  0.511772
# 16          MV_TEC  C2D_AE_128_3x3-_CONV_ATTENTION_P64_L1e-06_C3  0.501656
# 17          MV_TEC      C2D_AE_128_3x3-_SOFTMAX_ATTENTION_P64_C1  0.550122
# 18          MV_TEC      C2D_AE_128_3x3-_SOFTMAX_ATTENTION_P64_C3  0.490347
# 19          MV_TEC                           C2D_AE_128_3x3_AAC-  0.493874
# 20          MV_TEC                         C2D_AE_128_3x3_SQZEX-  0.499377
#
#     MEAN_AUC_ROC                                      CLASS_AUC_ROC       EER  \
# 0       0.702444  [0.8339449541284405, 0.709387159533074, 0.7182...  0.318784
# 1       0.703879  [0.8313761467889909, 0.705535019455253, 0.7185...  0.313220
# 2       0.708229  [0.8358256880733945, 0.7111964980544747, 0.722...  0.317918
# 3       0.570904  [0.5280275229357798, 0.580544747081712, 0.5866...  0.425000
# 4       0.753134  [0.8393883792048931, 0.7203599221789884, 0.738...  0.280000
# 5       0.702938  [0.8296636085626912, 0.7031128404669261, 0.715...  0.316859
# 6       0.709257  [0.8348776758409786, 0.7146400778210117, 0.722...  0.320000
# 7       0.794867               [0.6591, 0.7585, 0.9670000000000001]  0.283333
# 8       0.794800                            [0.6595, 0.7629, 0.962]  0.303333
# 9       0.787000               [0.6212, 0.7704, 0.9693999999999999]  0.266667
# 10      0.482133              [0.4943, 0.5473, 0.40480000000000005]  0.510000
# 11      0.602033                           [0.5561, 0.5534, 0.6966]  0.460000
# 12      0.839200   [0.7015000000000001, 0.8306, 0.9854999999999998]  0.226667
# 13      0.804800               [0.6614, 0.7793, 0.9737000000000001]  0.236122
# 14      0.639515  [0.8373015873015874, 0.704272863568216, 0.5807...  0.478537
# 15      0.641394  [0.8142857142857143, 0.690592203898051, 0.6067...  0.496820
# 16      0.654221  [0.8103174603174603, 0.700712143928036, 0.5895...  0.471092
# 17      0.644393  [0.7801587301587302, 0.7153298350824588, 0.628...  0.436831
# 18      0.637150  [0.8603174603174604, 0.6909670164917541, 0.504...  0.498410
# 19      0.660704  [0.8261904761904761, 0.6954647676161919, 0.578...  0.527822
# 20      0.646021  [0.8436507936507935, 0.7082083958020989, 0.554...  0.520473
#
#       AUC_PR                                       CLASS_PR_ROC  MEAN_AUC_PR  \
# 0   0.599439  [0.8102958834493114, 0.5998591277288121, 0.744...     0.707782
# 1   0.599181  [0.806280955129862, 0.6023549322192593, 0.7447...     0.711263
# 2   0.596536  [0.8144394711049829, 0.596743202232283, 0.7425...     0.713325
# 3   0.678514  [0.5938407994468471, 0.6726967844599026, 0.814...     0.686199
# 4   0.593964  [0.8046372852878263, 0.6097213521690048, 0.748...     0.738636
# 5   0.599769  [0.8056861479528674, 0.6026840036599632, 0.746...     0.712374
# 6   0.595072  [0.8149978383565307, 0.5931164029606546, 0.741...     0.712240
# 7   0.774288  [0.668895471502317, 0.7596022413833969, 0.9674...     0.798643
# 8   0.772905  [0.6558887309819585, 0.7727710844333873, 0.964...     0.797771
# 9   0.770409  [0.6473168416971862, 0.7877074023826396, 0.973...     0.802758
# 10  0.585603  [0.5570968825832607, 0.5253572839506221, 0.664...     0.582157
# 11  0.571612  [0.53276168559466, 0.5350842466002673, 0.70330...     0.590383
# 12  0.798207  [0.6643525487975639, 0.8267573190746549, 0.986...     0.825840
# 13  0.778505  [0.6690880032158317, 0.7732460530551477, 0.976...     0.806255
# 14  0.725499  [0.6311955584778812, 0.6251995733797795, 0.827...     0.727756
# 15  0.725982  [0.6105605999719228, 0.5789882490346153, 0.827...     0.731770
# 16  0.734736  [0.6176770988199485, 0.6142952423397358, 0.773...     0.732269
# 17  0.715842  [0.6580359547394332, 0.5794683123242571, 0.762...     0.744792
# 18  0.749829  [0.6458258809703076, 0.5697737543554883, 0.795...     0.745653
# 19  0.734423  [0.6621923595047565, 0.5818980348120949, 0.789...     0.725787
# 20  0.744085  [0.6464088214596422, 0.5851378621647195, 0.841...     0.718771
#
#     Pecision    Recall  F1-Score
# 0   0.758879  0.651178  0.671258
# 1   0.759318  0.652290  0.672315
# 2   0.760732  0.659849  0.679482
# 3   0.676392  0.620276  0.638924
# 4   0.777354  0.734993  0.747084
# 5   0.753748  0.736994  0.743573
# 6   0.753785  0.720320  0.731382
# 7   0.771490  0.763333  0.761542
# 8   0.759775  0.751667  0.749714
# 9   0.746266  0.741667  0.740455
# 10  0.614055  0.541667  0.455228
# 11  0.634834  0.608333  0.588094
# 12  0.821830  0.816667  0.815928
# 13  0.803030  0.800000  0.799499
# 14  0.630835  0.670145  0.644908
# 15  0.632322  0.658551  0.643084
# 16  0.631409  0.518841  0.545228
# 17  0.659190  0.554203  0.578941
# 18  0.686371  0.357681  0.302346
# 19  0.628008  0.675362  0.643537
# 20  0.623339  0.611594  0.617093

# %%
pd.DataFrame(IAD_RESULTS_DICT["squared"]["agg"])
# Out:
#            Dataset                                         Model   AUC_ROC  \
# 0         HAM10000                               C2D_AE_128_3x3-  0.683160
# 1         HAM10000  C2D_AE_128_3x3-_CONV_ATTENTION_P64_L1e-06_C1  0.684214
# 2         HAM10000  C2D_AE_128_3x3-_CONV_ATTENTION_P64_L1e-06_C3  0.685492
# 3         HAM10000      C2D_AE_128_3x3-_SOFTMAX_ATTENTION_P64_C1  0.531964
# 4         HAM10000      C2D_AE_128_3x3-_SOFTMAX_ATTENTION_P64_C3  0.674065
# 5         HAM10000                           C2D_AE_128_3x3_AAC-  0.680058
# 6         HAM10000                         C2D_AE_128_3x3_SQZEX-  0.687322
# 7   IR_DISTRACTION                               C2D_AE_128_3x3-  0.852789
# 8   IR_DISTRACTION  C2D_AE_128_3x3-_CONV_ATTENTION_P64_L1e-06_C1  0.844267
# 9   IR_DISTRACTION  C2D_AE_128_3x3-_CONV_ATTENTION_P64_L1e-06_C3  0.829911
# 10  IR_DISTRACTION      C2D_AE_128_3x3-_SOFTMAX_ATTENTION_P64_C1  0.476900
# 11  IR_DISTRACTION      C2D_AE_128_3x3-_SOFTMAX_ATTENTION_P64_C3  0.637422
# 12  IR_DISTRACTION                           C2D_AE_128_3x3_AAC-  0.858278
# 13  IR_DISTRACTION                         C2D_AE_128_3x3_SQZEX-  0.867644
# 14          MV_TEC                               C2D_AE_128_3x3-  0.641830
# 15          MV_TEC  C2D_AE_128_3x3-_CONV_ATTENTION_P64_L1e-06_C1  0.645066
# 16          MV_TEC  C2D_AE_128_3x3-_CONV_ATTENTION_P64_L1e-06_C3  0.645472
# 17          MV_TEC      C2D_AE_128_3x3-_SOFTMAX_ATTENTION_P64_C1  0.644099
# 18          MV_TEC      C2D_AE_128_3x3-_SOFTMAX_ATTENTION_P64_C3  0.569797
# 19          MV_TEC                           C2D_AE_128_3x3_AAC-  0.638427
# 20          MV_TEC                         C2D_AE_128_3x3_SQZEX-  0.634291
#
#     MEAN_AUC_ROC                                      CLASS_AUC_ROC       EER  \
# 0       0.707460  [0.8279816513761469, 0.7134824902723735, 0.716...  0.361128
# 1       0.710685  [0.8267584097859326, 0.7147859922178988, 0.719...  0.358096
# 2       0.711868  [0.8275535168195719, 0.714464980544747, 0.7192...  0.360522
# 3       0.579315  [0.5441743119266055, 0.5879280155642023, 0.582...  0.471801
# 4       0.767981  [0.8328746177370032, 0.7274221789883268, 0.741...  0.372347
# 5       0.708695  [0.8247094801223241, 0.7114396887159533, 0.714...  0.362874
# 6       0.713559  [0.8276299694189603, 0.7180447470817121, 0.719...  0.355345
# 7       0.849067                           [0.7326, 0.8187, 0.9959]  0.246667
# 8       0.841967               [0.7041000000000001, 0.8243, 0.9975]  0.203333
# 9       0.836000               [0.6787000000000001, 0.8305, 0.9988]  0.270000
# 10      0.484167                           [0.4915, 0.5374, 0.4236]  0.510000
# 11      0.640800                           [0.5657, 0.6011, 0.7556]  0.400000
# 12      0.853133                              [0.6985, 0.8609, 1.0]  0.246667
# 13      0.862133                           [0.7128, 0.8758, 0.9978]  0.196667
# 14      0.699413  [0.8626984126984127, 0.6964017991004497, 0.587...  0.412560
# 15      0.703451  [0.853968253968254, 0.6797226386806597, 0.6039...  0.413276
# 16      0.712507  [0.861904761904762, 0.6902173913043478, 0.5851...  0.411135
# 17      0.686986  [0.8420634920634922, 0.7228260869565217, 0.646...  0.403159
# 18      0.679848  [0.8896825396825396, 0.7089580209895052, 0.530...  0.468203
# 19      0.708253  [0.8698412698412699, 0.6840329835082459, 0.581...  0.405405
# 20      0.703448  [0.8603174603174603, 0.7016491754122938, 0.550...  0.402570
#
#       AUC_PR                                       CLASS_PR_ROC  MEAN_AUC_PR  \
# 0   0.614789  [0.8143959932420182, 0.5943540766530371, 0.741...     0.712580
# 1   0.613910  [0.8139032595798915, 0.5928372369020533, 0.740...     0.715528
# 2   0.612907  [0.8154961215855617, 0.5934405819525272, 0.740...     0.717128
# 3   0.710023  [0.5807019185726467, 0.6655308292787591, 0.817...     0.684215
# 4   0.623080  [0.8075052894689169, 0.6021840816047064, 0.742...     0.750173
# 5   0.615432  [0.8114688541029501, 0.5946624848085494, 0.742...     0.716094
# 6   0.611723  [0.8161857936123897, 0.5901438545634599, 0.739...     0.716885
# 7   0.845811  [0.7125535835716921, 0.8188571968589803, 0.995...     0.842453
# 8   0.837509    [0.6939648135025043, 0.8225274374317499, 0.998]     0.838164
# 9   0.840398  [0.6968849152367683, 0.8311459797079168, 0.998...     0.842320
# 10  0.578793  [0.5434085943730119, 0.5246991787521019, 0.653...     0.573848
# 11  0.591268  [0.5262745555663885, 0.5795847868148722, 0.747...     0.617785
# 12  0.859480       [0.665654858095384, 0.8588009986907531, 1.0]     0.841485
# 13  0.856103  [0.6992794467499281, 0.870906197646785, 0.9981...     0.856117
# 14  0.635941  [0.6646672512657168, 0.5913359169510866, 0.835...     0.730524
# 15  0.637186  [0.6638274208127151, 0.5399028153521461, 0.819...     0.721924
# 16  0.638611  [0.67572458740937, 0.5696410970958239, 0.80401...     0.742892
# 17  0.647047  [0.6298449502708918, 0.6025046696952105, 0.763...     0.730606
# 18  0.682288  [0.7102760371634771, 0.5900868590448425, 0.792...     0.730593
# 19  0.646723  [0.697236970468296, 0.5417649487503967, 0.8010...     0.749303
# 20  0.651148  [0.6657925407768006, 0.5707144916644535, 0.839...     0.733408
#
#     Pecision    Recall  F1-Score
# 0   0.719270  0.680747  0.693989
# 1   0.721423  0.702090  0.709898
# 2   0.721573  0.688751  0.700509
# 3   0.630992  0.529346  0.556513
# 4   0.719453  0.712317  0.715592
# 5   0.719672  0.698088  0.706649
# 6   0.723555  0.703424  0.711465
# 7   0.779113  0.771667  0.770134
# 8   0.801831  0.801667  0.801640
# 9   0.754525  0.750000  0.748884
# 10  0.616671  0.535000  0.436362
# 11  0.661483  0.650000  0.643665
# 12  0.768685  0.766667  0.766228
# 13  0.834375  0.831667  0.831325
# 14  0.693306  0.699130  0.696024
# 15  0.691254  0.686377  0.688699
# 16  0.686009  0.563478  0.586882
# 17  0.699554  0.528116  0.546918
# 18  0.650667  0.642319  0.646256
# 19  0.682981  0.610435  0.631116
# 20  0.680268  0.611594  0.631855

# %% [markdown]
# # Tr Graph Generation

# %%
# %matplotlib inline

# %%
GRAPHS_SAVE_PATH = join_paths([SAVE_PATH, "TrainStats"])

# %%
for stat_file in read_directory_contents(join_paths([SAVE_PATH, "*train_stats.pkl"])):
    stats = load_pickle(stat_file)
    dataset = os.path.split(stat_file)[-1].split("_train_stats.pkl")[0]
    
    for model in stats.keys():
        model_stats = stats[model]
        model_name = replace_model_name(model)
        for loss_type in model_stats.keys():
            plt.plot(np.array(range(len(model_stats[loss_type][:200]))), model_stats[loss_type][:200], label = "%s_%s"%(model_name, loss_type))
    plt.legend()
    plt.savefig(join_paths([GRAPHS_SAVE_PATH, "%s_stats.png"%(dataset)]))
    plt.close()
    plt.clf()

# %% [markdown]
# # SVDD

# %% [markdown]
# # SVDD Best models production

# %%
svdd_auc_best = load_pickle("../ATTN_PPR_RESULTS/Baseline_SVDD/SVDD_best_AUC_ROC_Baseline.pkl")

# %%
svdd_auc_best
# Out:
# {'AVENUE': array(['1e-05', '1.0', '0.84560572377758'], dtype='<U18'),
#  'HAM10000': array(['1e-07', '20.0', '0.685140236506974'], dtype='<U18'),
#  'IR_DISTRACTION': array(['0.0001', '0.0', '0.8918555555555556'], dtype='<U18'),
#  'MV_TEC': array(['0.0001', '1.0', '0.6605161654916032'], dtype='<U18'),
#  'SUBWAY_ENTRANCE': array(['5e-05', '2.0', '0.7903505071775421'], dtype='<U18'),
#  'SUBWAY_EXIT': array(['5e-05', '1.0', '0.9744849506754267'], dtype='<U18'),
#  'UCSD1': array(['1e-05', '20.0', '0.7345594236001872'], dtype='<U18'),
#  'UCSD2': array(['0.0001', '5.0', '0.8884852893847557'], dtype='<U18')}

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    
    for DATA_MODELS_PATH in read_directory_contents(MODELS_PATH):
        DATASET = ModelParser.getDatasetType(DATA_MODELS_PATH)
        INFO(DATASET)
        lr, e, perf = svdd_auc_best[DATASET]
        lr = float(lr)
        e = int(float(e))
        for MODEL_DIR in read_directory_contents(DATA_MODELS_PATH):
            MODEL_PATH = join_paths([MODEL_DIR, MODEL_DIR.split("/")[-1] + ".pth.tar"])
            MODEL = get_model_att_ppr(MODEL_PATH, channels = dataset_channels[DATASET], att_channels = get_att_channels(MODEL_PATH))
            load_model(MODEL, MODEL_PATH)
            MODEL_NAME = MODEL.__name__

            if replace_model_name(MODEL_NAME) != replace_model_name("Baseline CAE"): continue

            svdd_ft = SVDD_FineTuner(
                model = MODEL,
                model_path = MODEL_PATH,
                dataset_type = DATASET.lower(),
                lr = lr,
                epochs = [e],
                filename_addon = "BestAUCROC",
                testOriginal = True,
                returnResults = True,
            )
            
            del MODEL, svdd_ft
        print("-"*40)
        INFO("COMPLETED: " + DATASET)
# Out:
# 0it [00:00, ?it/s]
# ----------------------------------------
# [INFO]: AVENUE
# ----------------------------------------
# 21it [01:22,  3.91s/it]
# 21it [01:19,  3.78s/it]
# 0it [00:00, ?it/s]
# OrderedDict([('auc_roc_score_agg_absolute', 0.7109144442365489), ('auc_roc_score_agg_psnr', 0.7426772343502195), ('auc_roc_score_agg_squared', 0.8160297778419683), ('auc_roc_score_agg_ssim', 0.6590777026384347), ('auc_roc_score_mean_absolute', 0.8394928932513591), ('auc_roc_score_mean_psnr', 0.8356548987769931), ('auc_roc_score_mean_squared', 0.8357024550849584), ('auc_roc_score_mean_ssim', 0.8503179338827378), ('auc_roc_score_overall_absolute', 0.9443005043703278), ('auc_roc_score_overall_psnr', 0.9676234614973724), ('auc_roc_score_overall_squared', 0.9679805505266806), ('auc_roc_score_overall_ssim', 0.9228758191842975), ('eer_agg_absolute', 0.34276317548630636), ('eer_agg_psnr', 0.2989135773363982), ('eer_agg_squared', 0.2596652347800883), ('eer_agg_ssim', 0.4031995259961487), ('eer_overall_absolute', 0.10072581839727443), ('eer_overall_psnr', 0.08857946970818378), ('eer_overall_squared', 0.08976447933639474), ('eer_overall_ssim', 0.14394027761677491), ('pr_roc_score_agg_absolute', 0.5935212731772418), ('pr_roc_score_agg_psnr', 0.6886128044697373), ('pr_roc_score_agg_squared', 0.8015145563895475), ('pr_roc_score_agg_ssim', 0.5513851505777028), ('pr_roc_score_mean_absolute', nan), ('pr_roc_score_mean_psnr', nan), ('pr_roc_score_mean_squared', nan), ('pr_roc_score_mean_ssim', nan), ('pr_roc_score_overall_absolute', 0.932495853903921), ('pr_roc_score_overall_psnr', 0.955628899206896), ('pr_roc_score_overall_squared', 0.9562967041220386), ('pr_roc_score_overall_ssim', 0.9080325091133772), ('precision_absolute_agg', 0.6907567121172048), ('precision_squared_agg', 0.7527872677069369), ('precision_ssim_agg', 0.6527766284115323), ('precision_psnr_agg', 0.7106053574130888), ('recall_absolute_agg', 0.6553771861132863), ('recall_squared_agg', 0.7438005742625946), ('recall_ssim_agg', 0.6145914904724615), ('recall_psnr_agg', 0.7035369355259723), ('f1-score_absolute_agg', 0.6519552687512744), ('f1-score_squared_agg', 0.744681276651602), ('f1-score_ssim_agg', 0.6088123457703443), ('f1-score_psnr_agg', 0.7045884146819371), ('support_absolute_agg', 15324), ('support_squared_agg', 15324), ('support_ssim_agg', 15324), ('support_psnr_agg', 15324), ('conf_mat_absolute_agg', '4589,3984,1297,5454'), ('conf_mat_squared_agg', '6076,2497,1429,5322'), ('conf_mat_ssim_agg', '4124,4449,1457,5294'), ('conf_mat_psnr_agg', '5846,2727,1816,4935'), ('precision_absolute_overall', 0.903847676547576), ('precision_squared_overall', 0.9133084467726258), ('precision_ssim_overall', 0.8608483737405992), ('precision_psnr_overall', 0.9138941885794547), ('recall_absolute_overall', 0.9038110154006787), ('recall_squared_overall', 0.91327329678935), ('recall_ssim_overall', 0.8585225789611067), ('recall_psnr_overall', 0.9137300965805273), ('f1-score_absolute_overall', 0.9038274632888619), ('f1-score_squared_overall', 0.9132887919008802), ('f1-score_ssim_overall', 0.858904134706239), ('f1-score_psnr_overall', 0.9137844299729679), ('support_absolute_overall', 15324), ('support_squared_overall', 15324), ('support_ssim_overall', 15324), ('support_psnr_overall', 15324), ('conf_mat_absolute_overall', '7825,748,726,6025'), ('conf_mat_squared_overall', '7897,676,653,6098'), ('conf_mat_ssim_overall', '7258,1315,853,5898'), ('conf_mat_psnr_overall', '7870,703,619,6132')])
# ----------------------------------------
# [INFO]: Device set to GPU
# ----------------------------------------
# 16it [01:22,  5.14s/it]
#   1%|          | 112/15328 [00:00<00:13, 1115.57it/s]
# ----------------------------------------
# [INFO]: Created Dataset
# ----------------------------------------
# 100%|██████████| 15328/15328 [00:10<00:00, 1414.65it/s]
# ----------------------------------------
# [INFO]: Created Encodings
# ----------------------------------------
# INFO: SVDD C Initialized torch.Size([1, 1536])
# INFO: SVDD Initialized
# ----------------------------------------
# [INFO]: SVDD Ready
# ----------------------------------------
# ----------------------------------------
# [INFO]: Data Loaders Ready. Starting the training
# ----------------------------------------
# ========================================
# Testing: For epochs = 1 and model: ../../ATTN_PPR_MODELS/AVENUE/C2D_AE_128_3X3-_ADAM_MSE_AVENUE_NORMAL-{APE}/C2D_AE_128_3X3-_ADAM_MSE_AVENUE_NORMAL-{APE}.pth.tar
# 0it [00:00, ?it/s]
# Epoch [0/1] | Train Loss: 0.529015 | Val Loss: 0.231433 | Time: (5) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 21it [01:20,  3.84s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.7102133285143218), ('auc_roc_score_agg_psnr', 0.808959943775281), ('auc_roc_score_agg_squared', 0.8413528965895087), ('auc_roc_score_agg_ssim', 0.6254997574742265), ('auc_roc_score_mean_absolute', 0.8453669684797053), ('auc_roc_score_mean_psnr', 0.8390817997665133), ('auc_roc_score_mean_squared', 0.8388931156388736), ('auc_roc_score_mean_ssim', 0.8473785357974993), ('auc_roc_score_overall_absolute', 0.9502369561383505), ('auc_roc_score_overall_psnr', 0.9670732105769746), ('auc_roc_score_overall_squared', 0.9672190646942103), ('auc_roc_score_overall_ssim', 0.9162606615489377), ('eer_agg_absolute', 0.33994963709045795), ('eer_agg_psnr', 0.26396827248437643), ('eer_agg_squared', 0.24227225008861583), ('eer_agg_ssim', 0.42715502157836066), ('eer_overall_absolute', 0.1013183232113746), ('eer_overall_psnr', 0.09020885794671368), ('eer_overall_squared', 0.09169011998222515), ('eer_overall_ssim', 0.15745815434769422), ('pr_roc_score_agg_absolute', 0.612656988752069), ('pr_roc_score_agg_psnr', 0.7987170515921194), ('pr_roc_score_agg_squared', 0.8383738131650578), ('pr_roc_score_agg_ssim', 0.5146158100410125), ('pr_roc_score_mean_absolute', nan), ('pr_roc_score_mean_psnr', nan), ('pr_roc_score_mean_squared', nan), ('pr_roc_score_mean_ssim', nan), ('pr_roc_score_overall_absolute', 0.9423700818656433), ('pr_roc_score_overall_psnr', 0.958035792063848), ('pr_roc_score_overall_squared', 0.9583561870597632), ('pr_roc_score_overall_ssim', 0.9020311168790361), ('precision_absolute_agg', 0.6677812248063038), ('precision_squared_agg', 0.7756533862766369), ('precision_ssim_agg', 0.6587783270563665), ('precision_psnr_agg', 0.7397606197741171), ('recall_absolute_agg', 0.6673844949099452), ('recall_squared_agg', 0.7661837640302793), ('recall_ssim_agg', 0.5895327590707388), ('recall_psnr_agg', 0.735512920908379), ('f1-score_absolute_agg', 0.6675677286647851), ('f1-score_squared_agg', 0.7669766928463999), ('f1-score_ssim_agg', 0.5703569583688901), ('f1-score_psnr_agg', 0.7363682293947138), ('support_absolute_agg', 15324), ('support_squared_agg', 15324), ('support_ssim_agg', 15324), ('support_psnr_agg', 15324), ('conf_mat_absolute_agg', '5988,2585,2512,4239'), ('conf_mat_squared_agg', '6232,2341,1242,5509'), ('conf_mat_ssim_agg', '3276,5297,993,5758'), ('conf_mat_psnr_agg', '6228,2345,1708,5043'), ('precision_absolute_overall', 0.9038981423409757), ('precision_squared_overall', 0.912297229465275), ('precision_ssim_overall', 0.8666797788316611), ('precision_psnr_overall', 0.9128042721883138), ('recall_absolute_overall', 0.9039415296267294), ('recall_squared_overall', 0.9122944400939702), ('recall_ssim_overall', 0.8643304620203602), ('recall_psnr_overall', 0.9127512398851475), ('f1-score_absolute_overall', 0.9039153317382906), ('f1-score_squared_overall', 0.9122958190611243), ('f1-score_ssim_overall', 0.8630964550382585), ('f1-score_psnr_overall', 0.9127734780596567), ('support_absolute_overall', 15324), ('support_squared_overall', 15324), ('support_ssim_overall', 15324), ('support_psnr_overall', 15324), ('conf_mat_absolute_overall', '7854,719,753,5998'), ('conf_mat_squared_overall', '7900,673,671,6080'), ('conf_mat_ssim_overall', '7930,643,1436,5315'), ('conf_mat_psnr_overall', '7888,685,652,6099')])
# ========================================
# ----------------------------------------
# ----------------------------------------
# [INFO]: COMPLETED: AVENUE
# ----------------------------------------
# ----------------------------------------
# [INFO]: HAM10000
# ----------------------------------------
# 6it [00:24,  4.04s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.6860012381241156), ('auc_roc_score_agg_psnr', 0.7125897008287851), ('auc_roc_score_agg_squared', 0.6831596169395593), ('auc_roc_score_agg_ssim', 0.6777089650293106), ('auc_roc_score_mean_absolute', 0.7024437149292692), ('auc_roc_score_mean_psnr', 0.7074594097480108), ('auc_roc_score_mean_squared', 0.7074597923620298), ('auc_roc_score_mean_ssim', 0.6743390452838572), ('auc_roc_score_overall_absolute', 0.7342616737416615), ('auc_roc_score_overall_psnr', 0.7371262886597938), ('auc_roc_score_overall_squared', 0.7371270466949666), ('auc_roc_score_overall_ssim', 0.7032504548211036), ('eer_agg_absolute', 0.35499999999970083), ('eer_agg_psnr', 0.3358693793810857), ('eer_agg_squared', 0.36112795633688605), ('eer_agg_ssim', 0.3541666666669277), ('eer_overall_absolute', 0.31878409976618804), ('eer_overall_psnr', 0.3199999999995291), ('eer_overall_squared', 0.31999999999999995), ('eer_overall_ssim', 0.33500000000043995), ('pr_roc_score_agg_absolute', 0.6186530111092485), ('pr_roc_score_agg_psnr', 0.6025666324308946), ('pr_roc_score_agg_squared', 0.6147887302550454), ('pr_roc_score_agg_ssim', 0.6248723332744686), ('pr_roc_score_mean_absolute', 0.707781731344067), ('pr_roc_score_mean_psnr', 0.7125798350131695), ('pr_roc_score_mean_squared', 0.7125796535817739), ('pr_roc_score_mean_ssim', 0.7034883532450898), ('pr_roc_score_overall_absolute', 0.5994392910974514), ('pr_roc_score_overall_psnr', 0.5939016363344058), ('pr_roc_score_overall_squared', 0.5939011904663685), ('pr_roc_score_overall_ssim', 0.6142012857582351), ('precision_absolute_agg', 0.7203488813700633), ('precision_squared_agg', 0.7192701028523926), ('precision_ssim_agg', 0.7183561125861746), ('precision_psnr_agg', 0.7413503774553492), ('recall_absolute_agg', 0.6885282347710093), ('recall_squared_agg', 0.6807469986660738), ('recall_ssim_agg', 0.6647398843930635), ('recall_psnr_agg', 0.7349933303690529), ('f1-score_absolute_agg', 0.700053162804496), ('f1-score_squared_agg', 0.6939893638080452), ('f1-score_ssim_agg', 0.6812047262568726), ('f1-score_psnr_agg', 0.737888257347642), ('support_absolute_agg', 4498), ('support_squared_agg', 4498), ('support_ssim_agg', 4498), ('support_psnr_agg', 4498), ('conf_mat_absolute_agg', '2413,885,516,684'), ('conf_mat_squared_agg', '2362,936,500,700'), ('conf_mat_ssim_agg', '2254,1044,464,736'), ('conf_mat_psnr_agg', '2658,640,552,648'), ('precision_absolute_overall', 0.7588794229137465), ('precision_squared_overall', 0.7630827223773836), ('precision_ssim_overall', 0.7395086987316459), ('precision_psnr_overall', 0.7630827223773836), ('recall_absolute_overall', 0.6511783014673188), ('recall_squared_overall', 0.7696754112939084), ('recall_ssim_overall', 0.6847487772343264), ('recall_psnr_overall', 0.7696754112939084), ('f1-score_absolute_overall', 0.6712581518916825), ('f1-score_squared_overall', 0.765816828150754), ('f1-score_ssim_overall', 0.7005269765536203), ('f1-score_psnr_overall', 0.765816828150754), ('support_absolute_overall', 4498), ('support_squared_overall', 4498), ('support_ssim_overall', 4498), ('support_psnr_overall', 4498), ('conf_mat_absolute_overall', '1993,1305,264,936'), ('conf_mat_squared_overall', '2838,460,576,624'), ('conf_mat_ssim_overall', '2288,1010,408,792'), ('conf_mat_psnr_overall', '2838,460,576,624')])
# ----------------------------------------
# [INFO]: Device set to GPU
# ----------------------------------------
#   2%|▏         | 115/6460 [00:00<00:05, 1147.40it/s]
# ----------------------------------------
# [INFO]: Created Dataset
# ----------------------------------------
# 100%|██████████| 6460/6460 [00:04<00:00, 1405.33it/s]
# ----------------------------------------
# [INFO]: Created Encodings
# ----------------------------------------
# INFO: SVDD C Initialized torch.Size([1, 1536])
# INFO: SVDD Initialized
# ----------------------------------------
# [INFO]: SVDD Ready
# ----------------------------------------
# ----------------------------------------
# [INFO]: Data Loaders Ready. Starting the training
# ----------------------------------------
# ========================================
# Testing: For epochs = 20 and model: ../../ATTN_PPR_MODELS/HAM10000/C2D_AE_128_3X3-_ADAM_MSE_HAM10000_NORMAL-{APE}/C2D_AE_128_3X3-_ADAM_MSE_HAM10000_NORMAL-{APE}.pth.tar
# Epoch [0/20] | Train Loss: 76.026163 | Val Loss: 66.666294 | Time: (2) s
# Epoch [1/20] | Train Loss: 49.094232 | Val Loss: 58.833197 | Time: (2) s
# Epoch [2/20] | Train Loss: 49.772566 | Val Loss: 63.220711 | Time: (2) s
# Epoch [3/20] | Train Loss: 48.561560 | Val Loss: 56.734906 | Time: (2) s
# Epoch [4/20] | Train Loss: 49.985333 | Val Loss: 59.763126 | Time: (2) s
# Epoch [5/20] | Train Loss: 49.204714 | Val Loss: 59.045609 | Time: (2) s
# Epoch [6/20] | Train Loss: 48.753105 | Val Loss: 60.818300 | Time: (2) s
# Epoch [7/20] | Train Loss: 49.674718 | Val Loss: 53.167380 | Time: (2) s
# Epoch [8/20] | Train Loss: 48.891128 | Val Loss: 52.226075 | Time: (2) s
# Epoch [9/20] | Train Loss: 47.396048 | Val Loss: 72.594564 | Time: (2) s
# Epoch [10/20] | Train Loss: 48.184609 | Val Loss: 72.811808 | Time: (2) s
# Epoch [11/20] | Train Loss: 47.721381 | Val Loss: 54.170351 | Time: (2) s
# Epoch [12/20] | Train Loss: 48.729781 | Val Loss: 84.506998 | Time: (2) s
# Epoch [13/20] | Train Loss: 48.377234 | Val Loss: 59.690065 | Time: (2) s
# Epoch [14/20] | Train Loss: 47.368311 | Val Loss: 60.070746 | Time: (2) s
# Epoch [15/20] | Train Loss: 45.546596 | Val Loss: 52.025467 | Time: (2) s
# Epoch [16/20] | Train Loss: 47.149154 | Val Loss: 62.361592 | Time: (2) s
# Epoch [17/20] | Train Loss: 46.467557 | Val Loss: 49.013403 | Time: (2) s
# Epoch [18/20] | Train Loss: 46.725842 | Val Loss: 51.910068 | Time: (2) s
# 0it [00:00, ?it/s]
# Epoch [19/20] | Train Loss: 47.520349 | Val Loss: 78.589011 | Time: (2) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 6it [00:23,  3.99s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.6892019153022034), ('auc_roc_score_agg_psnr', 0.7149994946432181), ('auc_roc_score_agg_squared', 0.6860891702041642), ('auc_roc_score_agg_ssim', 0.677860824742268), ('auc_roc_score_mean_absolute', 0.7066387222485949), ('auc_roc_score_mean_psnr', 0.7103725523039374), ('auc_roc_score_mean_squared', 0.7103717416683991), ('auc_roc_score_mean_ssim', 0.6748437030668465), ('auc_roc_score_overall_absolute', 0.7362022437841116), ('auc_roc_score_overall_psnr', 0.7395019708914493), ('auc_roc_score_overall_squared', 0.7395012128562766), ('auc_roc_score_overall_ssim', 0.7037886597938143), ('eer_agg_absolute', 0.3525000000000001), ('eer_agg_psnr', 0.3391666666669457), ('eer_agg_squared', 0.35930867192254895), ('eer_agg_ssim', 0.355), ('eer_overall_absolute', 0.32565191024874285), ('eer_overall_psnr', 0.3150000000001083), ('eer_overall_squared', 0.3150000000001083), ('eer_overall_ssim', 0.3320394147506718), ('pr_roc_score_agg_absolute', 0.6144787484534788), ('pr_roc_score_agg_psnr', 0.6004255239611757), ('pr_roc_score_agg_squared', 0.6122503429465624), ('pr_roc_score_agg_ssim', 0.6247238936830555), ('pr_roc_score_mean_absolute', 0.7127412168162901), ('pr_roc_score_mean_psnr', 0.7150336342754281), ('pr_roc_score_mean_squared', 0.7150343408963645), ('pr_roc_score_mean_ssim', 0.7036969630812416), ('pr_roc_score_overall_absolute', 0.5962836257101323), ('pr_roc_score_overall_psnr', 0.5918358600156124), ('pr_roc_score_overall_squared', 0.5918364955312563), ('pr_roc_score_overall_ssim', 0.6138436687572427), ('precision_absolute_agg', 0.7270572895050696), ('precision_squared_agg', 0.7339768410413331), ('precision_ssim_agg', 0.7181658008565632), ('precision_psnr_agg', 0.7455046477686069), ('recall_absolute_agg', 0.7216540684748777), ('recall_squared_agg', 0.7436638506002667), ('recall_ssim_agg', 0.6651845264562027), ('recall_psnr_agg', 0.7434415295686972), ('f1-score_absolute_agg', 0.724171712918113), ('f1-score_squared_agg', 0.7379269662725122), ('f1-score_ssim_agg', 0.6815384011128778), ('f1-score_psnr_agg', 0.7444391170599106), ('support_absolute_agg', 4498), ('support_squared_agg', 4498), ('support_ssim_agg', 4498), ('support_psnr_agg', 4498), ('conf_mat_absolute_agg', '2636,662,590,610'), ('conf_mat_squared_agg', '2797,501,652,548'), ('conf_mat_ssim_agg', '2258,1040,466,734'), ('conf_mat_psnr_agg', '2706,592,562,638'), ('precision_absolute_overall', 0.7580954101730402), ('precision_squared_overall', 0.7540659441898538), ('precision_ssim_overall', 0.7389780804261894), ('precision_psnr_overall', 0.7540659441898538), ('recall_absolute_overall', 0.6571809693196976), ('recall_squared_overall', 0.7436638506002667), ('recall_ssim_overall', 0.6836371720764784), ('recall_psnr_overall', 0.7436638506002667), ('f1-score_absolute_overall', 0.6769682942746204), ('f1-score_squared_overall', 0.7480853062505393), ('f1-score_ssim_overall', 0.699535960954382), ('f1-score_psnr_overall', 0.7480853062505393), ('support_absolute_overall', 4498), ('support_squared_overall', 4498), ('support_ssim_overall', 4498), ('support_psnr_overall', 4498), ('conf_mat_absolute_overall', '2032,1266,276,924'), ('conf_mat_squared_overall', '2649,649,504,696'), ('conf_mat_ssim_overall', '2283,1015,408,792'), ('conf_mat_psnr_overall', '2649,649,504,696')])
# ========================================
# ----------------------------------------
# ----------------------------------------
# [INFO]: COMPLETED: HAM10000
# ----------------------------------------
# ----------------------------------------
# [INFO]: IR_DISTRACTION
# ----------------------------------------
# 3it [00:03,  1.17s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.7962222222222222), ('auc_roc_score_agg_psnr', 0.8561), ('auc_roc_score_agg_squared', 0.8527888888888888), ('auc_roc_score_agg_ssim', 0.7358555555555556), ('auc_roc_score_mean_absolute', 0.7948666666666666), ('auc_roc_score_mean_psnr', 0.8490666666666667), ('auc_roc_score_mean_squared', 0.8490666666666667), ('auc_roc_score_mean_ssim', 0.7411666666666666), ('auc_roc_score_overall_absolute', 0.7948666666666666), ('auc_roc_score_overall_psnr', 0.8490666666666666), ('auc_roc_score_overall_squared', 0.8490666666666666), ('auc_roc_score_overall_ssim', 0.7411666666666666), ('eer_agg_absolute', 0.3), ('eer_agg_psnr', 0.23666666666664898), ('eer_agg_squared', 0.24666666666646433), ('eer_agg_ssim', 0.36249999999999993), ('eer_overall_absolute', 0.2833333333336224), ('eer_overall_psnr', 0.2409090909090909), ('eer_overall_squared', 0.2409090909090909), ('eer_overall_ssim', 0.3733333333339954), ('pr_roc_score_agg_absolute', 0.7806105410162599), ('pr_roc_score_agg_psnr', 0.8423442227262191), ('pr_roc_score_agg_squared', 0.8458106603891247), ('pr_roc_score_agg_ssim', 0.7482136341230565), ('pr_roc_score_mean_absolute', 0.7986425263383122), ('pr_roc_score_mean_psnr', 0.8424533432296911), ('pr_roc_score_mean_squared', 0.8424533432296911), ('pr_roc_score_mean_ssim', 0.7729498252134045), ('pr_roc_score_overall_absolute', 0.7742876924413856), ('pr_roc_score_overall_psnr', 0.821583506626873), ('pr_roc_score_overall_squared', 0.821583506626873), ('pr_roc_score_overall_ssim', 0.7525622433838733), ('precision_absolute_agg', 0.7681252681252682), ('precision_squared_agg', 0.7791127752599916), ('precision_ssim_agg', 0.7188306587363932), ('precision_psnr_agg', 0.8098879179331306), ('recall_absolute_agg', 0.75), ('recall_squared_agg', 0.7716666666666666), ('recall_ssim_agg', 0.695), ('recall_psnr_agg', 0.79), ('f1-score_absolute_agg', 0.745702370053911), ('f1-score_squared_agg', 0.7701335853847465), ('f1-score_ssim_agg', 0.6864639819074297), ('f1-score_psnr_agg', 0.7865757260942229), ('support_absolute_agg', 600), ('support_squared_agg', 600), ('support_ssim_agg', 600), ('support_psnr_agg', 600), ('conf_mat_absolute_agg', '186,114,36,264'), ('conf_mat_squared_agg', '207,93,44,256'), ('conf_mat_ssim_agg', '159,141,42,258'), ('conf_mat_psnr_agg', '199,101,25,275'), ('precision_absolute_overall', 0.7714901026392963), ('precision_squared_overall', 0.8154285714285714), ('precision_ssim_overall', 0.732656251938802), ('precision_psnr_overall', 0.8154285714285714), ('recall_absolute_overall', 0.7633333333333333), ('recall_squared_overall', 0.8066666666666666), ('recall_ssim_overall', 0.7083333333333334), ('recall_psnr_overall', 0.8066666666666666), ('f1-score_absolute_overall', 0.7615422506829073), ('f1-score_squared_overall', 0.8053146853146853), ('f1-score_ssim_overall', 0.7005057174884695), ('f1-score_psnr_overall', 0.8053146853146853), ('support_absolute_overall', 600), ('support_squared_overall', 600), ('support_ssim_overall', 600), ('support_psnr_overall', 600), ('conf_mat_absolute_overall', '203,97,45,255'), ('conf_mat_squared_overall', '217,83,33,267'), ('conf_mat_ssim_overall', '164,136,39,261'), ('conf_mat_psnr_overall', '217,83,33,267')])
# ----------------------------------------
# [INFO]: Device set to GPU
# ----------------------------------------
#   4%|▍         | 136/3200 [00:00<00:02, 1354.07it/s]
# ----------------------------------------
# [INFO]: Created Dataset
# ----------------------------------------
# 100%|██████████| 3200/3200 [00:02<00:00, 1411.32it/s]
# 0it [00:00, ?it/s]
# ----------------------------------------
# [INFO]: Created Encodings
# ----------------------------------------
# INFO: SVDD C Initialized torch.Size([1, 1536])
# INFO: SVDD Initialized
# ----------------------------------------
# [INFO]: SVDD Ready
# ----------------------------------------
# ----------------------------------------
# [INFO]: Data Loaders Ready. Starting the training
# ----------------------------------------
# ========================================
# Testing: For epochs = 0 and model: ../../ATTN_PPR_MODELS/IR_DISTRACTION/C2D_AE_128_3X3-_ADAM_MSE_IR_DISTRACTION_NORMAL-{APE}/C2D_AE_128_3X3-_ADAM_MSE_IR_DISTRACTION_NORMAL-{APE}.pth.tar
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 3it [00:03,  1.15s/it]
#   0%|          | 0/17 [00:00<?, ?it/s]
# OrderedDict([('auc_roc_score_agg_absolute', 0.7962222222222222), ('auc_roc_score_agg_psnr', 0.8561), ('auc_roc_score_agg_squared', 0.8527888888888888), ('auc_roc_score_agg_ssim', 0.7358555555555556), ('auc_roc_score_mean_absolute', 0.7948666666666666), ('auc_roc_score_mean_psnr', 0.8490666666666667), ('auc_roc_score_mean_squared', 0.8490666666666667), ('auc_roc_score_mean_ssim', 0.7411666666666666), ('auc_roc_score_overall_absolute', 0.7948666666666666), ('auc_roc_score_overall_psnr', 0.8490666666666666), ('auc_roc_score_overall_squared', 0.8490666666666666), ('auc_roc_score_overall_ssim', 0.7411666666666666), ('eer_agg_absolute', 0.3), ('eer_agg_psnr', 0.23666666666664898), ('eer_agg_squared', 0.24666666666646433), ('eer_agg_ssim', 0.36249999999999993), ('eer_overall_absolute', 0.2833333333336224), ('eer_overall_psnr', 0.2409090909090909), ('eer_overall_squared', 0.2409090909090909), ('eer_overall_ssim', 0.3733333333339954), ('pr_roc_score_agg_absolute', 0.7806105410162599), ('pr_roc_score_agg_psnr', 0.8423442227262191), ('pr_roc_score_agg_squared', 0.8458106603891247), ('pr_roc_score_agg_ssim', 0.7482136341230565), ('pr_roc_score_mean_absolute', 0.7986425263383122), ('pr_roc_score_mean_psnr', 0.8424533432296911), ('pr_roc_score_mean_squared', 0.8424533432296911), ('pr_roc_score_mean_ssim', 0.7729498252134045), ('pr_roc_score_overall_absolute', 0.7742876924413856), ('pr_roc_score_overall_psnr', 0.821583506626873), ('pr_roc_score_overall_squared', 0.821583506626873), ('pr_roc_score_overall_ssim', 0.7525622433838733), ('precision_absolute_agg', 0.7681252681252682), ('precision_squared_agg', 0.7791127752599916), ('precision_ssim_agg', 0.7188306587363932), ('precision_psnr_agg', 0.8098879179331306), ('recall_absolute_agg', 0.75), ('recall_squared_agg', 0.7716666666666666), ('recall_ssim_agg', 0.695), ('recall_psnr_agg', 0.79), ('f1-score_absolute_agg', 0.745702370053911), ('f1-score_squared_agg', 0.7701335853847465), ('f1-score_ssim_agg', 0.6864639819074297), ('f1-score_psnr_agg', 0.7865757260942229), ('support_absolute_agg', 600), ('support_squared_agg', 600), ('support_ssim_agg', 600), ('support_psnr_agg', 600), ('conf_mat_absolute_agg', '186,114,36,264'), ('conf_mat_squared_agg', '207,93,44,256'), ('conf_mat_ssim_agg', '159,141,42,258'), ('conf_mat_psnr_agg', '199,101,25,275'), ('precision_absolute_overall', 0.7714901026392963), ('precision_squared_overall', 0.8154285714285714), ('precision_ssim_overall', 0.732656251938802), ('precision_psnr_overall', 0.8154285714285714), ('recall_absolute_overall', 0.7633333333333333), ('recall_squared_overall', 0.8066666666666666), ('recall_ssim_overall', 0.7083333333333334), ('recall_psnr_overall', 0.8066666666666666), ('f1-score_absolute_overall', 0.7615422506829073), ('f1-score_squared_overall', 0.8053146853146853), ('f1-score_ssim_overall', 0.7005057174884695), ('f1-score_psnr_overall', 0.8053146853146853), ('support_absolute_overall', 600), ('support_squared_overall', 600), ('support_ssim_overall', 600), ('support_psnr_overall', 600), ('conf_mat_absolute_overall', '203,97,45,255'), ('conf_mat_squared_overall', '217,83,33,267'), ('conf_mat_ssim_overall', '164,136,39,261'), ('conf_mat_psnr_overall', '217,83,33,267')])
# ========================================
# ----------------------------------------
# ----------------------------------------
# [INFO]: COMPLETED: IR_DISTRACTION
# ----------------------------------------
# ----------------------------------------
# [INFO]: MV_TEC
# ----------------------------------------
# 100%|██████████| 17/17 [00:48<00:00,  2.86s/it]
# 15it [00:10,  1.39it/s]
#   0%|          | 0/17 [00:00<?, ?it/s]
# OrderedDict([('auc_roc_score_agg_absolute', 0.6133524883997236), ('auc_roc_score_agg_psnr', 0.6527219372036099), ('auc_roc_score_agg_squared', 0.6418297627517933), ('auc_roc_score_agg_ssim', 0.5625206387896903), ('auc_roc_score_mean_absolute', 0.6395145156493324), ('auc_roc_score_mean_psnr', 0.699412651531654), ('auc_roc_score_mean_squared', 0.699412651531654), ('auc_roc_score_mean_ssim', 0.5863929737074862), ('auc_roc_score_overall_absolute', 0.5118930493662828), ('auc_roc_score_overall_psnr', 0.5313488321423829), ('auc_roc_score_overall_squared', 0.531348832142383), ('auc_roc_score_overall_ssim', 0.507955083184961), ('eer_agg_absolute', 0.4282655246249575), ('eer_agg_psnr', 0.40009124087591247), ('eer_agg_squared', 0.4125596184405878), ('eer_agg_ssim', 0.45824411134903614), ('eer_overall_absolute', 0.47853736089130317), ('eer_overall_psnr', 0.4785373608905759), ('eer_overall_squared', 0.47901459854014594), ('eer_overall_ssim', 0.4839400428265629), ('pr_roc_score_agg_absolute', 0.6462787587179011), ('pr_roc_score_agg_psnr', 0.6350322611008691), ('pr_roc_score_agg_squared', 0.6359407216725038), ('pr_roc_score_agg_ssim', 0.6851814722154704), ('pr_roc_score_mean_absolute', 0.7277564826693677), ('pr_roc_score_mean_psnr', 0.7305273638270415), ('pr_roc_score_mean_squared', 0.7305241211271697), ('pr_roc_score_mean_ssim', 0.762868589659466), ('pr_roc_score_overall_absolute', 0.7254993094387396), ('pr_roc_score_overall_psnr', 0.70763044485818), ('pr_roc_score_overall_squared', 0.7076302953121009), ('pr_roc_score_overall_ssim', 0.7309657054342973), ('precision_absolute_agg', 0.6913203259799992), ('precision_squared_agg', 0.6933058475285993), ('precision_ssim_agg', 0.6492716652645479), ('precision_psnr_agg', 0.7009905792280174), ('recall_absolute_agg', 0.6979710144927537), ('recall_squared_agg', 0.6991304347826087), ('recall_ssim_agg', 0.6330434782608696), ('recall_psnr_agg', 0.6939130434782609), ('f1-score_absolute_agg', 0.6943950339341602), ('f1-score_squared_agg', 0.6960240607805596), ('f1-score_ssim_agg', 0.6403046233862716), ('f1-score_psnr_agg', 0.6971920515458336), ('support_absolute_agg', 1725), ('support_squared_agg', 1725), ('support_ssim_agg', 1725), ('support_psnr_agg', 1725), ('conf_mat_absolute_agg', '1014,244,277,190'), ('conf_mat_squared_agg', '1013,245,274,193'), ('conf_mat_ssim_agg', '908,350,283,184'), ('conf_mat_psnr_agg', '977,281,247,220'), ('precision_absolute_overall', 0.630834912459581), ('precision_squared_overall', 0.6410725531002096), ('precision_ssim_overall', 0.6313118397585403), ('precision_psnr_overall', 0.6410725531002096), ('recall_absolute_overall', 0.6701449275362319), ('recall_squared_overall', 0.5101449275362319), ('recall_ssim_overall', 0.56), ('recall_psnr_overall', 0.5101449275362319), ('f1-score_absolute_overall', 0.6449076880057135), ('f1-score_squared_overall', 0.5353703504314435), ('f1-score_ssim_overall', 0.5829830964491941), ('f1-score_psnr_overall', 0.5353703504314435), ('support_absolute_overall', 1725), ('support_squared_overall', 1725), ('support_ssim_overall', 1725), ('support_psnr_overall', 1725), ('conf_mat_absolute_overall', '1056,202,367,100'), ('conf_mat_squared_overall', '593,665,180,287'), ('conf_mat_ssim_overall', '742,516,243,224'), ('conf_mat_psnr_overall', '593,665,180,287')])
# ----------------------------------------
# [INFO]: Device set to GPU
# ----------------------------------------
# 100%|██████████| 17/17 [01:42<00:00,  6.04s/it]
#   3%|▎         | 114/3629 [00:00<00:03, 1139.43it/s]
# ----------------------------------------
# [INFO]: Created Dataset
# ----------------------------------------
# 100%|██████████| 3629/3629 [00:02<00:00, 1396.64it/s]
# ----------------------------------------
# [INFO]: Created Encodings
# ----------------------------------------
# INFO: SVDD C Initialized torch.Size([1, 1536])
# INFO: SVDD Initialized
# ----------------------------------------
# [INFO]: SVDD Ready
# ----------------------------------------
# ----------------------------------------
# [INFO]: Data Loaders Ready. Starting the training
# ----------------------------------------
# ========================================
# Testing: For epochs = 1 and model: ../../ATTN_PPR_MODELS/MV-TEC/C2D_AE_128_3X3-_ADAM_MSE_MV_TEC_NORMAL-{APE}/C2D_AE_128_3X3-_ADAM_MSE_MV_TEC_NORMAL-{APE}.pth.tar
# 0it [00:00, ?it/s]
# Epoch [0/1] | Train Loss: 1157.236810 | Val Loss: 327.986990 | Time: (1) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 15it [00:10,  1.39it/s]
# OrderedDict([('auc_roc_score_agg_absolute', 0.6696482980019949), ('auc_roc_score_agg_psnr', 0.6696687240206575), ('auc_roc_score_agg_squared', 0.6643085962899542), ('auc_roc_score_agg_ssim', 0.5806180913247294), ('auc_roc_score_mean_absolute', 0.6837774313585165), ('auc_roc_score_mean_psnr', 0.7019288922305407), ('auc_roc_score_mean_squared', 0.7019288922305407), ('auc_roc_score_mean_ssim', 0.6061098668419729), ('auc_roc_score_overall_absolute', 0.5401303179990673), ('auc_roc_score_overall_psnr', 0.550651419778514), ('auc_roc_score_overall_squared', 0.5506514197785138), ('auc_roc_score_overall_ssim', 0.5277674702035453), ('eer_agg_absolute', 0.3878948531035725), ('eer_agg_psnr', 0.367536231884058), ('eer_agg_squared', 0.383942766296578), ('eer_agg_ssim', 0.44753747323340476), ('eer_overall_absolute', 0.4874012786761926), ('eer_overall_psnr', 0.45151033386384715), ('eer_overall_squared', 0.45151033386384715), ('eer_overall_ssim', 0.47840755735492585), ('pr_roc_score_agg_absolute', 0.6184072902131558), ('pr_roc_score_agg_psnr', 0.6249438674223566), ('pr_roc_score_agg_squared', 0.6232995138217279), ('pr_roc_score_agg_ssim', 0.6684265918734913), ('pr_roc_score_mean_absolute', 0.7580002864272107), ('pr_roc_score_mean_psnr', 0.7719069681497983), ('pr_roc_score_mean_squared', 0.7719056094910662), ('pr_roc_score_mean_ssim', 0.75991719230568), ('pr_roc_score_overall_absolute', 0.6906785117990313), ('pr_roc_score_overall_psnr', 0.6871501333432052), ('pr_roc_score_overall_squared', 0.6871495594633145), ('pr_roc_score_overall_ssim', 0.7127762701850406), ('precision_absolute_agg', 0.7167126906122444), ('precision_squared_agg', 0.712084388753399), ('precision_ssim_agg', 0.6604101385016466), ('precision_psnr_agg', 0.71371430950308), ('recall_absolute_agg', 0.7165217391304348), ('recall_squared_agg', 0.6944927536231884), ('recall_ssim_agg', 0.6376811594202898), ('recall_psnr_agg', 0.7095652173913043), ('f1-score_absolute_agg', 0.716616974276175), ('f1-score_squared_agg', 0.7017482946804905), ('f1-score_ssim_agg', 0.647297583308904), ('f1-score_psnr_agg', 0.711536208770831), ('support_absolute_agg', 1725), ('support_squared_agg', 1725), ('support_ssim_agg', 1725), ('support_psnr_agg', 1725), ('conf_mat_absolute_agg', '1013,245,244,223'), ('conf_mat_squared_agg', '953,305,222,245'), ('conf_mat_ssim_agg', '898,360,265,202'), ('conf_mat_psnr_agg', '997,261,240,227'), ('precision_absolute_overall', 0.6412495974235105), ('precision_squared_overall', 0.6563943013213257), ('precision_ssim_overall', 0.6492565524828254), ('precision_psnr_overall', 0.6563943013213257), ('recall_absolute_overall', 0.6307246376811594), ('recall_squared_overall', 0.5252173913043479), ('recall_ssim_overall', 0.6504347826086957), ('recall_psnr_overall', 0.5252173913043479), ('f1-score_absolute_overall', 0.635640522586602), ('f1-score_squared_overall', 0.5497354127577069), ('f1-score_ssim_overall', 0.6498407329849678), ('f1-score_psnr_overall', 0.5497354127577069), ('support_absolute_overall', 1725), ('support_squared_overall', 1725), ('support_ssim_overall', 1725), ('support_psnr_overall', 1725), ('conf_mat_absolute_overall', '918,340,297,170'), ('conf_mat_squared_overall', '607,651,168,299'), ('conf_mat_ssim_overall', '959,299,304,163'), ('conf_mat_psnr_overall', '607,651,168,299')])
# ========================================
# ----------------------------------------
# ----------------------------------------
# [INFO]: COMPLETED: MV_TEC
# ----------------------------------------
# ----------------------------------------
# [INFO]: SUBWAY_ENTRANCE
# ----------------------------------------
# 0it [00:00, ?it/s]
# Subway Entrance: Last few frames dropped
# 24344
# 21344
# 21344
# 1it [01:51, 111.41s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.7966039531284252), ('auc_roc_score_agg_psnr', 0.7388356173483284), ('auc_roc_score_agg_squared', 0.7428423863583523), ('auc_roc_score_agg_ssim', 0.7629251390005247), ('auc_roc_score_mean_absolute', 0.7966039531284252), ('auc_roc_score_mean_psnr', 0.7388356173483284), ('auc_roc_score_mean_squared', 0.7428423863583523), ('auc_roc_score_mean_ssim', 0.7629251390005247), ('auc_roc_score_overall_absolute', 0.7966039531284252), ('auc_roc_score_overall_psnr', 0.7388356173483284), ('auc_roc_score_overall_squared', 0.7428423863583523), ('auc_roc_score_overall_ssim', 0.7629251390005247), ('eer_agg_absolute', 0.29482758620815475), ('eer_agg_psnr', 0.3354941623676351), ('eer_agg_squared', 0.3337988826815642), ('eer_agg_ssim', 0.33620689655323216), ('eer_overall_absolute', 0.29482758620815475), ('eer_overall_psnr', 0.3354941623676351), ('eer_overall_squared', 0.3337988826815642), ('eer_overall_ssim', 0.33620689655323216), ('pr_roc_score_agg_absolute', 0.9929512123535654), ('pr_roc_score_agg_psnr', 0.9901487670729345), ('pr_roc_score_agg_squared', 0.9903350635484705), ('pr_roc_score_agg_ssim', 0.9910076053740628), ('pr_roc_score_mean_absolute', 0.9929512123535654), ('pr_roc_score_mean_psnr', 0.9901487670729345), ('pr_roc_score_mean_squared', 0.9903350635484705), ('pr_roc_score_mean_ssim', 0.9910076053740628), ('pr_roc_score_overall_absolute', 0.9929512123535654), ('pr_roc_score_overall_psnr', 0.9901487670729345), ('pr_roc_score_overall_squared', 0.9903350635484705), ('pr_roc_score_overall_ssim', 0.9910076053740628), ('precision_absolute_agg', 0.9663788982534212), ('precision_squared_agg', 0.9637697929420067), ('precision_ssim_agg', 0.9608212371273795), ('precision_psnr_agg', 0.9634228167399034), ('recall_absolute_agg', 0.6362443778110944), ('recall_squared_agg', 0.6115067466266867), ('recall_ssim_agg', 0.845483508245877), ('recall_psnr_agg', 0.6133808095952024), ('f1-score_absolute_agg', 0.7535009699472283), ('f1-score_squared_agg', 0.7347249477058166), ('f1-score_ssim_agg', 0.8943793942149343), ('f1-score_psnr_agg', 0.7362277014718539), ('support_absolute_agg', 21344), ('support_squared_agg', 21344), ('support_ssim_agg', 21344), ('support_psnr_agg', 21344), ('conf_mat_absolute_agg', '471,109,7655,13109'), ('conf_mat_squared_agg', '443,137,8155,12609'), ('conf_mat_ssim_agg', '311,269,3029,17735'), ('conf_mat_psnr_agg', '438,142,8110,12654'), ('precision_absolute_overall', 0.9663788982534212), ('precision_squared_overall', 0.9637697929420067), ('precision_ssim_overall', 0.9608212371273795), ('precision_psnr_overall', 0.9634228167399034), ('recall_absolute_overall', 0.6362443778110944), ('recall_squared_overall', 0.6115067466266867), ('recall_ssim_overall', 0.845483508245877), ('recall_psnr_overall', 0.6133808095952024), ('f1-score_absolute_overall', 0.7535009699472283), ('f1-score_squared_overall', 0.7347249477058166), ('f1-score_ssim_overall', 0.8943793942149343), ('f1-score_psnr_overall', 0.7362277014718539), ('support_absolute_overall', 21344), ('support_squared_overall', 21344), ('support_ssim_overall', 21344), ('support_psnr_overall', 21344), ('conf_mat_absolute_overall', '471,109,7655,13109'), ('conf_mat_squared_overall', '443,137,8155,12609'), ('conf_mat_ssim_overall', '311,269,3029,17735'), ('conf_mat_psnr_overall', '438,142,8110,12654')])
# ----------------------------------------
# [INFO]: Device set to GPU
# ----------------------------------------
#   2%|▏         | 117/7509 [00:00<00:06, 1164.50it/s]
# ----------------------------------------
# [INFO]: Created Dataset
# ----------------------------------------
# 100%|██████████| 7509/7509 [00:05<00:00, 1452.05it/s]
# ----------------------------------------
# [INFO]: Created Encodings
# ----------------------------------------
# INFO: SVDD C Initialized torch.Size([1, 1536])
# INFO: SVDD Initialized
# ----------------------------------------
# [INFO]: SVDD Ready
# ----------------------------------------
# ----------------------------------------
# [INFO]: Data Loaders Ready. Starting the training
# ----------------------------------------
# ========================================
# Testing: For epochs = 2 and model: ../../ATTN_PPR_MODELS/SUBWAY_ENTRANCE/C2D_AE_128_3X3-_ADAM_MSE_SUBWAY_ENTRANCE_NORMAL-{APE}/C2D_AE_128_3X3-_ADAM_MSE_SUBWAY_ENTRANCE_NORMAL-{APE}.pth.tar
# Epoch [0/2] | Train Loss: 0.511673 | Val Loss: 0.134887 | Time: (2) s
# 0it [00:00, ?it/s]
# Epoch [1/2] | Train Loss: 0.089826 | Val Loss: 0.072085 | Time: (2) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 1it [01:51, 111.36s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.7827190960482001), ('auc_roc_score_agg_psnr', 0.786101649738606), ('auc_roc_score_agg_squared', 0.7897309833332227), ('auc_roc_score_agg_ssim', 0.7699142747062224), ('auc_roc_score_mean_absolute', 0.7827190960482001), ('auc_roc_score_mean_psnr', 0.786101649738606), ('auc_roc_score_mean_squared', 0.7897309833332227), ('auc_roc_score_mean_ssim', 0.7699142747062224), ('auc_roc_score_overall_absolute', 0.7827190960482001), ('auc_roc_score_overall_psnr', 0.786101649738606), ('auc_roc_score_overall_squared', 0.7897309833332227), ('auc_roc_score_overall_ssim', 0.7699142747062224), ('eer_agg_absolute', 0.27889616644186965), ('eer_agg_psnr', 0.2637931034478647), ('eer_agg_squared', 0.2592949335388266), ('eer_agg_ssim', 0.30517241379317517), ('eer_overall_absolute', 0.27889616644186965), ('eer_overall_psnr', 0.2637931034478647), ('eer_overall_squared', 0.2592949335388266), ('eer_overall_ssim', 0.30517241379317517), ('pr_roc_score_agg_absolute', 0.9927134431192193), ('pr_roc_score_agg_psnr', 0.9928721946915887), ('pr_roc_score_agg_squared', 0.9930339625193517), ('pr_roc_score_agg_ssim', 0.9917809678989257), ('pr_roc_score_mean_absolute', 0.9927134431192193), ('pr_roc_score_mean_psnr', 0.9928721946915887), ('pr_roc_score_mean_squared', 0.9930339625193517), ('pr_roc_score_mean_ssim', 0.9917809678989257), ('pr_roc_score_overall_absolute', 0.9927134431192193), ('pr_roc_score_overall_psnr', 0.9928721946915887), ('pr_roc_score_overall_squared', 0.9930339625193517), ('pr_roc_score_overall_ssim', 0.9917809678989257), ('precision_absolute_agg', 0.9707029993683675), ('precision_squared_agg', 0.9665570560155728), ('precision_ssim_agg', 0.9659354945898612), ('precision_psnr_agg', 0.9667353497419338), ('recall_absolute_agg', 0.5383714392803599), ('recall_squared_agg', 0.7232008995502248), ('recall_ssim_agg', 0.5837706146926537), ('recall_psnr_agg', 0.6909670164917541), ('f1-score_absolute_agg', 0.6736601476885915), ('f1-score_squared_agg', 0.8162288734033217), ('f1-score_ssim_agg', 0.7123687173411031), ('f1-score_psnr_agg', 0.7937007537686258), ('support_absolute_agg', 21344), ('support_squared_agg', 21344), ('support_ssim_agg', 21344), ('support_psnr_agg', 21344), ('conf_mat_absolute_agg', '540,40,9813,10951'), ('conf_mat_squared_agg', '452,128,5780,14984'), ('conf_mat_ssim_agg', '477,103,8781,11983'), ('conf_mat_psnr_agg', '463,117,6479,14285'), ('precision_absolute_overall', 0.9707029993683675), ('precision_squared_overall', 0.9665570560155728), ('precision_ssim_overall', 0.9659354945898612), ('precision_psnr_overall', 0.9667353497419338), ('recall_absolute_overall', 0.5383714392803599), ('recall_squared_overall', 0.7232008995502248), ('recall_ssim_overall', 0.5837706146926537), ('recall_psnr_overall', 0.6909670164917541), ('f1-score_absolute_overall', 0.6736601476885915), ('f1-score_squared_overall', 0.8162288734033217), ('f1-score_ssim_overall', 0.7123687173411031), ('f1-score_psnr_overall', 0.7937007537686258), ('support_absolute_overall', 21344), ('support_squared_overall', 21344), ('support_ssim_overall', 21344), ('support_psnr_overall', 21344), ('conf_mat_absolute_overall', '540,40,9813,10951'), ('conf_mat_squared_overall', '452,128,5780,14984'), ('conf_mat_ssim_overall', '477,103,8781,11983'), ('conf_mat_psnr_overall', '463,117,6479,14285')])
# ========================================
# ----------------------------------------
# ----------------------------------------
# [INFO]: COMPLETED: SUBWAY_ENTRANCE
# ----------------------------------------
# ----------------------------------------
# [INFO]: SUBWAY_EXIT
# ----------------------------------------
# 0it [00:00, ?it/s]
# 11475
# 1it [00:58, 58.79s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.971887900459329), ('auc_roc_score_agg_psnr', 0.9566060042250517), ('auc_roc_score_agg_squared', 0.9567707424850282), ('auc_roc_score_agg_ssim', 0.9717328526852336), ('auc_roc_score_mean_absolute', 0.971887900459329), ('auc_roc_score_mean_psnr', 0.9566060042250517), ('auc_roc_score_mean_squared', 0.9567707424850282), ('auc_roc_score_mean_ssim', 0.9717328526852336), ('auc_roc_score_overall_absolute', 0.971887900459329), ('auc_roc_score_overall_psnr', 0.9566060042250517), ('auc_roc_score_overall_squared', 0.9567707424850282), ('auc_roc_score_overall_ssim', 0.9717328526852336), ('eer_agg_absolute', 0.11111111111038387), ('eer_agg_psnr', 0.11111111111148114), ('eer_agg_squared', 0.11111111111116716), ('eer_agg_ssim', 0.10997732426303854), ('eer_overall_absolute', 0.11111111111038387), ('eer_overall_psnr', 0.11111111111148114), ('eer_overall_squared', 0.11111111111116716), ('eer_overall_ssim', 0.10997732426303854), ('pr_roc_score_agg_absolute', 0.9999770950334977), ('pr_roc_score_agg_psnr', 0.9999633920863479), ('pr_roc_score_agg_squared', 0.9999634878554304), ('pr_roc_score_agg_ssim', 0.9999770231400712), ('pr_roc_score_mean_absolute', 0.9999770950334977), ('pr_roc_score_mean_psnr', 0.9999633920863479), ('pr_roc_score_mean_squared', 0.9999634878554304), ('pr_roc_score_mean_ssim', 0.9999770231400712), ('pr_roc_score_overall_absolute', 0.9999770950334977), ('pr_roc_score_overall_psnr', 0.9999633920863479), ('pr_roc_score_overall_squared', 0.9999634878554304), ('pr_roc_score_overall_ssim', 0.9999770231400712), ('precision_absolute_agg', 0.9992209976541406), ('precision_squared_agg', 0.9991296865267637), ('precision_ssim_agg', 0.9992212444032732), ('precision_psnr_agg', 0.9991294506537134), ('recall_absolute_agg', 0.8849673202614379), ('recall_squared_agg', 0.929760348583878), ('recall_ssim_agg', 0.8901089324618736), ('recall_psnr_agg', 0.9286274509803921), ('f1-score_absolute_agg', 0.9381969619054998), ('f1-score_squared_agg', 0.9628350812856558), ('f1-score_ssim_agg', 0.9410839999134424), ('f1-score_psnr_agg', 0.9622260735275601), ('support_absolute_agg', 11475), ('support_squared_agg', 11475), ('support_ssim_agg', 11475), ('support_psnr_agg', 11475), ('conf_mat_absolute_agg', '9,0,1320,10146'), ('conf_mat_squared_agg', '8,1,805,10661'), ('conf_mat_ssim_agg', '9,0,1261,10205'), ('conf_mat_psnr_agg', '8,1,818,10648'), ('precision_absolute_overall', 0.9992209976541406), ('precision_squared_overall', 0.9991296865267637), ('precision_ssim_overall', 0.9992212444032732), ('precision_psnr_overall', 0.9991294506537134), ('recall_absolute_overall', 0.8849673202614379), ('recall_squared_overall', 0.929760348583878), ('recall_ssim_overall', 0.8901089324618736), ('recall_psnr_overall', 0.9286274509803921), ('f1-score_absolute_overall', 0.9381969619054998), ('f1-score_squared_overall', 0.9628350812856558), ('f1-score_ssim_overall', 0.9410839999134424), ('f1-score_psnr_overall', 0.9622260735275601), ('support_absolute_overall', 11475), ('support_squared_overall', 11475), ('support_ssim_overall', 11475), ('support_psnr_overall', 11475), ('conf_mat_absolute_overall', '9,0,1320,10146'), ('conf_mat_squared_overall', '8,1,805,10661'), ('conf_mat_ssim_overall', '9,0,1261,10205'), ('conf_mat_psnr_overall', '8,1,818,10648')])
# ----------------------------------------
# [INFO]: Device set to GPU
# ----------------------------------------
#   6%|▌         | 139/2509 [00:00<00:01, 1388.53it/s]
# ----------------------------------------
# [INFO]: Created Dataset
# ----------------------------------------
# 100%|██████████| 2509/2509 [00:01<00:00, 1446.66it/s]
# ----------------------------------------
# [INFO]: Created Encodings
# ----------------------------------------
# INFO: SVDD C Initialized torch.Size([1, 1536])
# INFO: SVDD Initialized
# ----------------------------------------
# [INFO]: SVDD Ready
# ----------------------------------------
# ----------------------------------------
# [INFO]: Data Loaders Ready. Starting the training
# ----------------------------------------
# ========================================
# Testing: For epochs = 1 and model: ../../ATTN_PPR_MODELS/SUBWAY_EXIT/C2D_AE_128_3X3-_ADAM_MSE_SUBWAY_EXIT_NORMAL-{APE}/C2D_AE_128_3X3-_ADAM_MSE_SUBWAY_EXIT_NORMAL-{APE}.pth.tar
# 0it [00:00, ?it/s]
# Epoch [0/1] | Train Loss: 36.243558 | Val Loss: 38.577898 | Time: (1) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 1it [00:57, 57.61s/it]
# 0it [00:00, ?it/s]
# ...
# ----------------------------------------
# [INFO]: Device set to GPU
# ----------------------------------------
# 34it [00:07,  4.46it/s]
#   2%|▏         | 138/6800 [00:00<00:04, 1372.87it/s]
# ----------------------------------------
# [INFO]: Created Dataset
# ----------------------------------------
# 100%|██████████| 6800/6800 [00:04<00:00, 1447.38it/s]
# ----------------------------------------
# [INFO]: Created Encodings
# ----------------------------------------
# INFO: SVDD C Initialized torch.Size([1, 1536])
# INFO: SVDD Initialized
# ----------------------------------------
# [INFO]: SVDD Ready
# ----------------------------------------
# ----------------------------------------
# [INFO]: Data Loaders Ready. Starting the training
# ----------------------------------------
# ========================================
# Testing: For epochs = 20 and model: ../../ATTN_PPR_MODELS/UCSD1/C2D_AE_128_3X3-_ADAM_MSE_UCSD1_NORMAL-{APE}/C2D_AE_128_3X3-_ADAM_MSE_UCSD1_NORMAL-{APE}.pth.tar
# Epoch [0/20] | Train Loss: 1.880154 | Val Loss: 0.771534 | Time: (2) s
# Epoch [1/20] | Train Loss: 0.632854 | Val Loss: 0.539246 | Time: (2) s
# Epoch [2/20] | Train Loss: 0.463611 | Val Loss: 0.409006 | Time: (2) s
# Epoch [3/20] | Train Loss: 0.348175 | Val Loss: 0.306535 | Time: (2) s
# Epoch [4/20] | Train Loss: 0.258225 | Val Loss: 0.237104 | Time: (2) s
# Epoch [5/20] | Train Loss: 0.186303 | Val Loss: 0.163767 | Time: (2) s
# Epoch [6/20] | Train Loss: 0.139141 | Val Loss: 0.124071 | Time: (2) s
# Epoch [7/20] | Train Loss: 0.106467 | Val Loss: 0.094375 | Time: (2) s
# Epoch [8/20] | Train Loss: 0.082388 | Val Loss: 0.073336 | Time: (2) s
# Epoch [9/20] | Train Loss: 0.064854 | Val Loss: 0.059776 | Time: (2) s
# Epoch [10/20] | Train Loss: 0.053920 | Val Loss: 0.049879 | Time: (2) s
# Epoch [11/20] | Train Loss: 0.045289 | Val Loss: 0.048953 | Time: (2) s
# Epoch [12/20] | Train Loss: 0.038177 | Val Loss: 0.036061 | Time: (2) s
# Epoch [13/20] | Train Loss: 0.032205 | Val Loss: 0.032202 | Time: (2) s
# Epoch [14/20] | Train Loss: 0.028715 | Val Loss: 0.030691 | Time: (2) s
# Epoch [15/20] | Train Loss: 0.025662 | Val Loss: 0.028346 | Time: (2) s
# Epoch [16/20] | Train Loss: 0.023220 | Val Loss: 0.023144 | Time: (2) s
# Epoch [17/20] | Train Loss: 0.021341 | Val Loss: 0.020195 | Time: (2) s
# Epoch [18/20] | Train Loss: 0.019062 | Val Loss: 0.021159 | Time: (2) s
# 0it [00:00, ?it/s]
# Epoch [19/20] | Train Loss: 0.017550 | Val Loss: 0.017751 | Time: (2) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 36it [00:41,  1.16s/it]
# 0it [00:00, ?it/s]
# OrderedDict([('auc_roc_score_agg_absolute', 0.7119283653196312), ('auc_roc_score_agg_psnr', 0.7240012615602208), ('auc_roc_score_agg_squared', 0.7339581060141553), ('auc_roc_score_agg_ssim', 0.6732727497115454), ('auc_roc_score_mean_absolute', 0.7083450084619735), ('auc_roc_score_mean_psnr', 0.7212377698285659), ('auc_roc_score_mean_squared', 0.7213312158057342), ('auc_roc_score_mean_ssim', 0.6838594270463143), ('auc_roc_score_overall_absolute', 0.640121532913205), ('auc_roc_score_overall_psnr', 0.6583033582184575), ('auc_roc_score_overall_squared', 0.6577796148323437), ('auc_roc_score_overall_ssim', 0.6400305595333011), ('eer_agg_absolute', 0.33058637083993686), ('eer_agg_psnr', 0.33448702101394945), ('eer_agg_squared', 0.32801173266289546), ('eer_agg_ssim', 0.37250252270432693), ('eer_overall_absolute', 0.386053882725832), ('eer_overall_psnr', 0.4004540867810292), ('eer_overall_squared', 0.40221870047543584), ('eer_overall_ssim', 0.3882725832012682), ('pr_roc_score_agg_absolute', 0.6488014538091349), ('pr_roc_score_agg_psnr', 0.6484714693116697), ('pr_roc_score_agg_squared', 0.6672595454945763), ('pr_roc_score_agg_ssim', 0.6121314740570043), ('pr_roc_score_mean_absolute', nan), ('pr_roc_score_mean_psnr', nan), ('pr_roc_score_mean_squared', nan), ('pr_roc_score_mean_ssim', nan), ('pr_roc_score_overall_absolute', 0.6007166780120979), ('pr_roc_score_overall_psnr', 0.6227209707501871), ('pr_roc_score_overall_squared', 0.6224081113820624), ('pr_roc_score_overall_ssim', 0.6081256945045801), ('precision_absolute_agg', 0.6993402771732459), ('precision_squared_agg', 0.6862381990608664), ('precision_ssim_agg', 0.6340707204288305), ('precision_psnr_agg', 0.689248259875244), ('recall_absolute_agg', 0.7008333333333333), ('recall_squared_agg', 0.6705555555555556), ('recall_ssim_agg', 0.6306944444444444), ('recall_psnr_agg', 0.68875), ('f1-score_absolute_agg', 0.696985706059239), ('f1-score_squared_agg', 0.6712612695196283), ('f1-score_ssim_agg', 0.6317695365812149), ('f1-score_psnr_agg', 0.6805968425288518), ('support_absolute_agg', 7200), ('support_squared_agg', 7200), ('support_ssim_agg', 7200), ('support_psnr_agg', 7200), ('conf_mat_absolute_agg', '3204,841,1313,1842'), ('conf_mat_squared_agg', '2489,1556,816,2339'), ('conf_mat_ssim_agg', '2603,1442,1217,1938'), ('conf_mat_psnr_agg', '3311,734,1507,1648'), ('precision_absolute_overall', 0.6401047889436879), ('precision_squared_overall', 0.6418584525886839), ('precision_ssim_overall', 0.6254549634787562), ('precision_psnr_overall', 0.6428974122908083), ('recall_absolute_overall', 0.6415277777777778), ('recall_squared_overall', 0.6454166666666666), ('recall_ssim_overall', 0.6229166666666667), ('recall_psnr_overall', 0.6463888888888889), ('f1-score_absolute_overall', 0.6406164646037529), ('f1-score_squared_overall', 0.6388896176823937), ('f1-score_ssim_overall', 0.6238279762340703), ('f1-score_psnr_overall', 0.6397090787556517), ('support_absolute_overall', 7200), ('support_squared_overall', 7200), ('support_ssim_overall', 7200), ('support_psnr_overall', 7200), ('conf_mat_absolute_overall', '2818,1227,1354,1801'), ('conf_mat_squared_overall', '3073,972,1581,1574'), ('conf_mat_ssim_overall', '2601,1444,1271,1884'), ('conf_mat_psnr_overall', '3082,963,1583,1572')])
# ========================================
# ----------------------------------------
# ----------------------------------------
# [INFO]: COMPLETED: UCSD1
# ----------------------------------------
# ----------------------------------------
# [INFO]: UCSD2
# ----------------------------------------
# 12it [00:02,  4.11it/s]
# 12it [00:12,  1.00s/it]
# 1it [00:00,  5.75it/s]
# OrderedDict([('auc_roc_score_agg_absolute', 0.8739138014268089), ('auc_roc_score_agg_psnr', 0.8453256584240735), ('auc_roc_score_agg_squared', 0.8384966877648448), ('auc_roc_score_agg_ssim', 0.8261847610363139), ('auc_roc_score_mean_absolute', 0.924842366596246), ('auc_roc_score_mean_psnr', 0.8266458877419519), ('auc_roc_score_mean_squared', 0.8259738667521), ('auc_roc_score_mean_ssim', 0.8718140138456316), ('auc_roc_score_overall_absolute', 0.6949558815641259), ('auc_roc_score_overall_psnr', 0.7255420935471759), ('auc_roc_score_overall_squared', 0.723803840583597), ('auc_roc_score_overall_ssim', 0.7107241994314221), ('eer_agg_absolute', 0.19889502762430938), ('eer_agg_psnr', 0.25138121546961234), ('eer_agg_squared', 0.2651933701657435), ('eer_agg_ssim', 0.2659107534747623), ('eer_overall_absolute', 0.4538703870387114), ('eer_overall_psnr', 0.3816747572816059), ('eer_overall_squared', 0.3828883495133143), ('eer_overall_ssim', 0.4203730272596844), ('pr_roc_score_agg_absolute', 0.6584254432055067), ('pr_roc_score_agg_psnr', 0.667830842517112), ('pr_roc_score_agg_squared', 0.6692428085980349), ('pr_roc_score_agg_ssim', 0.6834748445835506), ('pr_roc_score_mean_absolute', nan), ('pr_roc_score_mean_psnr', nan), ('pr_roc_score_mean_squared', nan), ('pr_roc_score_mean_ssim', nan), ('pr_roc_score_overall_absolute', 0.7183511645526307), ('pr_roc_score_overall_psnr', 0.7125539516186234), ('pr_roc_score_overall_squared', 0.7137865053339056), ('pr_roc_score_overall_ssim', 0.7164289475244529), ('precision_absolute_agg', 0.8714525202845514), ('precision_squared_agg', 0.8495129094078011), ('precision_ssim_agg', 0.8726846311809296), ('precision_psnr_agg', 0.8417039994429099), ('recall_absolute_agg', 0.7825870646766169), ('recall_squared_agg', 0.6691542288557214), ('recall_ssim_agg', 0.6985074626865672), ('recall_psnr_agg', 0.7432835820895523), ('f1-score_absolute_agg', 0.8049612475456289), ('f1-score_squared_agg', 0.7073947750139962), ('f1-score_ssim_agg', 0.7333896987556184), ('f1-score_psnr_agg', 0.7702326811749025), ('support_absolute_agg', 2010), ('support_squared_agg', 2010), ('support_ssim_agg', 2010), ('support_psnr_agg', 2010), ('conf_mat_absolute_agg', '1257,391,46,316'), ('conf_mat_squared_agg', '1024,624,41,321'), ('conf_mat_ssim_agg', '1060,588,18,344'), ('conf_mat_psnr_agg', '1209,439,77,285'), ('precision_absolute_overall', 0.8088309354135546), ('precision_squared_overall', 0.8138954907759287), ('precision_ssim_overall', 0.7947383171548664), ('precision_psnr_overall', 0.8153380400348684), ('recall_absolute_overall', 0.7940298507462686), ('recall_squared_overall', 0.5582089552238806), ('recall_ssim_overall', 0.7621890547263681), ('recall_psnr_overall', 0.5522388059701493), ('f1-score_absolute_overall', 0.8005293281213168), ('f1-score_squared_overall', 0.6046365712055164), ('f1-score_ssim_overall', 0.7754070089767101), ('f1-score_psnr_overall', 0.5984820484151392), ('support_absolute_overall', 2010), ('support_squared_overall', 2010), ('support_ssim_overall', 2010), ('support_psnr_overall', 2010), ('conf_mat_absolute_overall', '1408,240,174,188'), ('conf_mat_squared_overall', '818,830,58,304'), ('conf_mat_ssim_overall', '1344,304,174,188'), ('conf_mat_psnr_overall', '803,845,55,307')])
# ----------------------------------------
# [INFO]: Device set to GPU
# ----------------------------------------
# 16it [00:03,  4.31it/s]
#   6%|▌         | 147/2550 [00:00<00:01, 1466.18it/s]
# ----------------------------------------
# [INFO]: Created Dataset
# ----------------------------------------
# 100%|██████████| 2550/2550 [00:01<00:00, 1465.36it/s]
# ----------------------------------------
# [INFO]: Created Encodings
# ----------------------------------------
# INFO: SVDD C Initialized torch.Size([1, 1536])
# INFO: SVDD Initialized
# ----------------------------------------
# [INFO]: SVDD Ready
# ----------------------------------------
# ----------------------------------------
# [INFO]: Data Loaders Ready. Starting the training
# ----------------------------------------
# ========================================
# Testing: For epochs = 5 and model: ../../ATTN_PPR_MODELS/UCSD2/C2D_AE_128_3X3-_ADAM_MSE_UCSD2_NORMAL-{APE}/C2D_AE_128_3X3-_ADAM_MSE_UCSD2_NORMAL-{APE}.pth.tar
# Epoch [0/5] | Train Loss: 34.277548 | Val Loss: 171.529577 | Time: (1) s
# Epoch [1/5] | Train Loss: 3.823765 | Val Loss: 4.085698 | Time: (1) s
# Epoch [2/5] | Train Loss: 3.127064 | Val Loss: 2.872994 | Time: (1) s
# Epoch [3/5] | Train Loss: 2.674391 | Val Loss: 2.471445 | Time: (1) s
# 0it [00:00, ?it/s]
# Epoch [4/5] | Train Loss: 2.408207 | Val Loss: 2.206981 | Time: (1) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 12it [00:11,  1.02it/s]
# OrderedDict([('auc_roc_score_agg_absolute', 0.9279756476961861), ('auc_roc_score_agg_psnr', 0.8792341629566056), ('auc_roc_score_agg_squared', 0.8781077348066298), ('auc_roc_score_agg_ssim', 0.8212164083033847), ('auc_roc_score_mean_absolute', 0.9489050013514028), ('auc_roc_score_mean_psnr', 0.8706765685428306), ('auc_roc_score_mean_squared', 0.87067747384112), ('auc_roc_score_mean_ssim', 0.8361394159953726), ('auc_roc_score_overall_absolute', 0.665080392104275), ('auc_roc_score_overall_psnr', 0.6702917985302794), ('auc_roc_score_overall_squared', 0.6679819503298825), ('auc_roc_score_overall_ssim', 0.6341254090006974), ('eer_agg_absolute', 0.140883977900551), ('eer_agg_psnr', 0.22026699029019875), ('eer_agg_squared', 0.22099447513819181), ('eer_agg_ssim', 0.2396844660181769), ('eer_overall_absolute', 0.47237569060737294), ('eer_overall_psnr', 0.45580110497237564), ('eer_overall_squared', 0.45710959885386826), ('eer_overall_ssim', 0.46132596685082694), ('pr_roc_score_agg_absolute', 0.6715198836758149), ('pr_roc_score_agg_psnr', 0.6607522435536655), ('pr_roc_score_agg_squared', 0.659359084490317), ('pr_roc_score_agg_ssim', 0.6820585649941918), ('pr_roc_score_mean_absolute', nan), ('pr_roc_score_mean_psnr', nan), ('pr_roc_score_mean_squared', nan), ('pr_roc_score_mean_ssim', nan), ('pr_roc_score_overall_absolute', 0.7150127397680408), ('pr_roc_score_overall_psnr', 0.7128852888995263), ('pr_roc_score_overall_squared', 0.713743267139962), ('pr_roc_score_overall_ssim', 0.7344021778807845), ('precision_absolute_agg', 0.8986381248830471), ('precision_squared_agg', 0.8632289566094715), ('precision_ssim_agg', 0.8425807095907324), ('precision_psnr_agg', 0.8661587192537503), ('recall_absolute_agg', 0.8149253731343283), ('recall_squared_agg', 0.7532338308457711), ('recall_ssim_agg', 0.7721393034825871), ('recall_psnr_agg', 0.7338308457711443), ('f1-score_absolute_agg', 0.8338518979370345), ('f1-score_squared_agg', 0.7801446563302364), ('f1-score_ssim_agg', 0.7932541433260596), ('f1-score_psnr_agg', 0.7639915346939853), ('support_absolute_agg', 2010), ('support_squared_agg', 2010), ('support_ssim_agg', 2010), ('support_psnr_agg', 2010), ('conf_mat_absolute_agg', '1292,356,16,346'), ('conf_mat_squared_agg', '1199,449,47,315'), ('conf_mat_ssim_agg', '1280,368,90,272'), ('conf_mat_psnr_agg', '1149,499,36,326'), ('precision_absolute_overall', 0.855201603920695), ('precision_squared_overall', 0.8415231126560012), ('precision_ssim_overall', 0.8016856422388213), ('precision_psnr_overall', 0.8420309081637117), ('recall_absolute_overall', 0.8656716417910447), ('recall_squared_overall', 0.8507462686567164), ('recall_ssim_overall', 0.7786069651741293), ('recall_psnr_overall', 0.8507462686567164), ('f1-score_absolute_overall', 0.857512689397513), ('f1-score_squared_overall', 0.8449311882147703), ('f1-score_ssim_overall', 0.7883290665485206), ('f1-score_psnr_overall', 0.8453370881280089), ('support_absolute_overall', 2010), ('support_squared_overall', 2010), ('support_ssim_overall', 2010), ('support_psnr_overall', 2010), ('conf_mat_absolute_overall', '1560,88,182,180'), ('conf_mat_squared_overall', '1530,118,182,180'), ('conf_mat_ssim_overall', '1377,271,174,188'), ('conf_mat_psnr_overall', '1528,120,180,182')])
# ========================================
# ----------------------------------------
# ----------------------------------------
# [INFO]: COMPLETED: UCSD2
# ----------------------------------------

# %% [markdown]
# # SVDD Basline Fine Tuning

# %%
warnings.catch_warnings():
    warnings.simplefilter("ignore")
    
    for lr in [1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4]:
        INFO("SVDD Fine Tuning Learning Rate: %s"%lr)
        SVDD_RESULTS = dict()
        for DATA_MODELS_PATH in read_directory_contents(MODELS_PATH):
            DATASET = ModelParser.getDatasetType(DATA_MODELS_PATH)
            INFO(DATASET)
            SVDD_RESULTS[DATASET] = dict()
            for MODEL_DIR in read_directory_contents(DATA_MODELS_PATH):
                MODEL_PATH = join_paths([MODEL_DIR, MODEL_DIR.split("/")[-1] + ".pth.tar"])
                MODEL = get_model_att_ppr(MODEL_PATH, channels = dataset_channels[DATASET], att_channels = get_att_channels(MODEL_PATH))
                load_model(MODEL, MODEL_PATH)
                MODEL_NAME = MODEL.__name__

                if replace_model_name(MODEL_NAME) != replace_model_name("Baseline CAE"): continue

                svdd_ft = SVDD_FineTuner(
                    model = MODEL,
                    model_path = MODEL_PATH,
                    dataset_type = DATASET.lower(),
                    lr = lr,
                    testOriginal = True,
                    returnResults = True,
                )
                SVDD_RESULTS[DATASET][MODEL_NAME] = svdd_ft.results
                del MODEL, svdd_ft
            print("-"*40)
            INFO("COMPLETED: " + DATASET)
        dump_pickle(SVDD_RESULTS, join_paths([SAVE_PATH, "SVDD_results_LR_%s.pkl"%(lr)]))
        del SVDD_RESULTS
# Out:
# 0it [00:00, ?it/s]
# ----------------------------------------
# [INFO]: SVDD Fine Tuning Learning Rate: 1e-07
# ----------------------------------------
# ----------------------------------------
# [INFO]: AVENUE
# ----------------------------------------
# 21it [01:27,  4.18s/it]
# 21it [01:56,  5.53s/it]
# 0it [00:00, ?it/s]
# OrderedDict([('auc_roc_score_agg_absolute', 0.7109144442365489), ('auc_roc_score_agg_psnr', 0.7426772343502195), ('auc_roc_score_agg_squared', 0.8160297778419683), ('auc_roc_score_agg_ssim', 0.6590777026384347), ('auc_roc_score_mean_absolute', 0.8394928932513591), ('auc_roc_score_mean_psnr', 0.8356548987769931), ('auc_roc_score_mean_squared', 0.8357024550849584), ('auc_roc_score_mean_ssim', 0.8503179338827378), ('auc_roc_score_overall_absolute', 0.9443005043703278), ('auc_roc_score_overall_psnr', 0.9676234614973724), ('auc_roc_score_overall_squared', 0.9679805505266806), ('auc_roc_score_overall_ssim', 0.9228758191842975), ('eer_agg_absolute', 0.34276317548630636), ('eer_agg_psnr', 0.2989135773363982), ('eer_agg_squared', 0.2596652347800883), ('eer_agg_ssim', 0.4031995259961487), ('eer_overall_absolute', 0.10072581839727443), ('eer_overall_psnr', 0.08857946970818378), ('eer_overall_squared', 0.08976447933639474), ('eer_overall_ssim', 0.14394027761677491), ('pr_roc_score_agg_absolute', 0.5935212731772418), ('pr_roc_score_agg_psnr', 0.6886128044697373), ('pr_roc_score_agg_squared', 0.8015145563895475), ('pr_roc_score_agg_ssim', 0.5513851505777028), ('pr_roc_score_mean_absolute', nan), ('pr_roc_score_mean_psnr', nan), ('pr_roc_score_mean_squared', nan), ('pr_roc_score_mean_ssim', nan), ('pr_roc_score_overall_absolute', 0.932495853903921), ('pr_roc_score_overall_psnr', 0.955628899206896), ('pr_roc_score_overall_squared', 0.9562967041220386), ('pr_roc_score_overall_ssim', 0.9080325091133772), ('precision_absolute_agg', 0.6907567121172048), ('precision_squared_agg', 0.7527872677069369), ('precision_ssim_agg', 0.6527766284115323), ('precision_psnr_agg', 0.7106053574130888), ('recall_absolute_agg', 0.6553771861132863), ('recall_squared_agg', 0.7438005742625946), ('recall_ssim_agg', 0.6145914904724615), ('recall_psnr_agg', 0.7035369355259723), ('f1-score_absolute_agg', 0.6519552687512744), ('f1-score_squared_agg', 0.744681276651602), ('f1-score_ssim_agg', 0.6088123457703443), ('f1-score_psnr_agg', 0.7045884146819371), ('support_absolute_agg', 15324), ('support_squared_agg', 15324), ('support_ssim_agg', 15324), ('support_psnr_agg', 15324), ('conf_mat_absolute_agg', '4589,3984,1297,5454'), ('conf_mat_squared_agg', '6076,2497,1429,5322'), ('conf_mat_ssim_agg', '4124,4449,1457,5294'), ('conf_mat_psnr_agg', '5846,2727,1816,4935'), ('precision_absolute_overall', 0.903847676547576), ('precision_squared_overall', 0.9133084467726258), ('precision_ssim_overall', 0.8608483737405992), ('precision_psnr_overall', 0.9138941885794547), ('recall_absolute_overall', 0.9038110154006787), ('recall_squared_overall', 0.91327329678935), ('recall_ssim_overall', 0.8585225789611067), ('recall_psnr_overall', 0.9137300965805273), ('f1-score_absolute_overall', 0.9038274632888619), ('f1-score_squared_overall', 0.9132887919008802), ('f1-score_ssim_overall', 0.858904134706239), ('f1-score_psnr_overall', 0.9137844299729679), ('support_absolute_overall', 15324), ('support_squared_overall', 15324), ('support_ssim_overall', 15324), ('support_psnr_overall', 15324), ('conf_mat_absolute_overall', '7825,748,726,6025'), ('conf_mat_squared_overall', '7897,676,653,6098'), ('conf_mat_ssim_overall', '7258,1315,853,5898'), ('conf_mat_psnr_overall', '7870,703,619,6132')])
# ----------------------------------------
# [INFO]: Device set to GPU
# ----------------------------------------
# 16it [01:33,  5.86s/it]
#   0%|          | 36/15328 [00:00<00:42, 358.35it/s]
# ----------------------------------------
# [INFO]: Created Dataset
# ----------------------------------------
# 100%|██████████| 15328/15328 [00:36<00:00, 425.65it/s]
# ----------------------------------------
# [INFO]: Created Encodings
# ----------------------------------------
# INFO: SVDD C Initialized torch.Size([1, 1536])
# INFO: SVDD Initialized
# ----------------------------------------
# [INFO]: SVDD Ready
# ----------------------------------------
# ----------------------------------------
# [INFO]: Data Loaders Ready. Starting the training
# ----------------------------------------
# ========================================
# Testing: For epochs = 1 and model: ../../ATTN_PPR_MODELS/AVENUE/C2D_AE_128_3X3-_ADAM_MSE_AVENUE_NORMAL-{APE}/C2D_AE_128_3X3-_ADAM_MSE_AVENUE_NORMAL-{APE}.pth.tar
# 0it [00:00, ?it/s]
# Epoch [0/1] | Train Loss: 0.746950 | Val Loss: 0.534251 | Time: (9) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 21it [01:56,  5.55s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.7105797823403536), ('auc_roc_score_agg_psnr', 0.7419514366868123), ('auc_roc_score_agg_squared', 0.8153136646224052), ('auc_roc_score_agg_ssim', 0.6588751845897329), ('auc_roc_score_mean_absolute', 0.8396951621584386), ('auc_roc_score_mean_psnr', 0.8355947028326177), ('auc_roc_score_mean_squared', 0.8356479223689046), ('auc_roc_score_mean_ssim', 0.8502927373895736), ('auc_roc_score_overall_absolute', 0.9442435207917407), ('auc_roc_score_overall_psnr', 0.9675682057410593), ('auc_roc_score_overall_squared', 0.967918020638595), ('auc_roc_score_overall_ssim', 0.9229914882464112), ('eer_agg_absolute', 0.34340370932035), ('eer_agg_psnr', 0.29892149613727337), ('eer_agg_squared', 0.26025773959397974), ('eer_agg_ssim', 0.40324273883149186), ('eer_overall_absolute', 0.10105898209357554), ('eer_overall_psnr', 0.08874375256537168), ('eer_overall_squared', 0.09005015747087083), ('eer_overall_ssim', 0.14412679603021766), ('pr_roc_score_agg_absolute', 0.5918774838607257), ('pr_roc_score_agg_psnr', 0.6868056610788815), ('pr_roc_score_agg_squared', 0.7998794627762074), ('pr_roc_score_agg_ssim', 0.5512216071426246), ('pr_roc_score_mean_absolute', nan), ('pr_roc_score_mean_psnr', nan), ('pr_roc_score_mean_squared', nan), ('pr_roc_score_mean_ssim', nan), ('pr_roc_score_overall_absolute', 0.932484094714644), ('pr_roc_score_overall_psnr', 0.9555211607053652), ('pr_roc_score_overall_squared', 0.9561713537992094), ('pr_roc_score_overall_ssim', 0.9081817664871897), ('precision_absolute_agg', 0.6923455849507418), ('precision_squared_agg', 0.7533386771852525), ('precision_ssim_agg', 0.6530035585776672), ('precision_psnr_agg', 0.7106467896313287), ('recall_absolute_agg', 0.6559645001305142), ('recall_squared_agg', 0.7444531453928478), ('recall_ssim_agg', 0.6146567475854868), ('recall_psnr_agg', 0.7030801357347951), ('f1-score_absolute_agg', 0.6523307732556758), ('f1-score_squared_agg', 0.7453343206325683), ('f1-score_ssim_agg', 0.6088300018173716), ('f1-score_psnr_agg', 0.7041303066071319), ('support_absolute_agg', 15324), ('support_squared_agg', 15324), ('support_ssim_agg', 15324), ('support_psnr_agg', 15324), ('conf_mat_absolute_agg', '4573,4000,1272,5479'), ('conf_mat_squared_agg', '6085,2488,1428,5323'), ('conf_mat_ssim_agg', '4121,4452,1453,5298'), ('conf_mat_psnr_agg', '5820,2753,1797,4954'), ('precision_absolute_overall', 0.9037879626865284), ('precision_squared_overall', 0.9133084467726258), ('precision_ssim_overall', 0.8610090825870629), ('precision_psnr_overall', 0.9138791562197157), ('recall_absolute_overall', 0.9037457582876534), ('recall_squared_overall', 0.91327329678935), ('recall_ssim_overall', 0.8589141216392587), ('recall_psnr_overall', 0.9137300965805273), ('f1-score_absolute_overall', 0.903764429707537), ('f1-score_squared_overall', 0.9132887919008802), ('f1-score_ssim_overall', 0.859277890809416), ('f1-score_psnr_overall', 0.913780727753755), ('support_absolute_overall', 15324), ('support_squared_overall', 15324), ('support_ssim_overall', 15324), ('support_psnr_overall', 15324), ('conf_mat_absolute_overall', '7823,750,725,6026'), ('conf_mat_squared_overall', '7897,676,653,6098'), ('conf_mat_ssim_overall', '7276,1297,865,5886'), ('conf_mat_psnr_overall', '7873,700,622,6129')])
# ========================================
# ========================================
# Testing: For epochs = 2 and model: ../../ATTN_PPR_MODELS/AVENUE/C2D_AE_128_3X3-_ADAM_MSE_AVENUE_NORMAL-{APE}/C2D_AE_128_3X3-_ADAM_MSE_AVENUE_NORMAL-{APE}.pth.tar
# 0it [00:00, ?it/s]
# Epoch [0/1] | Train Loss: 0.539463 | Val Loss: 0.507918 | Time: (9) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 21it [01:56,  5.56s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.7095693000400181), ('auc_roc_score_agg_psnr', 0.7418316813250213), ('auc_roc_score_agg_squared', 0.8149648000271199), ('auc_roc_score_agg_ssim', 0.6584588312564363), ('auc_roc_score_mean_absolute', 0.8396690994186445), ('auc_roc_score_mean_psnr', 0.835532656029816), ('auc_roc_score_mean_squared', 0.8355597515931555), ('auc_roc_score_mean_ssim', 0.850384362165396), ('auc_roc_score_overall_absolute', 0.944688158575658), ('auc_roc_score_overall_psnr', 0.9676036260976704), ('auc_roc_score_overall_squared', 0.9679488104315127), ('auc_roc_score_overall_ssim', 0.9230160492400321), ('eer_agg_absolute', 0.3447642844394585), ('eer_agg_psnr', 0.29965930973189103), ('eer_agg_squared', 0.26120606256046436), ('eer_agg_ssim', 0.403592674676318), ('eer_overall_absolute', 0.10089816866944123), ('eer_overall_psnr', 0.08857946970819021), ('eer_overall_squared', 0.08961635313287754), ('eer_overall_ssim', 0.14368241741964158), ('pr_roc_score_agg_absolute', 0.589566306062768), ('pr_roc_score_agg_psnr', 0.6877086136895394), ('pr_roc_score_agg_squared', 0.800191863805858), ('pr_roc_score_agg_ssim', 0.550406468780795), ('pr_roc_score_mean_absolute', nan), ('pr_roc_score_mean_psnr', nan), ('pr_roc_score_mean_squared', nan), ('pr_roc_score_mean_ssim', nan), ('pr_roc_score_overall_absolute', 0.9333770045952197), ('pr_roc_score_overall_psnr', 0.9557120085840816), ('pr_roc_score_overall_squared', 0.9563559454501724), ('pr_roc_score_overall_ssim', 0.9083427199748396), ('precision_absolute_agg', 0.6918208659579448), ('precision_squared_agg', 0.7523420572320486), ('precision_ssim_agg', 0.6533984129347581), ('precision_psnr_agg', 0.7088700201206127), ('recall_absolute_agg', 0.6552466718872357), ('recall_squared_agg', 0.7433437744714174), ('recall_ssim_agg', 0.6141346906812842), ('recall_psnr_agg', 0.7022317932654659), ('f1-score_absolute_agg', 0.6515459750174196), ('f1-score_squared_agg', 0.7442256963457451), ('f1-score_ssim_agg', 0.6079903530156032), ('f1-score_psnr_agg', 0.7032862009795826), ('support_absolute_agg', 15324), ('support_squared_agg', 15324), ('support_ssim_agg', 15324), ('support_psnr_agg', 15324), ('conf_mat_absolute_agg', '4562,4011,1272,5479'), ('conf_mat_squared_agg', '6072,2501,1432,5319'), ('conf_mat_ssim_agg', '4095,4478,1435,5316'), ('conf_mat_psnr_agg', '5856,2717,1846,4905'), ('precision_absolute_overall', 0.9045429306651623), ('precision_squared_overall', 0.9131680740788031), ('precision_ssim_overall', 0.8609966195407152), ('precision_psnr_overall', 0.9138742584404442), ('recall_absolute_overall', 0.9045288436439571), ('recall_squared_overall', 0.9131427825632994), ('recall_ssim_overall', 0.8588488645262333), ('recall_psnr_overall', 0.9137300965805273), ('f1-score_absolute_overall', 0.9045355717093769), ('f1-score_squared_overall', 0.9131542920369334), ('f1-score_ssim_overall', 0.8592168059433306), ('f1-score_psnr_overall', 0.9137794875803904), ('support_absolute_overall', 15324), ('support_squared_overall', 15324), ('support_ssim_overall', 15324), ('support_psnr_overall', 15324), ('conf_mat_absolute_overall', '7837,736,727,6024'), ('conf_mat_squared_overall', '7899,674,657,6094'), ('conf_mat_ssim_overall', '7272,1301,862,5889'), ('conf_mat_psnr_overall', '7874,699,623,6128')])
# ========================================
# ========================================
# Testing: For epochs = 5 and model: ../../ATTN_PPR_MODELS/AVENUE/C2D_AE_128_3X3-_ADAM_MSE_AVENUE_NORMAL-{APE}/C2D_AE_128_3X3-_ADAM_MSE_AVENUE_NORMAL-{APE}.pth.tar
# Epoch [0/4] | Train Loss: 0.534607 | Val Loss: 0.548320 | Time: (9) s
# Epoch [1/4] | Train Loss: 0.513756 | Val Loss: 0.507760 | Time: (9) s
# Epoch [2/4] | Train Loss: 0.510713 | Val Loss: 0.491176 | Time: (9) s
# 0it [00:00, ?it/s]
# Epoch [3/4] | Train Loss: 0.502100 | Val Loss: 0.475336 | Time: (9) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 21it [03:40, 10.49s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.7080296894465808), ('auc_roc_score_agg_psnr', 0.7433201138227113), ('auc_roc_score_agg_squared', 0.8151472753374468), ('auc_roc_score_agg_ssim', 0.6566823016728274), ('auc_roc_score_mean_absolute', 0.840372237115727), ('auc_roc_score_mean_psnr', 0.8354420270719056), ('auc_roc_score_mean_squared', 0.8353794792930747), ('auc_roc_score_mean_ssim', 0.8502952073500519), ('auc_roc_score_overall_absolute', 0.9448374596983297), ('auc_roc_score_overall_psnr', 0.9675161464559522), ('auc_roc_score_overall_squared', 0.9678242690020237), ('auc_roc_score_overall_ssim', 0.9230929200529895), ('eer_agg_absolute', 0.345282180417716), ('eer_agg_psnr', 0.2999773499432616), ('eer_agg_squared', 0.26198530269326803), ('eer_agg_ssim', 0.405225708620882), ('eer_overall_absolute', 0.10205895422900332), ('eer_overall_psnr', 0.08830047824577197), ('eer_overall_squared', 0.08981686690858597), ('eer_overall_ssim', 0.14347369648868685), ('pr_roc_score_agg_absolute', 0.5841877828826131), ('pr_roc_score_agg_psnr', 0.691359157334362), ('pr_roc_score_agg_squared', 0.8015251077683248), ('pr_roc_score_agg_ssim', 0.5480257211340772), ('pr_roc_score_mean_absolute', nan), ('pr_roc_score_mean_psnr', nan), ('pr_roc_score_mean_squared', nan), ('pr_roc_score_mean_ssim', nan), ('pr_roc_score_overall_absolute', 0.9341471505148518), ('pr_roc_score_overall_psnr', 0.9557748817579685), ('pr_roc_score_overall_squared', 0.9563520240500036), ('pr_roc_score_overall_ssim', 0.9087205017504701), ('precision_absolute_agg', 0.6918346647482754), ('precision_squared_agg', 0.7507431214300436), ('precision_ssim_agg', 0.6519441657693539), ('precision_psnr_agg', 0.7079154241218398), ('recall_absolute_agg', 0.6525711302531976), ('recall_squared_agg', 0.7411902897415819), ('recall_ssim_agg', 0.6133516053249805), ('recall_psnr_agg', 0.6977290524667189), ('f1-score_absolute_agg', 0.6481469831397241), ('f1-score_squared_agg', 0.7420623223403472), ('f1-score_ssim_agg', 0.6073789940673135), ('f1-score_psnr_agg', 0.6987086878154837), ('support_absolute_agg', 15324), ('support_squared_agg', 15324), ('support_ssim_agg', 15324), ('support_psnr_agg', 15324), ('conf_mat_absolute_agg', '4480,4093,1231,5520'), ('conf_mat_squared_agg', '6034,2539,1427,5324'), ('conf_mat_ssim_agg', '4102,4471,1454,5297'), ('conf_mat_psnr_agg', '5669,2904,1728,5023'), ('precision_absolute_overall', 0.9053729407009171), ('precision_squared_overall', 0.9130281878249353), ('precision_ssim_overall', 0.860658094368033), ('precision_psnr_overall', 0.9134044250394135), ('recall_absolute_overall', 0.9054424432263116), ('recall_squared_overall', 0.9130122683372488), ('recall_ssim_overall', 0.8581962933959801), ('recall_psnr_overall', 0.9132080396763247), ('f1-score_absolute_overall', 0.9053890904750274), ('f1-score_squared_overall', 0.91301975232824), ('f1-score_ssim_overall', 0.8585877678598057), ('f1-score_psnr_overall', 0.9132700682938582), ('support_absolute_overall', 15324), ('support_squared_overall', 15324), ('support_ssim_overall', 15324), ('support_psnr_overall', 15324), ('conf_mat_absolute_overall', '7883,690,759,5992'), ('conf_mat_squared_overall', '7901,672,661,6090'), ('conf_mat_ssim_overall', '7247,1326,847,5904'), ('conf_mat_psnr_overall', '7860,713,617,6134')])
# ========================================
# ========================================
# Testing: For epochs = 10 and model: ../../ATTN_PPR_MODELS/AVENUE/C2D_AE_128_3X3-_ADAM_MSE_AVENUE_NORMAL-{APE}/C2D_AE_128_3X3-_ADAM_MSE_AVENUE_NORMAL-{APE}.pth.tar
# Epoch [0/6] | Train Loss: 0.479930 | Val Loss: 0.467151 | Time: (10) s
# Epoch [1/6] | Train Loss: 0.471445 | Val Loss: 0.459192 | Time: (10) s
# Epoch [2/6] | Train Loss: 0.463890 | Val Loss: 0.490640 | Time: (8) s
# Epoch [3/6] | Train Loss: 0.462929 | Val Loss: 0.431611 | Time: (9) s
# Epoch [4/6] | Train Loss: 0.448435 | Val Loss: 0.423702 | Time: (9) s
# 0it [00:00, ?it/s]
# Epoch [5/6] | Train Loss: 0.440666 | Val Loss: 0.452225 | Time: (9) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 21it [02:10,  6.23s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.7071088292875828), ('auc_roc_score_agg_psnr', 0.7479766294068129), ('auc_roc_score_agg_squared', 0.8162244170211022), ('auc_roc_score_agg_ssim', 0.6544152260674888), ('auc_roc_score_mean_absolute', 0.8413619736157663), ('auc_roc_score_mean_psnr', 0.8356508816464645), ('auc_roc_score_mean_squared', 0.8354987860702017), ('auc_roc_score_mean_ssim', 0.8501436795783143), ('auc_roc_score_overall_absolute', 0.9448083631712403), ('auc_roc_score_overall_psnr', 0.9673775059967096), ('auc_roc_score_overall_squared', 0.9676314267580542), ('auc_roc_score_overall_ssim', 0.9233696653465703), ('eer_agg_absolute', 0.34363699988255314), ('eer_agg_psnr', 0.29709553248517234), ('eer_agg_squared', 0.26210194797589237), ('eer_agg_ssim', 0.408491776507225), ('eer_overall_absolute', 0.10626385162866403), ('eer_overall_psnr', 0.08829287392325261), ('eer_overall_squared', 0.0897002216249227), ('eer_overall_ssim', 0.14234928158791407), ('pr_roc_score_agg_absolute', 0.5808362495743602), ('pr_roc_score_agg_psnr', 0.6997460373590599), ('pr_roc_score_agg_squared', 0.8039408799273996), ('pr_roc_score_agg_ssim', 0.5460954489916383), ('pr_roc_score_mean_absolute', nan), ('pr_roc_score_mean_psnr', nan), ('pr_roc_score_mean_squared', nan), ('pr_roc_score_mean_ssim', nan), ('pr_roc_score_overall_absolute', 0.9341030302187019), ('pr_roc_score_overall_psnr', 0.9556768326239965), ('pr_roc_score_overall_squared', 0.9561701608407935), ('pr_roc_score_overall_ssim', 0.9094499069404562), ('precision_absolute_agg', 0.6893358309000813), ('precision_squared_agg', 0.7507595746345422), ('precision_ssim_agg', 0.6518363687967522), ('precision_psnr_agg', 0.7065502226280889), ('recall_absolute_agg', 0.6513312451057165), ('recall_squared_agg', 0.7400156617071261), ('recall_ssim_agg', 0.6117201774993475), ('recall_psnr_agg', 0.7032106499608457), ('f1-score_absolute_agg', 0.6471632819709376), ('f1-score_squared_agg', 0.7408433954104946), ('f1-score_ssim_agg', 0.6051676224864203), ('f1-score_psnr_agg', 0.7040725658792919), ('support_absolute_agg', 15324), ('support_squared_agg', 15324), ('support_ssim_agg', 15324), ('support_psnr_agg', 15324), ('conf_mat_absolute_agg', '4494,4079,1264,5487'), ('conf_mat_squared_agg', '5981,2592,1392,5359'), ('conf_mat_ssim_agg', '4051,4522,1428,5323'), ('conf_mat_psnr_agg', '6039,2534,2014,4737'), ('precision_absolute_overall', 0.9067590946851142), ('precision_squared_overall', 0.9126336779955094), ('precision_ssim_overall', 0.8599702665455172), ('precision_psnr_overall', 0.9130471647747156), ('recall_absolute_overall', 0.9066823283737927), ('recall_squared_overall', 0.9126207256590968), ('recall_ssim_overall', 0.8569564082484991), ('recall_psnr_overall', 0.9128164969981728), ('f1-score_absolute_overall', 0.906470756475743), ('f1-score_squared_overall', 0.912626883471535), ('f1-score_ssim_overall', 0.8573828749100154), ('f1-score_psnr_overall', 0.9128860942592533), ('support_absolute_overall', 15324), ('support_squared_overall', 15324), ('support_ssim_overall', 15324), ('support_psnr_overall', 15324), ('conf_mat_absolute_overall', '7984,589,841,5910'), ('conf_mat_squared_overall', '7899,674,665,6086'), ('conf_mat_ssim_overall', '7205,1368,824,5927'), ('conf_mat_psnr_overall', '7851,722,614,6137')])
# ========================================
# ========================================
# Testing: For epochs = 20 and model: ../../ATTN_PPR_MODELS/AVENUE/C2D_AE_128_3X3-_ADAM_MSE_AVENUE_NORMAL-{APE}/C2D_AE_128_3X3-_ADAM_MSE_AVENUE_NORMAL-{APE}.pth.tar
# Epoch [0/14] | Train Loss: 0.430899 | Val Loss: 0.410940 | Time: (9) s
# Epoch [1/14] | Train Loss: 0.426849 | Val Loss: 0.404843 | Time: (9) s
# Epoch [2/14] | Train Loss: 0.418598 | Val Loss: 0.411805 | Time: (9) s
# Epoch [3/14] | Train Loss: 0.412301 | Val Loss: 0.414508 | Time: (9) s
# Epoch [4/14] | Train Loss: 0.407439 | Val Loss: 0.394789 | Time: (9) s
# Epoch [5/14] | Train Loss: 0.399513 | Val Loss: 0.377933 | Time: (9) s
# Epoch [6/14] | Train Loss: 0.392683 | Val Loss: 0.393030 | Time: (9) s
# Epoch [7/14] | Train Loss: 0.385305 | Val Loss: 0.366904 | Time: (9) s
# Epoch [8/14] | Train Loss: 0.381724 | Val Loss: 0.361832 | Time: (9) s
# Epoch [9/14] | Train Loss: 0.374502 | Val Loss: 0.372985 | Time: (9) s
# Epoch [10/14] | Train Loss: 0.368287 | Val Loss: 0.366930 | Time: (8) s
# Epoch [11/14] | Train Loss: 0.363050 | Val Loss: 0.372882 | Time: (10) s
# Epoch [12/14] | Train Loss: 0.359543 | Val Loss: 0.358032 | Time: (9) s
# 0it [00:00, ?it/s]
# Epoch [13/14] | Train Loss: 0.351535 | Val Loss: 0.380703 | Time: (9) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 21it [01:56,  5.56s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.7077331605879662), ('auc_roc_score_agg_psnr', 0.76798368825193), ('auc_roc_score_agg_squared', 0.8264089963006116), ('auc_roc_score_agg_ssim', 0.6486491030192088), ('auc_roc_score_mean_absolute', 0.8426211921222283), ('auc_roc_score_mean_psnr', 0.8366880558763348), ('auc_roc_score_mean_squared', 0.8363795063289609), ('auc_roc_score_mean_ssim', 0.8501625374613573), ('auc_roc_score_overall_absolute', 0.9457977142051681), ('auc_roc_score_overall_psnr', 0.9672759446034607), ('auc_roc_score_overall_squared', 0.9674188527837195), ('auc_roc_score_overall_ssim', 0.9246052483327248), ('eer_agg_absolute', 0.34364665911664766), ('eer_agg_psnr', 0.28718068354104853), ('eer_agg_squared', 0.25848022515213287), ('eer_agg_ssim', 0.41134646719004603), ('eer_overall_absolute', 0.11407908550119197), ('eer_overall_psnr', 0.08830047824689255), ('eer_overall_squared', 0.08911699521646176), ('eer_overall_ssim', 0.13760924307509997), ('pr_roc_score_agg_absolute', 0.5875276698450593), ('pr_roc_score_agg_psnr', 0.7343548061140956), ('pr_roc_score_agg_squared', 0.8202557874328134), ('pr_roc_score_agg_ssim', 0.5383819082222415), ('pr_roc_score_mean_absolute', nan), ('pr_roc_score_mean_psnr', nan), ('pr_roc_score_mean_squared', nan), ('pr_roc_score_mean_ssim', nan), ('pr_roc_score_overall_absolute', 0.9360534895588819), ('pr_roc_score_overall_psnr', 0.9561460477712427), ('pr_roc_score_overall_squared', 0.9564763400567674), ('pr_roc_score_overall_ssim', 0.9113839806700288), ('precision_absolute_agg', 0.6957575361842141), ('precision_squared_agg', 0.755811023886135), ('precision_ssim_agg', 0.6508178466282167), ('precision_psnr_agg', 0.7165981047597185), ('recall_absolute_agg', 0.652244844688071), ('recall_squared_agg', 0.7415165753067084), ('recall_ssim_agg', 0.6092404072043853), ('recall_psnr_agg', 0.7135212738188462), ('f1-score_absolute_agg', 0.6467840824727351), ('f1-score_squared_agg', 0.7421282610459962), ('f1-score_ssim_agg', 0.6020588924110859), ('f1-score_psnr_agg', 0.7143256305319658), ('support_absolute_agg', 15324), ('support_squared_agg', 15324), ('support_ssim_agg', 15324), ('support_psnr_agg', 15324), ('conf_mat_absolute_agg', '4393,4180,1149,5602'), ('conf_mat_squared_agg', '5875,2698,1263,5488'), ('conf_mat_ssim_agg', '3993,4580,1408,5343'), ('conf_mat_psnr_agg', '6132,2441,1949,4802'), ('precision_absolute_overall', 0.9010840257529215), ('precision_squared_overall', 0.9126771190302371), ('precision_ssim_overall', 0.8718114916920713), ('precision_psnr_overall', 0.9130868255542987), ('recall_absolute_overall', 0.9008744453145393), ('recall_squared_overall', 0.9125554685460715), ('recall_ssim_overall', 0.8719655442443226), ('recall_psnr_overall', 0.9128817541111981), ('f1-score_absolute_overall', 0.9005804027926623), ('f1-score_squared_overall', 0.9125992003508682), ('f1-score_ssim_overall', 0.8718249037247777), ('f1-score_psnr_overall', 0.912945847139621), ('support_absolute_overall', 15324), ('support_squared_overall', 15324), ('support_ssim_overall', 15324), ('support_psnr_overall', 15324), ('conf_mat_absolute_overall', '7973,600,919,5832'), ('conf_mat_squared_overall', '7870,703,637,6114'), ('conf_mat_ssim_overall', '7657,916,1046,5705'), ('conf_mat_psnr_overall', '7856,717,618,6133')])
# ========================================
# ----------------------------------------
# ----------------------------------------
# [INFO]: COMPLETED: AVENUE
# ----------------------------------------
# ----------------------------------------
# [INFO]: HAM10000
# ----------------------------------------
# 6it [00:34,  5.73s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.6860012381241156), ('auc_roc_score_agg_psnr', 0.7125897008287851), ('auc_roc_score_agg_squared', 0.6831596169395593), ('auc_roc_score_agg_ssim', 0.6777089650293106), ('auc_roc_score_mean_absolute', 0.7024437149292692), ('auc_roc_score_mean_psnr', 0.7074594097480108), ('auc_roc_score_mean_squared', 0.7074597923620298), ('auc_roc_score_mean_ssim', 0.6743390452838572), ('auc_roc_score_overall_absolute', 0.7342616737416615), ('auc_roc_score_overall_psnr', 0.7371262886597938), ('auc_roc_score_overall_squared', 0.7371270466949666), ('auc_roc_score_overall_ssim', 0.7032504548211036), ('eer_agg_absolute', 0.35499999999970083), ('eer_agg_psnr', 0.3358693793810857), ('eer_agg_squared', 0.36112795633688605), ('eer_agg_ssim', 0.3541666666669277), ('eer_overall_absolute', 0.31878409976618804), ('eer_overall_psnr', 0.3199999999995291), ('eer_overall_squared', 0.31999999999999995), ('eer_overall_ssim', 0.33500000000043995), ('pr_roc_score_agg_absolute', 0.6186530111092485), ('pr_roc_score_agg_psnr', 0.6025666324308946), ('pr_roc_score_agg_squared', 0.6147887302550454), ('pr_roc_score_agg_ssim', 0.6248723332744686), ('pr_roc_score_mean_absolute', 0.707781731344067), ('pr_roc_score_mean_psnr', 0.7125798350131695), ('pr_roc_score_mean_squared', 0.7125796535817739), ('pr_roc_score_mean_ssim', 0.7034883532450898), ('pr_roc_score_overall_absolute', 0.5994392910974514), ('pr_roc_score_overall_psnr', 0.5939016363344058), ('pr_roc_score_overall_squared', 0.5939011904663685), ('pr_roc_score_overall_ssim', 0.6142012857582351), ('precision_absolute_agg', 0.7203488813700633), ('precision_squared_agg', 0.7192701028523926), ('precision_ssim_agg', 0.7183561125861746), ('precision_psnr_agg', 0.7413503774553492), ('recall_absolute_agg', 0.6885282347710093), ('recall_squared_agg', 0.6807469986660738), ('recall_ssim_agg', 0.6647398843930635), ('recall_psnr_agg', 0.7349933303690529), ('f1-score_absolute_agg', 0.700053162804496), ('f1-score_squared_agg', 0.6939893638080452), ('f1-score_ssim_agg', 0.6812047262568726), ('f1-score_psnr_agg', 0.737888257347642), ('support_absolute_agg', 4498), ('support_squared_agg', 4498), ('support_ssim_agg', 4498), ('support_psnr_agg', 4498), ('conf_mat_absolute_agg', '2413,885,516,684'), ('conf_mat_squared_agg', '2362,936,500,700'), ('conf_mat_ssim_agg', '2254,1044,464,736'), ('conf_mat_psnr_agg', '2658,640,552,648'), ('precision_absolute_overall', 0.7588794229137465), ('precision_squared_overall', 0.7630827223773836), ('precision_ssim_overall', 0.7395086987316459), ('precision_psnr_overall', 0.7630827223773836), ('recall_absolute_overall', 0.6511783014673188), ('recall_squared_overall', 0.7696754112939084), ('recall_ssim_overall', 0.6847487772343264), ('recall_psnr_overall', 0.7696754112939084), ('f1-score_absolute_overall', 0.6712581518916825), ('f1-score_squared_overall', 0.765816828150754), ('f1-score_ssim_overall', 0.7005269765536203), ('f1-score_psnr_overall', 0.765816828150754), ('support_absolute_overall', 4498), ('support_squared_overall', 4498), ('support_ssim_overall', 4498), ('support_psnr_overall', 4498), ('conf_mat_absolute_overall', '1993,1305,264,936'), ('conf_mat_squared_overall', '2838,460,576,624'), ('conf_mat_ssim_overall', '2288,1010,408,792'), ('conf_mat_psnr_overall', '2838,460,576,624')])
# ----------------------------------------
# [INFO]: Device set to GPU
# ----------------------------------------
#   1%|          | 37/6460 [00:00<00:17, 362.65it/s]
# ----------------------------------------
# [INFO]: Created Dataset
# ----------------------------------------
# 100%|██████████| 6460/6460 [00:15<00:00, 417.46it/s]
# ----------------------------------------
# [INFO]: Created Encodings
# ----------------------------------------
# INFO: SVDD C Initialized torch.Size([1, 1536])
# INFO: SVDD Initialized
# ----------------------------------------
# [INFO]: SVDD Ready
# ----------------------------------------
# ----------------------------------------
# [INFO]: Data Loaders Ready. Starting the training
# ----------------------------------------
# ========================================
# Testing: For epochs = 1 and model: ../../ATTN_PPR_MODELS/HAM10000/C2D_AE_128_3X3-_ADAM_MSE_HAM10000_NORMAL-{APE}/C2D_AE_128_3X3-_ADAM_MSE_HAM10000_NORMAL-{APE}.pth.tar
# 0it [00:00, ?it/s]
# Epoch [0/1] | Train Loss: 78.059270 | Val Loss: 63.202767 | Time: (4) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 6it [00:34,  5.83s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.6852181877905802), ('auc_roc_score_agg_psnr', 0.7126404891853649), ('auc_roc_score_agg_squared', 0.6836508237315545), ('auc_roc_score_agg_ssim', 0.6780622094198504), ('auc_roc_score_mean_absolute', 0.7008341209867576), ('auc_roc_score_mean_psnr', 0.707165301003641), ('auc_roc_score_mean_squared', 0.7071656760411447), ('auc_roc_score_mean_ssim', 0.6747110231526938), ('auc_roc_score_overall_absolute', 0.7328259551243177), ('auc_roc_score_overall_psnr', 0.7368549120679199), ('auc_roc_score_overall_squared', 0.7368556701030927), ('auc_roc_score_overall_ssim', 0.7035961188599151), ('eer_agg_absolute', 0.35440849592491974), ('eer_agg_psnr', 0.33626440266795254), ('eer_agg_squared', 0.35833333333333334), ('eer_agg_ssim', 0.3541666666666719), ('eer_overall_absolute', 0.321710127350199), ('eer_overall_psnr', 0.3183943881527669), ('eer_overall_squared', 0.3183943881527669), ('eer_overall_ssim', 0.3308065494243008), ('pr_roc_score_agg_absolute', 0.6185250958396249), ('pr_roc_score_agg_psnr', 0.6024995641321612), ('pr_roc_score_agg_squared', 0.6144786928336816), ('pr_roc_score_agg_ssim', 0.6246019118370553), ('pr_roc_score_mean_absolute', 0.7083601068479138), ('pr_roc_score_mean_psnr', 0.7126208015524923), ('pr_roc_score_mean_squared', 0.712620626483896), ('pr_roc_score_mean_ssim', 0.7035911993834455), ('pr_roc_score_overall_absolute', 0.5995935308255993), ('pr_roc_score_overall_psnr', 0.5939362246965852), ('pr_roc_score_overall_squared', 0.5939359807493471), ('pr_roc_score_overall_ssim', 0.6139294461455058), ('precision_absolute_agg', 0.7213423631635006), ('precision_squared_agg', 0.7184744374650484), ('precision_ssim_agg', 0.7186446710779177), ('precision_psnr_agg', 0.7416335431230003), ('recall_absolute_agg', 0.70431302801245), ('recall_squared_agg', 0.6780791462872388), ('recall_ssim_agg', 0.6640729212983548), ('recall_psnr_agg', 0.7356602934637617), ('f1-score_absolute_agg', 0.7113467314473838), ('f1-score_squared_agg', 0.6917861646927258), ('f1-score_ssim_agg', 0.6807019162251001), ('f1-score_psnr_agg', 0.7383940368706963), ('support_absolute_agg', 4498), ('support_squared_agg', 4498), ('support_ssim_agg', 4498), ('support_psnr_agg', 4498), ('conf_mat_absolute_agg', '2528,770,560,640'), ('conf_mat_squared_agg', '2347,951,497,703'), ('conf_mat_ssim_agg', '2248,1050,461,739'), ('conf_mat_psnr_agg', '2662,636,553,647'), ('precision_absolute_overall', 0.7576194989620451), ('precision_squared_overall', 0.7491822107027414), ('precision_ssim_overall', 0.7394024923127945), ('precision_psnr_overall', 0.7491822107027414), ('recall_absolute_overall', 0.6598488216985327), ('recall_squared_overall', 0.7178746109381947), ('recall_ssim_overall', 0.6845264562027568), ('recall_psnr_overall', 0.7178746109381947), ('f1-score_absolute_overall', 0.679476685082492), ('f1-score_squared_overall', 0.7285527437941064), ('f1-score_ssim_overall', 0.7003288121220506), ('f1-score_psnr_overall', 0.7285527437941064), ('support_absolute_overall', 4498), ('support_squared_overall', 4498), ('support_ssim_overall', 4498), ('support_psnr_overall', 4498), ('conf_mat_absolute_overall', '2050,1248,282,918'), ('conf_mat_squared_overall', '2473,825,444,756'), ('conf_mat_ssim_overall', '2287,1011,408,792'), ('conf_mat_psnr_overall', '2473,825,444,756')])
# ========================================
# ========================================
# Testing: For epochs = 2 and model: ../../ATTN_PPR_MODELS/HAM10000/C2D_AE_128_3X3-_ADAM_MSE_HAM10000_NORMAL-{APE}/C2D_AE_128_3X3-_ADAM_MSE_HAM10000_NORMAL-{APE}.pth.tar
# 0it [00:00, ?it/s]
# Epoch [0/1] | Train Loss: 50.429056 | Val Loss: 51.857075 | Time: (4) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 6it [00:34,  5.81s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.684923185769153), ('auc_roc_score_agg_psnr', 0.7131495098039216), ('auc_roc_score_agg_squared', 0.6835481099656358), ('auc_roc_score_agg_ssim', 0.6778840711542349), ('auc_roc_score_mean_absolute', 0.7009239188253833), ('auc_roc_score_mean_psnr', 0.7066985638052437), ('auc_roc_score_mean_squared', 0.7066993744407819), ('auc_roc_score_mean_ssim', 0.6745119035398495), ('auc_roc_score_overall_absolute', 0.7320148574893877), ('auc_roc_score_overall_psnr', 0.736240903577926), ('auc_roc_score_overall_squared', 0.7362416616130989), ('auc_roc_score_overall_ssim', 0.7033869011522135), ('eer_agg_absolute', 0.3550636749536242), ('eer_agg_psnr', 0.3380836870828772), ('eer_agg_squared', 0.3608247422677902), ('eer_agg_ssim', 0.3542697354270107), ('eer_overall_absolute', 0.31964765601672135), ('eer_overall_psnr', 0.3213718640838361), ('eer_overall_squared', 0.3226197695561341), ('eer_overall_ssim', 0.3323134855260061), ('pr_roc_score_agg_absolute', 0.6186119603811371), ('pr_roc_score_agg_psnr', 0.6021513147312338), ('pr_roc_score_agg_squared', 0.6144469896342), ('pr_roc_score_agg_ssim', 0.6247581842264208), ('pr_roc_score_mean_absolute', 0.7089783892363429), ('pr_roc_score_mean_psnr', 0.7127966540462397), ('pr_roc_score_mean_squared', 0.7127965642842558), ('pr_roc_score_mean_ssim', 0.7035742652618707), ('pr_roc_score_overall_absolute', 0.600233209011053), ('pr_roc_score_overall_psnr', 0.5943784434217817), ('pr_roc_score_overall_squared', 0.5943781036278266), ('pr_roc_score_overall_ssim', 0.6140583897185713), ('precision_absolute_agg', 0.7215989020873577), ('precision_squared_agg', 0.719129545045703), ('precision_ssim_agg', 0.7187637047833955), ('precision_psnr_agg', 0.7420664363361825), ('recall_absolute_agg', 0.7067585593597154), ('recall_squared_agg', 0.6883059137394397), ('recall_ssim_agg', 0.6647398843930635), ('recall_psnr_agg', 0.7363272565584704), ('f1-score_absolute_agg', 0.7130207418362072), ('f1-score_squared_agg', 0.6995914241362792), ('f1-score_ssim_agg', 0.6812634139635516), ('f1-score_psnr_agg', 0.7389614255334254), ('support_absolute_agg', 4498), ('support_squared_agg', 4498), ('support_ssim_agg', 4498), ('support_psnr_agg', 4498), ('conf_mat_absolute_agg', '2546,752,567,633'), ('conf_mat_squared_agg', '2418,880,522,678'), ('conf_mat_ssim_agg', '2252,1046,462,738'), ('conf_mat_psnr_agg', '2665,633,553,647'), ('precision_absolute_overall', 0.7569345133313342), ('precision_squared_overall', 0.7484698697278729), ('precision_ssim_overall', 0.7395086987316459), ('precision_psnr_overall', 0.7484698697278729), ('recall_absolute_overall', 0.6542907959092931), ('recall_squared_overall', 0.7165406847487772), ('recall_ssim_overall', 0.6847487772343264), ('recall_psnr_overall', 0.7165406847487772), ('f1-score_absolute_overall', 0.6742397084371092), ('f1-score_squared_overall', 0.7273872711396452), ('f1-score_ssim_overall', 0.7005269765536203), ('f1-score_psnr_overall', 0.7273872711396452), ('support_absolute_overall', 4498), ('support_squared_overall', 4498), ('support_ssim_overall', 4498), ('support_psnr_overall', 4498), ('conf_mat_absolute_overall', '2019,1279,276,924'), ('conf_mat_squared_overall', '2467,831,444,756'), ('conf_mat_ssim_overall', '2288,1010,408,792'), ('conf_mat_psnr_overall', '2467,831,444,756')])
# ========================================
# ========================================
# Testing: For epochs = 5 and model: ../../ATTN_PPR_MODELS/HAM10000/C2D_AE_128_3X3-_ADAM_MSE_HAM10000_NORMAL-{APE}/C2D_AE_128_3X3-_ADAM_MSE_HAM10000_NORMAL-{APE}.pth.tar
# Epoch [0/4] | Train Loss: 51.409680 | Val Loss: 74.018522 | Time: (4) s
# Epoch [1/4] | Train Loss: 50.515395 | Val Loss: 51.514574 | Time: (4) s
# Epoch [2/4] | Train Loss: 50.247185 | Val Loss: 79.952239 | Time: (4) s
# 0it [00:00, ?it/s]
# Epoch [3/4] | Train Loss: 48.527517 | Val Loss: 54.792500 | Time: (4) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 6it [00:34,  5.80s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.6840597837072974), ('auc_roc_score_agg_psnr', 0.7145194057004245), ('auc_roc_score_agg_squared', 0.6838551142106326), ('auc_roc_score_agg_ssim', 0.6779437032544977), ('auc_roc_score_mean_absolute', 0.7012046639327404), ('auc_roc_score_mean_psnr', 0.7071176278867247), ('auc_roc_score_mean_squared', 0.7071176278867247), ('auc_roc_score_mean_ssim', 0.6745580704642503), ('auc_roc_score_overall_absolute', 0.7310203153426319), ('auc_roc_score_overall_psnr', 0.7364069132807763), ('auc_roc_score_overall_squared', 0.7364069132807761), ('auc_roc_score_overall_ssim', 0.7035309278350516), ('eer_agg_absolute', 0.3580958156449234), ('eer_agg_psnr', 0.3374999999999999), ('eer_agg_squared', 0.36082703423743884), ('eer_agg_ssim', 0.35506367495451985), ('eer_overall_absolute', 0.32499999999999996), ('eer_overall_psnr', 0.3244390539713417), ('eer_overall_squared', 0.3244390539716172), ('eer_overall_ssim', 0.33000000000001084), ('pr_roc_score_agg_absolute', 0.6185247192736671), ('pr_roc_score_agg_psnr', 0.6011629753148874), ('pr_roc_score_agg_squared', 0.6139229489441638), ('pr_roc_score_agg_ssim', 0.6246684952874375), ('pr_roc_score_mean_absolute', 0.7104147530360444), ('pr_roc_score_mean_psnr', 0.7133784747923766), ('pr_roc_score_mean_squared', 0.713378407318371), ('pr_roc_score_mean_ssim', 0.7034091156739145), ('pr_roc_score_overall_absolute', 0.600280696202343), ('pr_roc_score_overall_psnr', 0.5940806404897061), ('pr_roc_score_overall_squared', 0.5940804433846247), ('pr_roc_score_overall_ssim', 0.6139677821502636), ('precision_absolute_agg', 0.7239863383947117), ('precision_squared_agg', 0.7187200705631853), ('precision_ssim_agg', 0.7185722338287084), ('precision_psnr_agg', 0.7438162641415307), ('recall_absolute_agg', 0.7118719430858159), ('recall_squared_agg', 0.6731880835927079), ('recall_ssim_agg', 0.6651845264562027), ('recall_psnr_agg', 0.737661182747888), ('f1-score_absolute_agg', 0.7171147144474254), ('f1-score_squared_agg', 0.6880289833092004), ('f1-score_ssim_agg', 0.6815979837804824), ('f1-score_psnr_agg', 0.740466014860052), ('support_absolute_agg', 4498), ('support_squared_agg', 4498), ('support_ssim_agg', 4498), ('support_psnr_agg', 4498), ('conf_mat_absolute_agg', '2573,725,571,629'), ('conf_mat_squared_agg', '2311,987,483,717'), ('conf_mat_ssim_agg', '2256,1042,464,736'), ('conf_mat_psnr_agg', '2665,633,547,653'), ('precision_absolute_overall', 0.7511277381101322), ('precision_squared_overall', 0.7602804873077225), ('precision_ssim_overall', 0.7395086987316459), ('precision_psnr_overall', 0.7602804873077225), ('recall_absolute_overall', 0.7325477990217875), ('recall_squared_overall', 0.76345042240996), ('recall_ssim_overall', 0.6847487772343264), ('recall_psnr_overall', 0.76345042240996), ('f1-score_absolute_overall', 0.739727731256468), ('f1-score_squared_overall', 0.7617561826202418), ('f1-score_ssim_overall', 0.7005269765536203), ('f1-score_psnr_overall', 0.7617561826202418), ('support_absolute_overall', 4498), ('support_squared_overall', 4498), ('support_ssim_overall', 4498), ('support_psnr_overall', 4498), ('conf_mat_absolute_overall', '2575,723,480,720'), ('conf_mat_squared_overall', '2792,506,558,642'), ('conf_mat_ssim_overall', '2288,1010,408,792'), ('conf_mat_psnr_overall', '2792,506,558,642')])
# ========================================
# ========================================
# Testing: For epochs = 10 and model: ../../ATTN_PPR_MODELS/HAM10000/C2D_AE_128_3X3-_ADAM_MSE_HAM10000_NORMAL-{APE}/C2D_AE_128_3X3-_ADAM_MSE_HAM10000_NORMAL-{APE}.pth.tar
# Epoch [0/6] | Train Loss: 48.239634 | Val Loss: 48.511160 | Time: (5) s
# Epoch [1/6] | Train Loss: 49.090717 | Val Loss: 80.504842 | Time: (4) s
# Epoch [2/6] | Train Loss: 48.306089 | Val Loss: 47.782825 | Time: (4) s
# Epoch [3/6] | Train Loss: 49.135672 | Val Loss: 84.933533 | Time: (5) s
# Epoch [4/6] | Train Loss: 47.733681 | Val Loss: 55.044929 | Time: (4) s
# 0it [00:00, ?it/s]
# Epoch [5/6] | Train Loss: 50.288225 | Val Loss: 52.925501 | Time: (4) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 6it [00:34,  5.76s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.6841343238326258), ('auc_roc_score_agg_psnr', 0.7139837275116232), ('auc_roc_score_agg_squared', 0.6828944309682636), ('auc_roc_score_agg_ssim', 0.6778509702850213), ('auc_roc_score_mean_absolute', 0.7052880761381438), ('auc_roc_score_mean_psnr', 0.7089849059747477), ('auc_roc_score_mean_squared', 0.7089844703767132), ('auc_roc_score_mean_ssim', 0.6745979670738375), ('auc_roc_score_overall_absolute', 0.7325530624620981), ('auc_roc_score_overall_psnr', 0.7361961795027289), ('auc_roc_score_overall_squared', 0.7361961795027289), ('auc_roc_score_overall_ssim', 0.7035430563978169), ('eer_agg_absolute', 0.35999999999984195), ('eer_agg_psnr', 0.34038851841113366), ('eer_agg_squared', 0.36245512053342455), ('eer_agg_ssim', 0.35445724681627666), ('eer_overall_absolute', 0.33201940570082955), ('eer_overall_psnr', 0.32499999999999984), ('eer_overall_squared', 0.3249999999998729), ('eer_overall_ssim', 0.332888770338757), ('pr_roc_score_agg_absolute', 0.6167885509581437), ('pr_roc_score_agg_psnr', 0.600843122955016), ('pr_roc_score_agg_squared', 0.6138207406627935), ('pr_roc_score_agg_ssim', 0.6247078235925123), ('pr_roc_score_mean_absolute', 0.7118640413389751), ('pr_roc_score_mean_psnr', 0.7142139229907111), ('pr_roc_score_mean_squared', 0.7142146293536283), ('pr_roc_score_mean_ssim', 0.703557141191841), ('pr_roc_score_overall_absolute', 0.5979205011200329), ('pr_roc_score_overall_psnr', 0.5937058208854743), ('pr_roc_score_overall_squared', 0.5937063890729681), ('pr_roc_score_overall_ssim', 0.6140066697997744), ('precision_absolute_agg', 0.7249108986793403), ('precision_squared_agg', 0.7329064687079331), ('precision_ssim_agg', 0.7182361516092605), ('precision_psnr_agg', 0.7459961814675813), ('recall_absolute_agg', 0.7187638950644731), ('recall_squared_agg', 0.7432192085371276), ('recall_ssim_agg', 0.6640729212983548), ('recall_psnr_agg', 0.7463317029791018), ('f1-score_absolute_agg', 0.7216065281544559), ('f1-score_squared_agg', 0.73704620355361), ('f1-score_ssim_agg', 0.680643922313201), ('f1-score_psnr_agg', 0.7461629854448018), ('support_absolute_agg', 4498), ('support_squared_agg', 4498), ('support_ssim_agg', 4498), ('support_psnr_agg', 4498), ('conf_mat_absolute_agg', '2625,673,592,608'), ('conf_mat_squared_agg', '2801,497,658,542'), ('conf_mat_ssim_agg', '2250,1048,463,737'), ('conf_mat_psnr_agg', '2730,568,573,627'), ('precision_absolute_overall', 0.7551853234001018), ('precision_squared_overall', 0.7595207203747456), ('precision_ssim_overall', 0.7391902039191766), ('precision_psnr_overall', 0.7595207203747456), ('recall_absolute_overall', 0.7361049355269008), ('recall_squared_overall', 0.7614495331258337), ('recall_ssim_overall', 0.6840818141396177), ('recall_psnr_overall', 0.7614495331258337), ('f1-score_absolute_overall', 0.7433782192724839), ('f1-score_squared_overall', 0.7604466840125781), ('f1-score_ssim_overall', 0.6999324253393445), ('f1-score_psnr_overall', 0.7604466840125781), ('support_absolute_overall', 4498), ('support_squared_overall', 4498), ('support_ssim_overall', 4498), ('support_psnr_overall', 4498), ('conf_mat_absolute_overall', '2579,719,468,732'), ('conf_mat_squared_overall', '2777,521,552,648'), ('conf_mat_ssim_overall', '2285,1013,408,792'), ('conf_mat_psnr_overall', '2777,521,552,648')])
# ========================================
# ========================================
# Testing: For epochs = 20 and model: ../../ATTN_PPR_MODELS/HAM10000/C2D_AE_128_3X3-_ADAM_MSE_HAM10000_NORMAL-{APE}/C2D_AE_128_3X3-_ADAM_MSE_HAM10000_NORMAL-{APE}.pth.tar
# Epoch [0/14] | Train Loss: 47.252409 | Val Loss: 47.241231 | Time: (4) s
# Epoch [1/14] | Train Loss: 46.132992 | Val Loss: 48.611275 | Time: (4) s
# Epoch [2/14] | Train Loss: 47.170135 | Val Loss: 50.173713 | Time: (4) s
# Epoch [3/14] | Train Loss: 46.885651 | Val Loss: 78.240243 | Time: (4) s
# Epoch [4/14] | Train Loss: 47.296413 | Val Loss: 57.349915 | Time: (4) s
# Epoch [5/14] | Train Loss: 46.593365 | Val Loss: 48.324251 | Time: (4) s
# Epoch [6/14] | Train Loss: 47.040333 | Val Loss: 53.652550 | Time: (4) s
# Epoch [7/14] | Train Loss: 47.060033 | Val Loss: 78.681613 | Time: (4) s
# Epoch [8/14] | Train Loss: 47.125920 | Val Loss: 50.140973 | Time: (4) s
# Epoch [9/14] | Train Loss: 45.863236 | Val Loss: 52.001064 | Time: (5) s
# Epoch [10/14] | Train Loss: 46.699808 | Val Loss: 49.696387 | Time: (4) s
# Epoch [11/14] | Train Loss: 45.875267 | Val Loss: 76.531098 | Time: (4) s
# Epoch [12/14] | Train Loss: 46.699048 | Val Loss: 57.159442 | Time: (4) s
# 0it [00:00, ?it/s]
# Epoch [13/14] | Train Loss: 46.070626 | Val Loss: 54.731853 | Time: (4) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 6it [00:35,  5.92s/it]
# ...
# ========================================
# ========================================
# Testing: For epochs = 5 and model: ../../ATTN_PPR_MODELS/UCSD2/C2D_AE_128_3X3-_ADAM_MSE_UCSD2_NORMAL-{APE}/C2D_AE_128_3X3-_ADAM_MSE_UCSD2_NORMAL-{APE}.pth.tar
# Epoch [0/4] | Train Loss: 3.130172 | Val Loss: 2.767025 | Time: (2) s
# Epoch [1/4] | Train Loss: 2.671337 | Val Loss: 2.466367 | Time: (2) s
# Epoch [2/4] | Train Loss: 2.394483 | Val Loss: 2.458697 | Time: (1) s
# 0it [00:00, ?it/s]
# Epoch [3/4] | Train Loss: 2.132220 | Val Loss: 1.992092 | Time: (1) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 12it [00:12,  1.02s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.9269816419031272), ('auc_roc_score_agg_psnr', 0.8899234967548141), ('auc_roc_score_agg_squared', 0.8884852893847557), ('auc_roc_score_agg_ssim', 0.8301674891380142), ('auc_roc_score_mean_absolute', 0.9511407892859527), ('auc_roc_score_mean_psnr', 0.8873067101388324), ('auc_roc_score_mean_squared', 0.8870989412391959), ('auc_roc_score_mean_ssim', 0.8398142080944735), ('auc_roc_score_overall_absolute', 0.6632516225929304), ('auc_roc_score_overall_psnr', 0.6692273909778468), ('auc_roc_score_overall_squared', 0.6670013543957517), ('auc_roc_score_overall_ssim', 0.6313797403851311), ('eer_agg_absolute', 0.14138349514540652), ('eer_agg_psnr', 0.19337016574585633), ('eer_agg_squared', 0.19417475728195482), ('eer_agg_ssim', 0.21823204419889533), ('eer_overall_absolute', 0.47237569060737294), ('eer_overall_psnr', 0.45580110497237575), ('eer_overall_squared', 0.4608389402859546), ('eer_overall_ssim', 0.4623226950354736), ('pr_roc_score_agg_absolute', 0.6702211288096602), ('pr_roc_score_agg_psnr', 0.6572150979435305), ('pr_roc_score_agg_squared', 0.6561528211409732), ('pr_roc_score_agg_ssim', 0.6801374523736795), ('pr_roc_score_mean_absolute', nan), ('pr_roc_score_mean_psnr', nan), ('pr_roc_score_mean_squared', nan), ('pr_roc_score_mean_ssim', nan), ('pr_roc_score_overall_absolute', 0.7150723295487841), ('pr_roc_score_overall_psnr', 0.7130085961464441), ('pr_roc_score_overall_squared', 0.713818560897582), ('pr_roc_score_overall_ssim', 0.7350004902589966), ('precision_absolute_agg', 0.8971624530573393), ('precision_squared_agg', 0.8686642874564665), ('precision_ssim_agg', 0.854154852436699), ('precision_psnr_agg', 0.8692733453938163), ('recall_absolute_agg', 0.818407960199005), ('recall_squared_agg', 0.7791044776119403), ('recall_ssim_agg', 0.7970149253731343), ('recall_psnr_agg', 0.7975124378109453), ('f1-score_absolute_agg', 0.8366060337376016), ('f1-score_squared_agg', 0.8018651491473411), ('f1-score_ssim_agg', 0.8143121588728166), ('f1-score_psnr_agg', 0.8168027357566389), ('support_absolute_agg', 2010), ('support_squared_agg', 2010), ('support_ssim_agg', 2010), ('support_psnr_agg', 2010), ('conf_mat_absolute_agg', '1303,345,20,342'), ('conf_mat_squared_agg', '1253,395,49,313'), ('conf_mat_ssim_agg', '1324,324,84,278'), ('conf_mat_psnr_agg', '1298,350,57,305'), ('precision_absolute_overall', 0.8553453676699516), ('precision_squared_overall', 0.8469350058446955), ('precision_ssim_overall', 0.8019059700820615), ('precision_psnr_overall', 0.8499975483342144), ('recall_absolute_overall', 0.8656716417910447), ('recall_squared_overall', 0.8572139303482587), ('recall_ssim_overall', 0.7791044776119403), ('recall_psnr_overall', 0.8606965174129353), ('f1-score_absolute_overall', 0.8577183984282555), ('f1-score_squared_overall', 0.8501407930202562), ('f1-score_ssim_overall', 0.7887215143793228), ('f1-score_psnr_overall', 0.8528704441572859), ('support_absolute_overall', 2010), ('support_squared_overall', 2010), ('support_ssim_overall', 2010), ('support_psnr_overall', 2010), ('conf_mat_absolute_overall', '1559,89,181,181'), ('conf_mat_squared_overall', '1544,104,183,179'), ('conf_mat_ssim_overall', '1378,270,174,188'), ('conf_mat_psnr_overall', '1552,96,184,178')])
# ========================================
# ========================================
# Testing: For epochs = 10 and model: ../../ATTN_PPR_MODELS/UCSD2/C2D_AE_128_3X3-_ADAM_MSE_UCSD2_NORMAL-{APE}/C2D_AE_128_3X3-_ADAM_MSE_UCSD2_NORMAL-{APE}.pth.tar
# Epoch [0/6] | Train Loss: 1.918306 | Val Loss: 1.806231 | Time: (1) s
# Epoch [1/6] | Train Loss: 3.462945 | Val Loss: 27.869730 | Time: (1) s
# Epoch [2/6] | Train Loss: 1.861395 | Val Loss: 1.682426 | Time: (2) s
# Epoch [3/6] | Train Loss: 1.544198 | Val Loss: 1.426862 | Time: (2) s
# Epoch [4/6] | Train Loss: 1.352017 | Val Loss: 1.207718 | Time: (2) s
# 0it [00:00, ?it/s]
# Epoch [5/6] | Train Loss: 1.158253 | Val Loss: 1.069627 | Time: (2) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 12it [00:12,  1.01s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.8976844526095585), ('auc_roc_score_agg_psnr', 0.8665920184519659), ('auc_roc_score_agg_squared', 0.8649660730569113), ('auc_roc_score_agg_ssim', 0.8376015796813817), ('auc_roc_score_mean_absolute', 0.9111461458049512), ('auc_roc_score_mean_psnr', 0.8689246024005904), ('auc_roc_score_mean_squared', 0.8689518832544618), ('auc_roc_score_mean_ssim', 0.8340391462706778), ('auc_roc_score_overall_absolute', 0.6446504720270343), ('auc_roc_score_overall_psnr', 0.6391390200075096), ('auc_roc_score_overall_squared', 0.6368526390602371), ('auc_roc_score_overall_ssim', 0.6152577374886016), ('eer_agg_absolute', 0.17958656330739692), ('eer_agg_psnr', 0.20752427184551853), ('eer_agg_squared', 0.21177544500228204), ('eer_agg_ssim', 0.24278606965181063), ('eer_overall_absolute', 0.4723756906076859), ('eer_overall_psnr', 0.4585635359116409), ('eer_overall_squared', 0.46568961004972514), ('eer_overall_ssim', 0.4640883977900553), ('pr_roc_score_agg_absolute', 0.6543671394988422), ('pr_roc_score_agg_psnr', 0.6733485614167459), ('pr_roc_score_agg_squared', 0.6695708422710882), ('pr_roc_score_agg_ssim', 0.6803529440956184), ('pr_roc_score_mean_absolute', nan), ('pr_roc_score_mean_psnr', nan), ('pr_roc_score_mean_squared', nan), ('pr_roc_score_mean_ssim', nan), ('pr_roc_score_overall_absolute', 0.7195811775399198), ('pr_roc_score_overall_psnr', 0.7198913029405773), ('pr_roc_score_overall_squared', 0.7207268262749432), ('pr_roc_score_overall_ssim', 0.7393240876498601), ('precision_absolute_agg', 0.8877156946934931), ('precision_squared_agg', 0.8639959054010746), ('precision_ssim_agg', 0.8680443693728014), ('precision_psnr_agg', 0.8657247296250851), ('recall_absolute_agg', 0.799502487562189), ('recall_squared_agg', 0.7482587064676617), ('recall_ssim_agg', 0.7328358208955223), ('recall_psnr_agg', 0.7606965174129353), ('f1-score_absolute_agg', 0.8202370153331214), ('f1-score_squared_agg', 0.7760490280827456), ('f1-score_ssim_agg', 0.7632146049476394), ('f1-score_psnr_agg', 0.7865043104463735), ('support_absolute_agg', 2010), ('support_squared_agg', 2010), ('support_ssim_agg', 2010), ('support_psnr_agg', 2010), ('conf_mat_absolute_agg', '1272,376,27,335'), ('conf_mat_squared_agg', '1186,462,44,318'), ('conf_mat_ssim_agg', '1144,504,33,329'), ('conf_mat_psnr_agg', '1213,435,46,316'), ('precision_absolute_overall', 0.8539149462043442), ('precision_squared_overall', 0.8486900769960527), ('precision_ssim_overall', 0.7994836318562515), ('precision_psnr_overall', 0.8471421079195934), ('recall_absolute_overall', 0.8646766169154229), ('recall_squared_overall', 0.8597014925373134), ('recall_ssim_overall', 0.7800995024875622), ('recall_psnr_overall', 0.8572139303482587), ('f1-score_absolute_overall', 0.85624838193362), ('f1-score_squared_overall', 0.8516079662320318), ('f1-score_ssim_overall', 0.7884803055801148), ('f1-score_psnr_overall', 0.8503471714578703), ('support_absolute_overall', 2010), ('support_squared_overall', 2010), ('support_ssim_overall', 2010), ('support_psnr_overall', 2010), ('conf_mat_absolute_overall', '1560,88,184,178'), ('conf_mat_squared_overall', '1552,96,186,176'), ('conf_mat_ssim_overall', '1386,262,180,182'), ('conf_mat_psnr_overall', '1543,105,182,180')])
# ========================================
# ========================================
# Testing: For epochs = 20 and model: ../../ATTN_PPR_MODELS/UCSD2/C2D_AE_128_3X3-_ADAM_MSE_UCSD2_NORMAL-{APE}/C2D_AE_128_3X3-_ADAM_MSE_UCSD2_NORMAL-{APE}.pth.tar
# Epoch [0/14] | Train Loss: 1.027851 | Val Loss: 0.939298 | Time: (2) s
# Epoch [1/14] | Train Loss: 0.891934 | Val Loss: 0.814227 | Time: (2) s
# Epoch [2/14] | Train Loss: 8.458933 | Val Loss: 247.299775 | Time: (1) s
# Epoch [3/14] | Train Loss: 1.874165 | Val Loss: 11.380833 | Time: (1) s
# Epoch [4/14] | Train Loss: 1.590837 | Val Loss: 1.473946 | Time: (1) s
# Epoch [5/14] | Train Loss: 1.390550 | Val Loss: 1.285204 | Time: (1) s
# Epoch [6/14] | Train Loss: 1.248116 | Val Loss: 1.168749 | Time: (2) s
# Epoch [7/14] | Train Loss: 1.142057 | Val Loss: 1.090796 | Time: (2) s
# Epoch [8/14] | Train Loss: 1.047666 | Val Loss: 0.990541 | Time: (1) s
# Epoch [9/14] | Train Loss: 0.956587 | Val Loss: 0.905068 | Time: (2) s
# Epoch [10/14] | Train Loss: 0.891487 | Val Loss: 0.820306 | Time: (1) s
# Epoch [11/14] | Train Loss: 0.776595 | Val Loss: 0.731123 | Time: (1) s
# Epoch [12/14] | Train Loss: 0.705804 | Val Loss: 0.643632 | Time: (1) s
# 0it [00:00, ?it/s]
# Epoch [13/14] | Train Loss: 0.625633 | Val Loss: 0.562304 | Time: (1) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 12it [00:12,  1.01s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.8991628895564019), ('auc_roc_score_agg_psnr', 0.8698020034329239), ('auc_roc_score_agg_squared', 0.8691264817894115), ('auc_roc_score_agg_ssim', 0.835960548195033), ('auc_roc_score_mean_absolute', 0.9107704612070524), ('auc_roc_score_mean_psnr', 0.8806818060286499), ('auc_roc_score_mean_squared', 0.8808014230070398), ('auc_roc_score_mean_ssim', 0.85441946388999), ('auc_roc_score_overall_absolute', 0.6480666335890146), ('auc_roc_score_overall_psnr', 0.6415762618677251), ('auc_roc_score_overall_squared', 0.6390937617336265), ('auc_roc_score_overall_ssim', 0.6211211983049938), ('eer_agg_absolute', 0.1771844660176888), ('eer_agg_psnr', 0.1923543689317977), ('eer_agg_squared', 0.1961325966850829), ('eer_agg_ssim', 0.2486187845301501), ('eer_overall_absolute', 0.47391675063948524), ('eer_overall_psnr', 0.4553455019556715), ('eer_overall_squared', 0.4640737844427066), ('eer_overall_ssim', 0.4640883977900782), ('pr_roc_score_agg_absolute', 0.6528090386309571), ('pr_roc_score_agg_psnr', 0.6689153381932527), ('pr_roc_score_agg_squared', 0.6659490305760412), ('pr_roc_score_agg_ssim', 0.679505456923941), ('pr_roc_score_mean_absolute', nan), ('pr_roc_score_mean_psnr', nan), ('pr_roc_score_mean_squared', nan), ('pr_roc_score_mean_ssim', nan), ('pr_roc_score_overall_absolute', 0.7184353607077515), ('pr_roc_score_overall_psnr', 0.7191262140519465), ('pr_roc_score_overall_squared', 0.7200343357108412), ('pr_roc_score_overall_ssim', 0.7373153962549437), ('precision_absolute_agg', 0.8908684658369955), ('precision_squared_agg', 0.8690614696025373), ('precision_ssim_agg', 0.8664302674049186), ('precision_psnr_agg', 0.8722741851769868), ('recall_absolute_agg', 0.7920398009950249), ('recall_squared_agg', 0.7910447761194029), ('recall_ssim_agg', 0.7318407960199005), ('recall_psnr_agg', 0.7855721393034826), ('f1-score_absolute_agg', 0.8142798339073405), ('f1-score_squared_agg', 0.8115851436246778), ('f1-score_ssim_agg', 0.762307211110958), ('f1-score_psnr_agg', 0.8074722495392149), ('support_absolute_agg', 2010), ('support_squared_agg', 2010), ('support_ssim_agg', 2010), ('support_psnr_agg', 2010), ('conf_mat_absolute_agg', '1249,399,19,343'), ('conf_mat_squared_agg', '1282,366,54,308'), ('conf_mat_ssim_agg', '1144,504,35,327'), ('conf_mat_psnr_agg', '1263,385,46,316'), ('precision_absolute_overall', 0.853068882916198), ('precision_squared_overall', 0.8490494970112078), ('precision_ssim_overall', 0.8022907970209316), ('precision_psnr_overall', 0.8489614113362762), ('recall_absolute_overall', 0.863681592039801), ('recall_squared_overall', 0.8597014925373134), ('recall_ssim_overall', 0.7820895522388059), ('recall_psnr_overall', 0.8592039800995025), ('f1-score_absolute_overall', 0.8556105228494146), ('f1-score_squared_overall', 0.8520294441803762), ('f1-score_ssim_overall', 0.7907385881254855), ('f1-score_psnr_overall', 0.8520243531677413), ('support_absolute_overall', 2010), ('support_squared_overall', 2010), ('support_ssim_overall', 2010), ('support_psnr_overall', 2010), ('conf_mat_absolute_overall', '1557,91,183,179'), ('conf_mat_squared_overall', '1550,98,184,178'), ('conf_mat_ssim_overall', '1386,262,176,186'), ('conf_mat_psnr_overall', '1547,101,182,180')])
# ========================================
# ----------------------------------------
# ----------------------------------------
# [INFO]: COMPLETED: UCSD2
# ----------------------------------------

# %%
print("DONE")
# Out:
# DONE

# %% [markdown]
# # SVDD Attention Fine Tuning

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    
    for lr in [1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4]:
        INFO("SVDD Fine Tuning Learning Rate: %s"%lr)
        SVDD_RESULTS = dict()
        for DATA_MODELS_PATH in read_directory_contents(MODELS_PATH):
            DATASET = ModelParser.getDatasetType(DATA_MODELS_PATH)
            INFO(DATASET)
            SVDD_RESULTS[DATASET] = dict()
            for MODEL_DIR in read_directory_contents(DATA_MODELS_PATH):
                if "softmax" not in MODEL_DIR.lower(): continue
                MODEL_PATH = join_paths([MODEL_DIR, MODEL_DIR.split("/")[-1] + ".pth.tar"])
                MODEL = get_model_att_ppr(MODEL_PATH, channels = dataset_channels[DATASET], att_channels = get_att_channels(MODEL_PATH))
                
                load_model(MODEL, MODEL_PATH)
                MODEL_NAME = MODEL.__name__
                if dataset_channels[DATASET] != get_att_channels(MODEL_PATH): continue

                # if replace_model_name(MODEL_NAME) != replace_model_name("Softmax Attention CAE"): continue
                print(MODEL_DIR)
                svdd_ft = SVDD_FineTuner(
                    model = MODEL,
                    model_path = MODEL_PATH,
                    dataset_type = DATASET.lower(),
                    lr = lr,
                    testOriginal = True,
                    returnResults = True,
                )
                SVDD_RESULTS[DATASET][MODEL_NAME] = svdd_ft.results
                del MODEL, svdd_ft
            print("-"*40)
            INFO("COMPLETED: " + DATASET)
        dump_pickle(SVDD_RESULTS, join_paths([SAVE_PATH, "Attention_SVDD/SVDD_results_LR_%s.pkl"%(lr)]))
        del SVDD_RESULTS
# Out:
# 0it [00:00, ?it/s]
# ----------------------------------------
# [INFO]: SVDD Fine Tuning Learning Rate: 1e-07
# ----------------------------------------
# ----------------------------------------
# [INFO]: AVENUE
# ----------------------------------------
# ../../ATTN_PPR_MODELS/AVENUE/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_AVENUE_NORMAL-{APE}
# 21it [01:22,  3.94s/it]
# 21it [01:25,  4.09s/it]
# 0it [00:00, ?it/s]
# OrderedDict([('auc_roc_score_agg_absolute', 0.8502527363391763), ('auc_roc_score_agg_psnr', 0.8596221463481708), ('auc_roc_score_agg_squared', 0.8967315874576205), ('auc_roc_score_agg_ssim', 0.815389464185553), ('auc_roc_score_mean_absolute', 0.8277660890176642), ('auc_roc_score_mean_psnr', 0.8380296021336524), ('auc_roc_score_mean_squared', 0.8380844331318845), ('auc_roc_score_mean_ssim', 0.8416038924873265), ('auc_roc_score_overall_absolute', 0.9478822972219574), ('auc_roc_score_overall_psnr', 0.9647113207243658), ('auc_roc_score_overall_squared', 0.965118050087598), ('auc_roc_score_overall_ssim', 0.9447601569298035), ('eer_agg_absolute', 0.22389396381876517), ('eer_agg_psnr', 0.19922974374154487), ('eer_agg_squared', 0.15758777557422265), ('eer_agg_ssim', 0.2567362650188717), ('eer_overall_absolute', 0.11041503523884104), ('eer_overall_psnr', 0.0920199188181383), ('eer_overall_squared', 0.09249970838722793), ('eer_overall_ssim', 0.12926506924093545), ('pr_roc_score_agg_absolute', 0.823523021859543), ('pr_roc_score_agg_psnr', 0.8529847921764606), ('pr_roc_score_agg_squared', 0.8966094493814093), ('pr_roc_score_agg_ssim', 0.7741368268124091), ('pr_roc_score_mean_absolute', nan), ('pr_roc_score_mean_psnr', nan), ('pr_roc_score_mean_squared', nan), ('pr_roc_score_mean_ssim', nan), ('pr_roc_score_overall_absolute', 0.9306026354687689), ('pr_roc_score_overall_psnr', 0.9523652001961042), ('pr_roc_score_overall_squared', 0.9531952631201582), ('pr_roc_score_overall_ssim', 0.9317022423441981), ('precision_absolute_agg', 0.7894992542414061), ('precision_squared_agg', 0.8544032400648671), ('precision_ssim_agg', 0.7468032059760298), ('precision_psnr_agg', 0.823521529218404), ('recall_absolute_agg', 0.7886322109109893), ('recall_squared_agg', 0.8546071521795876), ('recall_ssim_agg', 0.7447141738449491), ('recall_psnr_agg', 0.8236100234925607), ('f1-score_absolute_agg', 0.7864871489922227), ('f1-score_squared_agg', 0.8543096007407186), ('f1-score_ssim_agg', 0.7453105536036195), ('f1-score_psnr_agg', 0.8227972638717654), ('support_absolute_agg', 15324), ('support_squared_agg', 15324), ('support_ssim_agg', 15324), ('support_psnr_agg', 15324), ('conf_mat_absolute_agg', '7384,1189,2050,4701'), ('conf_mat_squared_agg', '7574,999,1229,5522'), ('conf_mat_ssim_agg', '6429,2144,1768,4983'), ('conf_mat_psnr_agg', '7453,1120,1583,5168'), ('precision_absolute_overall', 0.8962097130937743), ('precision_squared_overall', 0.9092305189704951), ('precision_ssim_overall', 0.8762659948675031), ('precision_psnr_overall', 0.9091864731129137), ('recall_absolute_overall', 0.8963064474027669), ('recall_squared_overall', 0.9091620986687549), ('recall_ssim_overall', 0.876337770817019), ('recall_psnr_overall', 0.9089010702166536), ('f1-score_absolute_overall', 0.8961916074326579), ('f1-score_squared_overall', 0.9091900500649311), ('f1-score_ssim_overall', 0.8762949040275506), ('f1-score_psnr_overall', 0.9089837679631543), ('support_absolute_overall', 15324), ('support_squared_overall', 15324), ('support_ssim_overall', 15324), ('support_psnr_overall', 15324), ('conf_mat_absolute_overall', '7844,729,860,5891'), ('conf_mat_squared_overall', '7857,716,676,6075'), ('conf_mat_ssim_overall', '7647,926,969,5782'), ('conf_mat_psnr_overall', '7813,760,636,6115')])
# ----------------------------------------
# [INFO]: Device set to GPU
# ----------------------------------------
# 16it [01:24,  5.25s/it]
#   1%|          | 113/15328 [00:00<00:13, 1126.95it/s]
# ----------------------------------------
# [INFO]: Created Dataset
# ----------------------------------------
# 100%|██████████| 15328/15328 [00:11<00:00, 1388.01it/s]
# ----------------------------------------
# [INFO]: Created Encodings
# ----------------------------------------
# INFO: SVDD C Initialized torch.Size([1, 1536])
# INFO: SVDD Initialized
# ----------------------------------------
# [INFO]: SVDD Ready
# ----------------------------------------
# ----------------------------------------
# [INFO]: Data Loaders Ready. Starting the training
# ----------------------------------------
# ========================================
# Testing: For epochs = 1 and model: ../../ATTN_PPR_MODELS/AVENUE/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_AVENUE_NORMAL-{APE}/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_AVENUE_NORMAL-{APE}.pth.tar
# 0it [00:00, ?it/s]
# Epoch [0/1] | Train Loss: 1704.113379 | Val Loss: 896.238038 | Time: (5) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 21it [01:26,  4.10s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.6345726559028292), ('auc_roc_score_agg_psnr', 0.6060107861378823), ('auc_roc_score_agg_squared', 0.6022086786681317), ('auc_roc_score_agg_ssim', 0.615422389566801), ('auc_roc_score_mean_absolute', 0.628720991921622), ('auc_roc_score_mean_psnr', 0.6328782951129692), ('auc_roc_score_mean_squared', 0.6333316035111302), ('auc_roc_score_mean_ssim', 0.6344958810717412), ('auc_roc_score_overall_absolute', 0.5868478203081422), ('auc_roc_score_overall_psnr', 0.6992532334854791), ('auc_roc_score_overall_squared', 0.6993979472400138), ('auc_roc_score_overall_ssim', 0.5842579961411853), ('eer_agg_absolute', 0.4074951858983689), ('eer_agg_psnr', 0.401263150424894), ('eer_agg_squared', 0.4051090633388041), ('eer_agg_ssim', 0.4264553399496392), ('eer_overall_absolute', 0.45667308546883795), ('eer_overall_psnr', 0.35880088650280617), ('eer_overall_squared', 0.35880088650516195), ('eer_overall_ssim', 0.4591912309291328), ('pr_roc_score_agg_absolute', 0.5290093865374826), ('pr_roc_score_agg_psnr', 0.5150184779551557), ('pr_roc_score_agg_squared', 0.5193442620746631), ('pr_roc_score_agg_ssim', 0.5939271346982239), ('pr_roc_score_mean_absolute', nan), ('pr_roc_score_mean_psnr', nan), ('pr_roc_score_mean_squared', nan), ('pr_roc_score_mean_ssim', nan), ('pr_roc_score_overall_absolute', 0.5651716506996509), ('pr_roc_score_overall_psnr', 0.564854272351649), ('pr_roc_score_overall_squared', 0.5650418638360701), ('pr_roc_score_overall_ssim', 0.5405583018886115), ('precision_absolute_agg', 0.7091520598393497), ('precision_squared_agg', 0.6128649852666845), ('precision_ssim_agg', 0.654768867420371), ('precision_psnr_agg', 0.6168316449245786), ('recall_absolute_agg', 0.5964500130514226), ('recall_squared_agg', 0.5918820151396502), ('recall_ssim_agg', 0.6290133124510572), ('recall_psnr_agg', 0.601409553641347), ('f1-score_absolute_agg', 0.5645567141084465), ('f1-score_squared_agg', 0.5907836219268847), ('f1-score_ssim_agg', 0.5821298804184478), ('f1-score_psnr_agg', 0.6018145186677167), ('support_absolute_agg', 15324), ('support_squared_agg', 15324), ('support_ssim_agg', 15324), ('support_psnr_agg', 15324), ('conf_mat_absolute_agg', '2876,5697,487,6264'), ('conf_mat_squared_agg', '4386,4187,2067,4684'), ('conf_mat_ssim_agg', '7822,751,4934,1817'), ('conf_mat_psnr_agg', '4679,3894,2214,4537'), ('precision_absolute_overall', 0.7335671710979388), ('precision_squared_overall', 0.670596227513988), ('precision_ssim_overall', 0.6698459284127145), ('precision_psnr_overall', 0.6709282684067581), ('recall_absolute_overall', 0.5682589402244844), ('recall_squared_overall', 0.6720830070477682), ('recall_ssim_overall', 0.5746541373009658), ('recall_psnr_overall', 0.6723440354998695), ('f1-score_absolute_overall', 0.5137778494139028), ('f1-score_squared_overall', 0.6654300171751412), ('f1-score_ssim_overall', 0.5429205741209971), ('f1-score_psnr_overall', 0.6655844374072462), ('support_absolute_overall', 15324), ('support_squared_overall', 15324), ('support_ssim_overall', 15324), ('support_psnr_overall', 15324), ('conf_mat_absolute_overall', '2162,6411,205,6546'), ('conf_mat_squared_overall', '6765,1808,3217,3534'), ('conf_mat_ssim_overall', '2764,5809,709,6042'), ('conf_mat_psnr_overall', '6775,1798,3223,3528')])
# ========================================
# ========================================
# Testing: For epochs = 2 and model: ../../ATTN_PPR_MODELS/AVENUE/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_AVENUE_NORMAL-{APE}/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_AVENUE_NORMAL-{APE}.pth.tar
# 0it [00:00, ?it/s]
# Epoch [0/1] | Train Loss: 893.502030 | Val Loss: 893.961606 | Time: (5) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 21it [01:26,  4.12s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.6341253399943876), ('auc_roc_score_agg_psnr', 0.6055794871419181), ('auc_roc_score_agg_squared', 0.6018165666813353), ('auc_roc_score_agg_ssim', 0.6150048094796899), ('auc_roc_score_mean_absolute', 0.6297030502299444), ('auc_roc_score_mean_psnr', 0.6333994058974566), ('auc_roc_score_mean_squared', 0.6337712567342453), ('auc_roc_score_mean_ssim', 0.6355271679708033), ('auc_roc_score_overall_absolute', 0.5855563768278782), ('auc_roc_score_overall_psnr', 0.6963970482368066), ('auc_roc_score_overall_squared', 0.6965444919505338), ('auc_roc_score_overall_ssim', 0.5847924893224471), ('eer_agg_absolute', 0.40720867840930064), ('eer_agg_psnr', 0.40067654263287844), ('eer_agg_squared', 0.405225708619718), ('eer_agg_ssim', 0.42612629453771633), ('eer_overall_absolute', 0.45841595707558436), ('eer_overall_psnr', 0.3602429269737852), ('eer_overall_squared', 0.3601812004530011), ('eer_overall_ssim', 0.4582993117911235), ('pr_roc_score_agg_absolute', 0.5293073316744246), ('pr_roc_score_agg_psnr', 0.5149692570058416), ('pr_roc_score_agg_squared', 0.5191601544038453), ('pr_roc_score_agg_ssim', 0.5936963437456646), ('pr_roc_score_mean_absolute', nan), ('pr_roc_score_mean_psnr', nan), ('pr_roc_score_mean_squared', nan), ('pr_roc_score_mean_ssim', nan), ('pr_roc_score_overall_absolute', 0.5654701653837233), ('pr_roc_score_overall_psnr', 0.5633601017482268), ('pr_roc_score_overall_squared', 0.5635311900330792), ('pr_roc_score_overall_ssim', 0.5400821837350511), ('precision_absolute_agg', 0.6916568881116293), ('precision_squared_agg', 0.6143933201253435), ('precision_ssim_agg', 0.6517338503786986), ('precision_psnr_agg', 0.6188132325514268), ('recall_absolute_agg', 0.5994518402505873), ('recall_squared_agg', 0.5927956147220047), ('recall_ssim_agg', 0.6284912555468546), ('recall_psnr_agg', 0.6004959540589925), ('f1-score_absolute_agg', 0.5742856119048083), ('f1-score_squared_agg', 0.591528984197399), ('f1-score_ssim_agg', 0.5831422597894332), ('f1-score_psnr_agg', 0.6002303283371696), ('support_absolute_agg', 15324), ('support_squared_agg', 15324), ('support_ssim_agg', 15324), ('support_psnr_agg', 15324), ('conf_mat_absolute_agg', '3110,5463,675,6076'), ('conf_mat_squared_agg', '4373,4200,2040,4711'), ('conf_mat_ssim_agg', '7781,792,4901,1850'), ('conf_mat_psnr_agg', '4560,4013,2109,4642'), ('precision_absolute_overall', 0.7330591467453925), ('precision_squared_overall', 0.6720625205634672), ('precision_ssim_overall', 0.6804101921261189), ('precision_psnr_overall', 0.6720070856018271), ('recall_absolute_overall', 0.5683894544505351), ('recall_squared_overall', 0.6726050639519707), ('recall_ssim_overall', 0.5729574523623074), ('recall_psnr_overall', 0.6725398068389454), ('f1-score_absolute_overall', 0.5141119442550518), ('f1-score_squared_overall', 0.6643639597290883), ('f1-score_ssim_overall', 0.5365290950010916), ('f1-score_psnr_overall', 0.6642739107661767), ('support_absolute_overall', 15324), ('support_squared_overall', 15324), ('support_ssim_overall', 15324), ('support_psnr_overall', 15324), ('conf_mat_absolute_overall', '2167,6406,208,6543'), ('conf_mat_squared_overall', '6878,1695,3322,3429'), ('conf_mat_ssim_overall', '2621,5952,592,6159'), ('conf_mat_psnr_overall', '6879,1694,3324,3427')])
# ========================================
# ========================================
# Testing: For epochs = 5 and model: ../../ATTN_PPR_MODELS/AVENUE/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_AVENUE_NORMAL-{APE}/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_AVENUE_NORMAL-{APE}.pth.tar
# Epoch [0/4] | Train Loss: 893.171391 | Val Loss: 893.124387 | Time: (5) s
# Epoch [1/4] | Train Loss: 892.584289 | Val Loss: 892.801039 | Time: (5) s
# Epoch [2/4] | Train Loss: 891.935208 | Val Loss: 892.271865 | Time: (5) s
# 0it [00:00, ?it/s]
# Epoch [3/4] | Train Loss: 891.404967 | Val Loss: 891.592464 | Time: (5) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 21it [01:26,  4.12s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.6347543018584647), ('auc_roc_score_agg_psnr', 0.6055732151470645), ('auc_roc_score_agg_squared', 0.6018261042602862), ('auc_roc_score_agg_ssim', 0.6107542630170198), ('auc_roc_score_mean_absolute', 0.6313211333428285), ('auc_roc_score_mean_psnr', 0.6341985652115256), ('auc_roc_score_mean_squared', 0.6346194357658818), ('auc_roc_score_mean_ssim', 0.6335179197783511), ('auc_roc_score_overall_absolute', 0.5885846358967898), ('auc_roc_score_overall_psnr', 0.697225469904161), ('auc_roc_score_overall_squared', 0.6973764210971038), ('auc_roc_score_overall_ssim', 0.5827212278153884), ('eer_agg_absolute', 0.4079222135216157), ('eer_agg_psnr', 0.40114312376176686), ('eer_agg_squared', 0.40522570862139373), ('eer_agg_ssim', 0.4290213460876848), ('eer_overall_absolute', 0.4563163420038787), ('eer_overall_psnr', 0.3587836074132081), ('eer_overall_squared', 0.35861353873456087), ('eer_overall_ssim', 0.46063221742571536), ('pr_roc_score_agg_absolute', 0.5306132383765088), ('pr_roc_score_agg_psnr', 0.51487963712), ('pr_roc_score_agg_squared', 0.5188762594417748), ('pr_roc_score_agg_ssim', 0.5934563359576799), ('pr_roc_score_mean_absolute', nan), ('pr_roc_score_mean_psnr', nan), ('pr_roc_score_mean_squared', nan), ('pr_roc_score_mean_ssim', nan), ('pr_roc_score_overall_absolute', 0.5617259693287944), ('pr_roc_score_overall_psnr', 0.56494839408803), ('pr_roc_score_overall_squared', 0.5651274139672353), ('pr_roc_score_overall_ssim', 0.5410091685929097), ('precision_absolute_agg', 0.690697748717967), ('precision_squared_agg', 0.6166284691838362), ('precision_ssim_agg', 0.6498001080470354), ('precision_psnr_agg', 0.619247427072237), ('recall_absolute_agg', 0.6004306969459671), ('recall_squared_agg', 0.5946228138867137), ('recall_ssim_agg', 0.628164969981728), ('recall_psnr_agg', 0.6019316105455494), ('f1-score_absolute_agg', 0.5760527991437985), ('f1-score_squared_agg', 0.5932660258124752), ('f1-score_ssim_agg', 0.5838586278882741), ('f1-score_psnr_agg', 0.6019192290188304), ('support_absolute_agg', 15324), ('support_squared_agg', 15324), ('support_ssim_agg', 15324), ('support_psnr_agg', 15324), ('conf_mat_absolute_agg', '3143,5430,693,6058'), ('conf_mat_squared_agg', '4376,4197,2015,4736'), ('conf_mat_ssim_agg', '7753,820,4878,1873'), ('conf_mat_psnr_agg', '4610,3963,2137,4614'), ('precision_absolute_overall', 0.7322860053508745), ('precision_squared_overall', 0.674226873005069), ('precision_ssim_overall', 0.6794891523095307), ('precision_psnr_overall', 0.6741616358529784), ('recall_absolute_overall', 0.5683894544505351), ('recall_squared_overall', 0.6745627773427304), ('recall_ssim_overall', 0.5728921952492821), ('recall_psnr_overall', 0.674497520229705), ('f1-score_absolute_overall', 0.5142986456549833), ('f1-score_squared_overall', 0.6662941434115864), ('f1-score_ssim_overall', 0.5367314960477133), ('f1-score_psnr_overall', 0.6662195267473512), ('support_absolute_overall', 15324), ('support_squared_overall', 15324), ('support_ssim_overall', 15324), ('support_psnr_overall', 15324), ('conf_mat_absolute_overall', '2171,6402,212,6539'), ('conf_mat_squared_overall', '6898,1675,3312,3439'), ('conf_mat_ssim_overall', '2628,5945,600,6151'), ('conf_mat_psnr_overall', '6898,1675,3313,3438')])
# ========================================
# ========================================
# Testing: For epochs = 10 and model: ../../ATTN_PPR_MODELS/AVENUE/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_AVENUE_NORMAL-{APE}/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_AVENUE_NORMAL-{APE}.pth.tar
# Epoch [0/6] | Train Loss: 890.627282 | Val Loss: 891.154437 | Time: (5) s
# Epoch [1/6] | Train Loss: 890.096170 | Val Loss: 890.983088 | Time: (5) s
# Epoch [2/6] | Train Loss: 889.594494 | Val Loss: 889.416771 | Time: (5) s
# Epoch [3/6] | Train Loss: 888.771021 | Val Loss: 888.579135 | Time: (5) s
# Epoch [4/6] | Train Loss: 888.198292 | Val Loss: 889.553113 | Time: (5) s
# 0it [00:00, ?it/s]
# Epoch [5/6] | Train Loss: 887.225292 | Val Loss: 887.514916 | Time: (5) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 21it [01:25,  4.09s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.6351905251479089), ('auc_roc_score_agg_psnr', 0.6062455107937662), ('auc_roc_score_agg_squared', 0.6024822102122832), ('auc_roc_score_agg_ssim', 0.6050580649361571), ('auc_roc_score_mean_absolute', 0.6338335881181428), ('auc_roc_score_mean_psnr', 0.6350953499592674), ('auc_roc_score_mean_squared', 0.6354988735516247), ('auc_roc_score_mean_ssim', 0.6294429395833916), ('auc_roc_score_overall_absolute', 0.5971388248006011), ('auc_roc_score_overall_psnr', 0.6997897568579124), ('auc_roc_score_overall_squared', 0.6999372178498624), ('auc_roc_score_overall_ssim', 0.5792100251427513), ('eer_agg_absolute', 0.40989151988836225), ('eer_agg_psnr', 0.4007931879146995), ('eer_agg_squared', 0.40475912749193765), ('eer_agg_ssim', 0.43497203249307753), ('eer_overall_absolute', 0.4507173684813076), ('eer_overall_psnr', 0.356687898089668), ('eer_overall_squared', 0.3568360242927411), ('eer_overall_ssim', 0.46028228158271306), ('pr_roc_score_agg_absolute', 0.532390483862782), ('pr_roc_score_agg_psnr', 0.5130675807943027), ('pr_roc_score_agg_squared', 0.5165569100549476), ('pr_roc_score_agg_ssim', 0.5920571866442472), ('pr_roc_score_mean_absolute', nan), ('pr_roc_score_mean_psnr', nan), ('pr_roc_score_mean_squared', nan), ('pr_roc_score_mean_ssim', nan), ('pr_roc_score_overall_absolute', 0.5515592682257643), ('pr_roc_score_overall_psnr', 0.5688206131866161), ('pr_roc_score_overall_squared', 0.5690024917849754), ('pr_roc_score_overall_ssim', 0.5435813985641593), ('precision_absolute_agg', 0.6885282670920798), ('precision_squared_agg', 0.6180556764551892), ('precision_ssim_agg', 0.651572971864295), ('precision_psnr_agg', 0.6228599826169553), ('recall_absolute_agg', 0.6049986948577395), ('recall_squared_agg', 0.5952753850169669), ('recall_ssim_agg', 0.6292090837901331), ('recall_psnr_agg', 0.604280866614461), ('f1-score_absolute_agg', 0.5835283516615367), ('f1-score_squared_agg', 0.5936970311413989), ('f1-score_ssim_agg', 0.5849431163562133), ('f1-score_psnr_agg', 0.6039841183569978), ('support_absolute_agg', 15324), ('support_squared_agg', 15324), ('support_ssim_agg', 15324), ('support_psnr_agg', 15324), ('conf_mat_absolute_agg', '3275,5298,755,5996'), ('conf_mat_squared_agg', '4356,4217,1985,4766'), ('conf_mat_ssim_agg', '7763,810,4872,1879'), ('conf_mat_psnr_agg', '4584,3989,2075,4676'), ('precision_absolute_overall', 0.7432956349793058), ('precision_squared_overall', 0.6771714298068605), ('precision_ssim_overall', 0.6667177520897183), ('precision_psnr_overall', 0.6771621625396017), ('recall_absolute_overall', 0.5665622552858262), ('recall_squared_overall', 0.6778256329939963), ('recall_ssim_overall', 0.5714565387627252), ('recall_psnr_overall', 0.6778256329939963), ('f1-score_absolute_overall', 0.508755329832589), ('f1-score_squared_overall', 0.6704864893364624), ('f1-score_ssim_overall', 0.5388534671218324), ('f1-score_psnr_overall', 0.6705009475482022), ('support_absolute_overall', 15324), ('support_squared_overall', 15324), ('support_ssim_overall', 15324), ('support_psnr_overall', 15324), ('conf_mat_absolute_overall', '2084,6489,153,6598'), ('conf_mat_squared_overall', '6866,1707,3230,3521'), ('conf_mat_ssim_overall', '2721,5852,715,6036'), ('conf_mat_psnr_overall', '6865,1708,3229,3522')])
# ========================================
# ========================================
# Testing: For epochs = 20 and model: ../../ATTN_PPR_MODELS/AVENUE/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_AVENUE_NORMAL-{APE}/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_AVENUE_NORMAL-{APE}.pth.tar
# Epoch [0/14] | Train Loss: 886.355593 | Val Loss: 886.294684 | Time: (5) s
# Epoch [1/14] | Train Loss: 885.596487 | Val Loss: 886.555812 | Time: (5) s
# Epoch [2/14] | Train Loss: 884.641589 | Val Loss: 884.842526 | Time: (5) s
# Epoch [3/14] | Train Loss: 884.054188 | Val Loss: 884.989758 | Time: (5) s
# Epoch [4/14] | Train Loss: 883.298404 | Val Loss: 884.279650 | Time: (5) s
# Epoch [5/14] | Train Loss: 882.703822 | Val Loss: 882.372132 | Time: (5) s
# Epoch [6/14] | Train Loss: 881.594065 | Val Loss: 882.822304 | Time: (5) s
# Epoch [7/14] | Train Loss: 881.276634 | Val Loss: 881.221024 | Time: (5) s
# Epoch [8/14] | Train Loss: 880.270977 | Val Loss: 880.065974 | Time: (5) s
# Epoch [9/14] | Train Loss: 879.572769 | Val Loss: 879.226666 | Time: (5) s
# Epoch [10/14] | Train Loss: 878.872851 | Val Loss: 878.795141 | Time: (5) s
# Epoch [11/14] | Train Loss: 877.952302 | Val Loss: 877.576498 | Time: (5) s
# Epoch [12/14] | Train Loss: 877.124042 | Val Loss: 877.492459 | Time: (5) s
# 0it [00:00, ?it/s]
# Epoch [13/14] | Train Loss: 876.426704 | Val Loss: 876.148677 | Time: (5) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 21it [01:26,  4.11s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.6327516521738951), ('auc_roc_score_agg_psnr', 0.6113060689774642), ('auc_roc_score_agg_squared', 0.6074203435487773), ('auc_roc_score_agg_ssim', 0.5909695057856388), ('auc_roc_score_mean_absolute', 0.6376726285488632), ('auc_roc_score_mean_psnr', 0.6360944600155762), ('auc_roc_score_mean_squared', 0.6364350766444314), ('auc_roc_score_mean_ssim', 0.620748789917784), ('auc_roc_score_overall_absolute', 0.6100512898858484), ('auc_roc_score_overall_psnr', 0.7069663530628923), ('auc_roc_score_overall_squared', 0.707098617857945), ('auc_roc_score_overall_ssim', 0.5771022115554921), ('eer_agg_absolute', 0.4105913915780035), ('eer_agg_psnr', 0.4018429954505465), ('eer_agg_squared', 0.4064583024737063), ('eer_agg_ssim', 0.450208822761681), ('eer_overall_absolute', 0.44458574644650833), ('eer_overall_psnr', 0.35313286920445325), ('eer_overall_squared', 0.35308526770108883), ('eer_overall_ssim', 0.4661145456656979), ('pr_roc_score_agg_absolute', 0.5248088692043167), ('pr_roc_score_agg_psnr', 0.5100136838335232), ('pr_roc_score_agg_squared', 0.5110814953918232), ('pr_roc_score_agg_ssim', 0.5807063256384332), ('pr_roc_score_mean_absolute', nan), ('pr_roc_score_mean_psnr', nan), ('pr_roc_score_mean_squared', nan), ('pr_roc_score_mean_ssim', nan), ('pr_roc_score_overall_absolute', 0.5359129358917627), ('pr_roc_score_overall_psnr', 0.5780854641835734), ('pr_roc_score_overall_squared', 0.5782685064266799), ('pr_roc_score_overall_ssim', 0.5447087024944823), ('precision_absolute_agg', 0.6789793636729594), ('precision_squared_agg', 0.6202173136503263), ('precision_ssim_agg', 0.6472761273000623), ('precision_psnr_agg', 0.6287469097472973), ('recall_absolute_agg', 0.6166797180892717), ('recall_squared_agg', 0.6031062385800052), ('recall_ssim_agg', 0.6269250848342469), ('recall_psnr_agg', 0.6062385800052206), ('f1-score_absolute_agg', 0.6034260076231129), ('f1-score_squared_agg', 0.6031490201590579), ('f1-score_ssim_agg', 0.5829131752793532), ('f1-score_psnr_agg', 0.6049377180784395), ('support_absolute_agg', 15324), ('support_squared_agg', 15324), ('support_ssim_agg', 15324), ('support_psnr_agg', 15324), ('conf_mat_absolute_agg', '3697,4876,998,5753'), ('conf_mat_squared_agg', '4628,3945,2137,4614'), ('conf_mat_ssim_agg', '7733,840,4877,1874'), ('conf_mat_psnr_agg', '4467,4106,1928,4823'), ('precision_absolute_overall', 0.7265054727812763), ('precision_squared_overall', 0.6830800989879781), ('precision_ssim_overall', 0.6803581875008557), ('precision_psnr_overall', 0.6826190264828654), ('recall_absolute_overall', 0.5660401983816236), ('recall_squared_overall', 0.6844166014095536), ('recall_ssim_overall', 0.5698903680501175), ('recall_psnr_overall', 0.684090315844427), ('f1-score_absolute_overall', 0.5118890421640099), ('f1-score_squared_overall', 0.6790770431000069), ('f1-score_ssim_overall', 0.5315428809263363), ('f1-score_psnr_overall', 0.6789961656728445), ('support_absolute_overall', 15324), ('support_squared_overall', 15324), ('support_ssim_overall', 15324), ('support_psnr_overall', 15324), ('conf_mat_absolute_overall', '2158,6415,235,6516'), ('conf_mat_squared_overall', '6777,1796,3040,3711'), ('conf_mat_ssim_overall', '2553,6020,571,6180'), ('conf_mat_psnr_overall', '6754,1819,3022,3729')])
# ========================================
# ----------------------------------------
# ----------------------------------------
# [INFO]: COMPLETED: AVENUE
# ----------------------------------------
# ----------------------------------------
# [INFO]: HAM10000
# ----------------------------------------
# ../../ATTN_PPR_MODELS/HAM10000/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_HAM10000_NORMAL-{APE}
# 6it [00:25,  4.25s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.7014901708105923), ('auc_roc_score_agg_psnr', 0.736696735395189), ('auc_roc_score_agg_squared', 0.6740650899535072), ('auc_roc_score_agg_ssim', 0.6912407772387306), ('auc_roc_score_mean_absolute', 0.7531339105587049), ('auc_roc_score_mean_psnr', 0.767981010700498), ('auc_roc_score_mean_squared', 0.767981010700498), ('auc_roc_score_mean_ssim', 0.6869482174819034), ('auc_roc_score_overall_absolute', 0.7639781685870226), ('auc_roc_score_overall_psnr', 0.7722255912674347), ('auc_roc_score_overall_squared', 0.7722255912674348), ('auc_roc_score_overall_ssim', 0.7172778956943602), ('eer_agg_absolute', 0.3444511825359091), ('eer_agg_psnr', 0.31121104047139087), ('eer_agg_squared', 0.37234687689446166), ('eer_agg_ssim', 0.3411158277751094), ('eer_overall_absolute', 0.28), ('eer_overall_psnr', 0.2783505154638535), ('eer_overall_squared', 0.27918781725888325), ('eer_overall_ssim', 0.3292904790774), ('pr_roc_score_agg_absolute', 0.6148190683739116), ('pr_roc_score_agg_psnr', 0.5952198658016189), ('pr_roc_score_agg_squared', 0.623079742111259), ('pr_roc_score_agg_ssim', 0.6165363961152199), ('pr_roc_score_mean_absolute', 0.7386357765259368), ('pr_roc_score_mean_psnr', 0.7501727411909846), ('pr_roc_score_mean_squared', 0.7501726023930925), ('pr_roc_score_mean_ssim', 0.7050492136215661), ('pr_roc_score_overall_absolute', 0.5939635597251227), ('pr_roc_score_overall_psnr', 0.5855993854570554), ('pr_roc_score_overall_squared', 0.5855990634688713), ('pr_roc_score_overall_ssim', 0.6062703535237756), ('precision_absolute_agg', 0.7330313039100597), ('precision_squared_agg', 0.7194531650178602), ('precision_ssim_agg', 0.7269800768057713), ('precision_psnr_agg', 0.7559746939302185), ('recall_absolute_agg', 0.6956425077812362), ('recall_squared_agg', 0.7123165851489551), ('recall_ssim_agg', 0.6662961316140507), ('recall_psnr_agg', 0.7281013783903957), ('f1-score_absolute_agg', 0.7082099642322974), ('f1-score_squared_agg', 0.7155922918617023), ('f1-score_ssim_agg', 0.6836030187119172), ('f1-score_psnr_agg', 0.737765802866949), ('support_absolute_agg', 4498), ('support_squared_agg', 4498), ('support_ssim_agg', 4498), ('support_psnr_agg', 4498), ('conf_mat_absolute_agg', '2397,901,468,732'), ('conf_mat_squared_agg', '2605,693,601,599'), ('conf_mat_ssim_agg', '2223,1075,426,774'), ('conf_mat_psnr_agg', '2512,786,437,763'), ('precision_absolute_overall', 0.7773542322604966), ('precision_squared_overall', 0.7811758019428191), ('precision_ssim_overall', 0.747578859941534), ('precision_psnr_overall', 0.7811758019428191), ('recall_absolute_overall', 0.7349933303690529), ('recall_squared_overall', 0.7550022232103157), ('recall_ssim_overall', 0.7227656736327257), ('recall_psnr_overall', 0.7550022232103157), ('f1-score_absolute_overall', 0.7470839510137599), ('f1-score_squared_overall', 0.7636557231262774), ('f1-score_ssim_overall', 0.7318083532557645), ('f1-score_psnr_overall', 0.7636557231262774), ('support_absolute_overall', 4498), ('support_squared_overall', 4498), ('support_ssim_overall', 4498), ('support_psnr_overall', 4498), ('conf_mat_absolute_overall', '2448,850,342,858'), ('conf_mat_squared_overall', '2574,724,378,822'), ('conf_mat_ssim_overall', '2519,779,468,732'), ('conf_mat_psnr_overall', '2574,724,378,822')])
# ----------------------------------------
# [INFO]: Device set to GPU
# ----------------------------------------
# Epoch [2/4] | Train Loss: 1505.320407 | Val Loss: 1536.132124 | Time: (3) s
# 0it [00:00, ?it/s]
# Epoch [3/4] | Train Loss: 1498.379762 | Val Loss: 1511.857012 | Time: (3) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 6it [00:25,  4.30s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.626770896502931), ('auc_roc_score_agg_psnr', 0.5304133818475844), ('auc_roc_score_agg_squared', 0.5312450727713766), ('auc_roc_score_agg_ssim', 0.6799297554073176), ('auc_roc_score_mean_absolute', 0.6803925065115571), ('auc_roc_score_mean_psnr', 0.6015412815453526), ('auc_roc_score_mean_squared', 0.601541220984822), ('auc_roc_score_mean_ssim', 0.7076128116206709), ('auc_roc_score_overall_absolute', 0.624043359611886), ('auc_roc_score_overall_psnr', 0.5283558217101274), ('auc_roc_score_overall_squared', 0.5283565797453003), ('auc_roc_score_overall_ssim', 0.7113576409945421), ('eer_agg_absolute', 0.42409158785474205), ('eer_agg_psnr', 0.4833333333333333), ('eer_agg_squared', 0.4816666666666702), ('eer_agg_ssim', 0.36294724075137397), ('eer_overall_absolute', 0.42480291085398836), ('eer_overall_psnr', 0.48500000000000587), ('eer_overall_squared', 0.4861917666795717), ('eer_overall_ssim', 0.3308065494255141), ('pr_roc_score_agg_absolute', 0.64179319836427), ('pr_roc_score_agg_psnr', 0.7043176495237481), ('pr_roc_score_agg_squared', 0.7038100404036289), ('pr_roc_score_agg_ssim', 0.6152022582402064), ('pr_roc_score_mean_absolute', 0.7590672897496712), ('pr_roc_score_mean_psnr', 0.7369343499414156), ('pr_roc_score_mean_squared', 0.7369348775896264), ('pr_roc_score_mean_ssim', 0.7450674613190283), ('pr_roc_score_overall_absolute', 0.6430525016742928), ('pr_roc_score_overall_psnr', 0.7053641051202356), ('pr_roc_score_overall_squared', 0.7053647808976165), ('pr_roc_score_overall_ssim', 0.6020623497119422), ('precision_absolute_agg', 0.7003491396149781), ('precision_squared_agg', 0.6595286096771369), ('precision_ssim_agg', 0.7237658226508789), ('precision_psnr_agg', 0.6595286096771369), ('recall_absolute_agg', 0.7240995998221432), ('recall_squared_agg', 0.7180969319697643), ('recall_ssim_agg', 0.7203201422854602), ('recall_psnr_agg', 0.7180969319697643), ('f1-score_absolute_agg', 0.70755814069068), ('f1-score_squared_agg', 0.6635552390153754), ('f1-score_ssim_agg', 0.721967920001962), ('f1-score_psnr_agg', 0.6635552390153754), ('support_absolute_agg', 4498), ('support_squared_agg', 4498), ('support_ssim_agg', 4498), ('support_psnr_agg', 4498), ('conf_mat_absolute_agg', '2852,446,795,405'), ('conf_mat_squared_agg', '3061,237,1031,169'), ('conf_mat_ssim_agg', '2646,652,606,594'), ('conf_mat_psnr_agg', '3061,237,1031,169'), ('precision_absolute_overall', 0.69938322204257), ('precision_squared_overall', 0.6593291603874895), ('precision_ssim_overall', 0.7412649280173411), ('precision_psnr_overall', 0.6593291603874895), ('recall_absolute_overall', 0.7234326367274344), ('recall_squared_overall', 0.7180969319697643), ('recall_ssim_overall', 0.7092040907069809), ('recall_psnr_overall', 0.7180969319697643), ('f1-score_absolute_overall', 0.7066708652639835), ('f1-score_squared_overall', 0.6633266376376088), ('f1-score_ssim_overall', 0.7202710842573558), ('f1-score_psnr_overall', 0.6633266376376088), ('support_absolute_overall', 4498), ('support_squared_overall', 4498), ('support_ssim_overall', 4498), ('support_psnr_overall', 4498), ('conf_mat_absolute_overall', '2852,446,798,402'), ('conf_mat_squared_overall', '3062,236,1032,168'), ('conf_mat_ssim_overall', '2452,846,462,738'), ('conf_mat_psnr_overall', '3062,236,1032,168')])
# ========================================
# ========================================
# Testing: For epochs = 10 and model: ../../ATTN_PPR_MODELS/HAM10000/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_HAM10000_NORMAL-{APE}/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_HAM10000_NORMAL-{APE}.pth.tar
# Epoch [0/6] | Train Loss: 1497.962941 | Val Loss: 1497.267794 | Time: (3) s
# Epoch [1/6] | Train Loss: 1491.638182 | Val Loss: 1504.057857 | Time: (3) s
# Epoch [2/6] | Train Loss: 1487.870777 | Val Loss: 1500.127885 | Time: (3) s
# Epoch [3/6] | Train Loss: 1489.398765 | Val Loss: 1485.494574 | Time: (3) s
# Epoch [4/6] | Train Loss: 1480.992920 | Val Loss: 1494.620844 | Time: (3) s
# 0it [00:00, ?it/s]
# Epoch [5/6] | Train Loss: 1483.828510 | Val Loss: 1530.126455 | Time: (3) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 6it [00:25,  4.32s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.6276039771578735), ('auc_roc_score_agg_psnr', 0.5351879927228623), ('auc_roc_score_agg_squared', 0.5359939104507783), ('auc_roc_score_agg_ssim', 0.6719669749343036), ('auc_roc_score_mean_absolute', 0.6806203377070635), ('auc_roc_score_mean_psnr', 0.605277214831279), ('auc_roc_score_mean_squared', 0.6052764041957407), ('auc_roc_score_mean_ssim', 0.7009498598997245), ('auc_roc_score_overall_absolute', 0.624865069739236), ('auc_roc_score_overall_psnr', 0.5332011825348696), ('auc_roc_score_overall_squared', 0.5332004244996967), ('auc_roc_score_overall_ssim', 0.7057519708914494), ('eer_agg_absolute', 0.424018573237653), ('eer_agg_psnr', 0.48166666666666713), ('eer_agg_squared', 0.48150394178252964), ('eer_agg_ssim', 0.36750000000036087), ('eer_overall_absolute', 0.4232992441084927), ('eer_overall_psnr', 0.4839296543354673), ('eer_overall_squared', 0.4839296543346909), ('eer_overall_ssim', 0.32999999999999696), ('pr_roc_score_agg_absolute', 0.6410085654277959), ('pr_roc_score_agg_psnr', 0.7007303154325002), ('pr_roc_score_agg_squared', 0.7002235885197727), ('pr_roc_score_agg_ssim', 0.6191393911868215), ('pr_roc_score_mean_absolute', 0.7581637495177836), ('pr_roc_score_mean_psnr', 0.7368434158966175), ('pr_roc_score_mean_squared', 0.7368438045864019), ('pr_roc_score_mean_ssim', 0.7402975649146759), ('pr_roc_score_overall_absolute', 0.6422601187705405), ('pr_roc_score_overall_psnr', 0.7017735263416849), ('pr_roc_score_overall_squared', 0.7017732064025175), ('pr_roc_score_overall_ssim', 0.6046996007346161), ('precision_absolute_agg', 0.703382835731811), ('precision_squared_agg', 0.6475263206142555), ('precision_ssim_agg', 0.7133062436987172), ('precision_psnr_agg', 0.6468429091385574), ('recall_absolute_agg', 0.7269897732325478), ('recall_squared_agg', 0.43241440640284573), ('recall_ssim_agg', 0.6818586038239217), ('recall_psnr_agg', 0.43241440640284573), ('f1-score_absolute_agg', 0.7103245087814017), ('f1-score_squared_agg', 0.4398555197261493), ('f1-score_ssim_agg', 0.6934470268010797), ('f1-score_psnr_agg', 0.4400607997451892), ('support_absolute_agg', 4498), ('support_squared_agg', 4498), ('support_ssim_agg', 4498), ('support_psnr_agg', 4498), ('conf_mat_absolute_agg', '2861,437,791,409'), ('conf_mat_squared_agg', '1040,2258,295,905'), ('conf_mat_ssim_agg', '2402,896,535,665'), ('conf_mat_psnr_agg', '1042,2256,297,903'), ('precision_absolute_overall', 0.7030625079065138), ('precision_squared_overall', 0.6565409625072636), ('precision_ssim_overall', 0.7373577140165736), ('precision_psnr_overall', 0.6565409625072636), ('recall_absolute_overall', 0.7267674522009782), ('recall_squared_overall', 0.7152067585593597), ('recall_ssim_overall', 0.6854157403290351), ('recall_psnr_overall', 0.7152067585593597), ('f1-score_absolute_overall', 0.7100289061219384), ('f1-score_squared_overall', 0.6627135824321948), ('f1-score_ssim_overall', 0.7007954854954823), ('f1-score_psnr_overall', 0.6627135824321948), ('support_absolute_overall', 4498), ('support_squared_overall', 4498), ('support_ssim_overall', 4498), ('support_psnr_overall', 4498), ('conf_mat_absolute_overall', '2861,437,792,408'), ('conf_mat_squared_overall', '3043,255,1026,174'), ('conf_mat_ssim_overall', '2303,995,420,780'), ('conf_mat_psnr_overall', '3043,255,1026,174')])
# ========================================
# ========================================
# Testing: For epochs = 20 and model: ../../ATTN_PPR_MODELS/HAM10000/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_HAM10000_NORMAL-{APE}/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_HAM10000_NORMAL-{APE}.pth.tar
# Epoch [0/14] | Train Loss: 1479.329059 | Val Loss: 1506.325432 | Time: (3) s
# Epoch [1/14] | Train Loss: 1471.375742 | Val Loss: 1482.149935 | Time: (3) s
# Epoch [2/14] | Train Loss: 1473.097944 | Val Loss: 1485.473830 | Time: (3) s
# Epoch [3/14] | Train Loss: 1467.898670 | Val Loss: 1481.542736 | Time: (3) s
# Epoch [4/14] | Train Loss: 1464.132312 | Val Loss: 1475.376945 | Time: (3) s
# Epoch [5/14] | Train Loss: 1460.569446 | Val Loss: 1484.374494 | Time: (3) s
# Epoch [6/14] | Train Loss: 1458.841958 | Val Loss: 1457.253910 | Time: (3) s
# Epoch [7/14] | Train Loss: 1457.335962 | Val Loss: 1454.255174 | Time: (3) s
# Epoch [8/14] | Train Loss: 1454.257306 | Val Loss: 1451.004652 | Time: (3) s
# Epoch [9/14] | Train Loss: 1453.593035 | Val Loss: 1452.833793 | Time: (3) s
# Epoch [10/14] | Train Loss: 1446.286096 | Val Loss: 1452.960430 | Time: (3) s
# Epoch [11/14] | Train Loss: 1444.969385 | Val Loss: 1479.584260 | Time: (3) s
# Epoch [12/14] | Train Loss: 1444.371416 | Val Loss: 1451.804419 | Time: (3) s
# 0it [00:00, ?it/s]
# Epoch [13/14] | Train Loss: 1440.493691 | Val Loss: 1459.437299 | Time: (3) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 6it [00:25,  4.31s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.6319240196078432), ('auc_roc_score_agg_psnr', 0.5418520062664242), ('auc_roc_score_agg_squared', 0.5425360066707096), ('auc_roc_score_agg_ssim', 0.6677328431372549), ('auc_roc_score_mean_absolute', 0.6828915237503285), ('auc_roc_score_mean_psnr', 0.6098057515783789), ('auc_roc_score_mean_squared', 0.6098057515783789), ('auc_roc_score_mean_ssim', 0.6955528311435097), ('auc_roc_score_overall_absolute', 0.6291494845360824), ('auc_roc_score_overall_psnr', 0.5400682231655549), ('auc_roc_score_overall_squared', 0.5400682231655549), ('auc_roc_score_overall_ssim', 0.7017692540933899), ('eer_agg_absolute', 0.4166666666666733), ('eer_agg_psnr', 0.47749999999993525), ('eer_agg_squared', 0.4766666666667038), ('eer_agg_ssim', 0.37174044875690376), ('eer_overall_absolute', 0.4185454965892011), ('eer_overall_psnr', 0.47998787143715976), ('eer_overall_squared', 0.47998787143698074), ('eer_overall_ssim', 0.349999999999984), ('pr_roc_score_agg_absolute', 0.6383715699120995), ('pr_roc_score_agg_psnr', 0.6952791061927339), ('pr_roc_score_agg_squared', 0.6948481608036596), ('pr_roc_score_agg_ssim', 0.6213163217579527), ('pr_roc_score_mean_absolute', 0.7570071408489777), ('pr_roc_score_mean_psnr', 0.7361145221095465), ('pr_roc_score_mean_squared', 0.7361143105018236), ('pr_roc_score_mean_ssim', 0.7347058834637185), ('pr_roc_score_overall_absolute', 0.6396127365957125), ('pr_roc_score_overall_psnr', 0.6962192892786663), ('pr_roc_score_overall_squared', 0.6962188210254284), ('pr_roc_score_overall_ssim', 0.6066055907119207), ('precision_absolute_agg', 0.7081383677220988), ('precision_squared_agg', 0.6498297739163437), ('precision_ssim_agg', 0.7101148604458247), ('precision_psnr_agg', 0.6489932591320531), ('recall_absolute_agg', 0.7327701200533571), ('recall_squared_agg', 0.43330369052912404), ('recall_ssim_agg', 0.6885282347710093), ('recall_psnr_agg', 0.4330813694975545), ('f1-score_absolute_agg', 0.7144264741082678), ('f1-score_squared_agg', 0.44042408848101405), ('f1-score_ssim_agg', 0.6972230813094901), ('f1-score_psnr_agg', 0.44035939296571214), ('support_absolute_agg', 4498), ('support_squared_agg', 4498), ('support_ssim_agg', 4498), ('support_psnr_agg', 4498), ('conf_mat_absolute_agg', '2891,407,795,405'), ('conf_mat_squared_agg', '1039,2259,290,910'), ('conf_mat_ssim_agg', '2470,828,573,627'), ('conf_mat_psnr_agg', '1040,2258,292,908'), ('precision_absolute_overall', 0.7075893139806231), ('precision_squared_overall', 0.6543301120828702), ('precision_ssim_overall', 0.7361515859087805), ('precision_psnr_overall', 0.6543301120828702), ('recall_absolute_overall', 0.7325477990217875), ('recall_squared_overall', 0.41240551356158295), ('recall_ssim_overall', 0.7116496220542463), ('recall_psnr_overall', 0.41240551356158295), ('f1-score_absolute_overall', 0.713881851470337), ('f1-score_squared_overall', 0.40832138515476124), ('f1-score_ssim_overall', 0.7208226935627673), ('f1-score_psnr_overall', 0.40832138515476124), ('support_absolute_overall', 4498), ('support_squared_overall', 4498), ('support_ssim_overall', 4498), ('support_psnr_overall', 4498), ('conf_mat_absolute_overall', '2893,405,798,402'), ('conf_mat_squared_overall', '895,2403,240,960'), ('conf_mat_ssim_overall', '2499,799,498,702'), ('conf_mat_psnr_overall', '895,2403,240,960')])
# ========================================
# ----------------------------------------
# ----------------------------------------
# [INFO]: COMPLETED: HAM10000
# ----------------------------------------
# ----------------------------------------
# [INFO]: IR_DISTRACTION
# ----------------------------------------
# ../../ATTN_PPR_MODELS/IR_DISTRACTION/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_IR_DISTRACTION_NORMAL-{APE}
# 3it [00:03,  1.24s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.6038000000000001), ('auc_roc_score_agg_psnr', 0.6403833333333334), ('auc_roc_score_agg_squared', 0.6374222222222222), ('auc_roc_score_agg_ssim', 0.5035888888888889), ('auc_roc_score_mean_absolute', 0.6020333333333334), ('auc_roc_score_mean_psnr', 0.6408166666666667), ('auc_roc_score_mean_squared', 0.6407999999999999), ('auc_roc_score_mean_ssim', 0.5044666666666666), ('auc_roc_score_overall_absolute', 0.6020333333333334), ('auc_roc_score_overall_psnr', 0.6408166666666666), ('auc_roc_score_overall_squared', 0.6408), ('auc_roc_score_overall_ssim', 0.5044666666666667), ('eer_agg_absolute', 0.45999999999999924), ('eer_agg_psnr', 0.39095238095238094), ('eer_agg_squared', 0.39999999999949026), ('eer_agg_ssim', 0.5226666666666666), ('eer_overall_absolute', 0.45999999999989766), ('eer_overall_psnr', 0.3900000000000272), ('eer_overall_squared', 0.3900000000000272), ('eer_overall_ssim', 0.5199999999999765), ('pr_roc_score_agg_absolute', 0.5698590691016292), ('pr_roc_score_agg_psnr', 0.5933331864301538), ('pr_roc_score_agg_squared', 0.591267977854879), ('pr_roc_score_agg_ssim', 0.5199130990470602), ('pr_roc_score_mean_absolute', 0.590382728440407), ('pr_roc_score_mean_psnr', 0.6177853723500921), ('pr_roc_score_mean_squared', 0.6177853723500921), ('pr_roc_score_mean_ssim', 0.5672084377082135), ('pr_roc_score_overall_absolute', 0.5716116036010392), ('pr_roc_score_overall_psnr', 0.594077160554709), ('pr_roc_score_overall_squared', 0.594077160554709), ('pr_roc_score_overall_ssim', 0.5120165718185479), ('precision_absolute_agg', 0.636997505418558), ('precision_squared_agg', 0.6614832535885168), ('precision_ssim_agg', 0.6409774436090225), ('precision_psnr_agg', 0.6571521698640342), ('recall_absolute_agg', 0.6116666666666667), ('recall_squared_agg', 0.65), ('recall_ssim_agg', 0.5566666666666666), ('recall_psnr_agg', 0.65), ('f1-score_absolute_agg', 0.592845971708911), ('f1-score_squared_agg', 0.6436651583710407), ('f1-score_ssim_agg', 0.4787311872909699), ('f1-score_psnr_agg', 0.6459719474914585), ('support_absolute_agg', 600), ('support_squared_agg', 600), ('support_ssim_agg', 600), ('support_psnr_agg', 600), ('conf_mat_absolute_agg', '119,181,52,248'), ('conf_mat_squared_agg', '155,145,65,235'), ('conf_mat_ssim_agg', '51,249,17,283'), ('conf_mat_psnr_agg', '163,137,73,227'), ('precision_absolute_overall', 0.6348342575818341), ('precision_squared_overall', 0.6577688137865672), ('precision_ssim_overall', 0.6509705248023004), ('precision_psnr_overall', 0.6577688137865672), ('recall_absolute_overall', 0.6083333333333333), ('recall_squared_overall', 0.6516666666666666), ('recall_ssim_overall', 0.5583333333333333), ('recall_psnr_overall', 0.6516666666666666), ('f1-score_absolute_overall', 0.5880938678570072), ('f1-score_squared_overall', 0.6482655903331941), ('f1-score_ssim_overall', 0.4783036666393241), ('f1-score_psnr_overall', 0.6482655903331941), ('support_absolute_overall', 600), ('support_squared_overall', 600), ('support_ssim_overall', 600), ('support_psnr_overall', 600), ('conf_mat_absolute_overall', '116,184,51,249'), ('conf_mat_squared_overall', '166,134,75,225'), ('conf_mat_ssim_overall', '50,250,15,285'), ('conf_mat_psnr_overall', '166,134,75,225')])
# ----------------------------------------
# [INFO]: Device set to GPU
# ----------------------------------------
#   4%|▍         | 135/3200 [00:00<00:02, 1344.17it/s]
# ----------------------------------------
# [INFO]: Created Dataset
# ----------------------------------------
# 100%|██████████| 3200/3200 [00:02<00:00, 1371.31it/s]
# ----------------------------------------
# [INFO]: Created Encodings
# ----------------------------------------
# INFO: SVDD C Initialized torch.Size([1, 1536])
# INFO: SVDD Initialized
# ----------------------------------------
# [INFO]: SVDD Ready
# ----------------------------------------
# ----------------------------------------
# [INFO]: Data Loaders Ready. Starting the training
# ----------------------------------------
# ========================================
# Testing: For epochs = 1 and model: ../../ATTN_PPR_MODELS/IR_DISTRACTION/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_IR_DISTRACTION_NORMAL-{APE}/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_IR_DISTRACTION_NORMAL-{APE}.pth.tar
# 0it [00:00, ?it/s]
# Epoch [0/1] | Train Loss: 4583.051903 | Val Loss: 1050.780374 | Time: (2) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 3it [00:03,  1.25s/it]
# ...
# ========================================
# ========================================
# Testing: For epochs = 20 and model: ../../ATTN_PPR_MODELS/MV-TEC/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_MV_TEC_NORMAL-{APE}/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C3_ADAM_MSE_MV_TEC_NORMAL-{APE}.pth.tar
# Epoch [0/14] | Train Loss: 1373.949086 | Val Loss: 1380.892301 | Time: (2) s
# Epoch [1/14] | Train Loss: 1365.345790 | Val Loss: 1380.755392 | Time: (2) s
# Epoch [2/14] | Train Loss: 1357.048209 | Val Loss: 1363.417281 | Time: (2) s
# Epoch [3/14] | Train Loss: 1363.629955 | Val Loss: 1369.030993 | Time: (2) s
# Epoch [4/14] | Train Loss: 1350.611471 | Val Loss: 1359.394074 | Time: (2) s
# Epoch [5/14] | Train Loss: 1344.431438 | Val Loss: 1348.186977 | Time: (2) s
# Epoch [6/14] | Train Loss: 1345.749034 | Val Loss: 1350.452381 | Time: (2) s
# Epoch [7/14] | Train Loss: 1343.047886 | Val Loss: 1350.708131 | Time: (3) s
# Epoch [8/14] | Train Loss: 1334.629391 | Val Loss: 1341.056754 | Time: (2) s
# Epoch [9/14] | Train Loss: 1326.279851 | Val Loss: 1329.960175 | Time: (2) s
# Epoch [10/14] | Train Loss: 1324.721793 | Val Loss: 1325.594266 | Time: (2) s
# Epoch [11/14] | Train Loss: 1327.310292 | Val Loss: 1349.159825 | Time: (2) s
# Epoch [12/14] | Train Loss: 1324.724669 | Val Loss: 1330.032785 | Time: (2) s
# 0it [00:00, ?it/s]
# Epoch [13/14] | Train Loss: 1331.495215 | Val Loss: 1358.004398 | Time: (2) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 15it [00:11,  1.25it/s]
# OrderedDict([('auc_roc_score_agg_absolute', 0.5727727979900797), ('auc_roc_score_agg_psnr', 0.5754179674068829), ('auc_roc_score_agg_squared', 0.5778367484501759), ('auc_roc_score_agg_ssim', 0.5270797942419054), ('auc_roc_score_mean_absolute', 0.539604327163253), ('auc_roc_score_mean_psnr', 0.5480627749070166), ('auc_roc_score_mean_squared', 0.5480627749070166), ('auc_roc_score_mean_ssim', 0.5391321819916242), ('auc_roc_score_overall_absolute', 0.5329403594298417), ('auc_roc_score_overall_psnr', 0.5488837180800905), ('auc_roc_score_overall_squared', 0.5488845691642014), ('auc_roc_score_overall_ssim', 0.46295911732364686), ('eer_agg_absolute', 0.42470965158184637), ('eer_agg_psnr', 0.4269762495568947), ('eer_agg_squared', 0.43305409626579583), ('eer_agg_ssim', 0.47537473233404715), ('eer_overall_absolute', 0.4839400428265525), ('eer_overall_psnr', 0.48965316234334016), ('eer_overall_squared', 0.4914019236374235), ('eer_overall_ssim', 0.5604133545305136), ('pr_roc_score_agg_absolute', 0.6707796658863727), ('pr_roc_score_agg_psnr', 0.66951682215421), ('pr_roc_score_agg_squared', 0.6670034769768997), ('pr_roc_score_agg_ssim', 0.7157281891998669), ('pr_roc_score_mean_absolute', 0.7747358627149112), ('pr_roc_score_mean_psnr', 0.7795486779912627), ('pr_roc_score_mean_squared', 0.7795486779912627), ('pr_roc_score_mean_ssim', 0.775279203555293), ('pr_roc_score_overall_absolute', 0.7073674275413782), ('pr_roc_score_overall_psnr', 0.7043164168323527), ('pr_roc_score_overall_squared', 0.7043160817782477), ('pr_roc_score_overall_ssim', 0.7296822318539287), ('precision_absolute_agg', 0.6815224096279439), ('precision_squared_agg', 0.6925090073053263), ('precision_ssim_agg', 0.6308781659295155), ('precision_psnr_agg', 0.6820194632705058), ('recall_absolute_agg', 0.647536231884058), ('recall_squared_agg', 0.6991304347826087), ('recall_ssim_agg', 0.6005797101449275), ('recall_psnr_agg', 0.6428985507246376), ('f1-score_absolute_agg', 0.6603786796230734), ('f1-score_squared_agg', 0.6955681815966012), ('f1-score_ssim_agg', 0.6132343547165213), ('f1-score_psnr_agg', 0.6571173637745271), ('support_absolute_agg', 1725), ('support_squared_agg', 1725), ('support_ssim_agg', 1725), ('support_psnr_agg', 1725), ('conf_mat_absolute_agg', '882,376,232,235'), ('conf_mat_squared_agg', '1015,243,276,191'), ('conf_mat_ssim_agg', '854,404,285,182'), ('conf_mat_psnr_agg', '868,390,226,241'), ('precision_absolute_overall', 0.6497875851684547), ('precision_squared_overall', 0.6764444178868965), ('precision_ssim_overall', 0.731916547220895), ('precision_psnr_overall', 0.6764444178868965), ('recall_absolute_overall', 0.6759420289855073), ('recall_squared_overall', 0.4765217391304348), ('recall_ssim_overall', 0.7379710144927536), ('recall_psnr_overall', 0.4765217391304348), ('f1-score_absolute_overall', 0.6599382883967295), ('f1-score_squared_overall', 0.48892857329807066), ('f1-score_ssim_overall', 0.6444243422354081), ('f1-score_psnr_overall', 0.48892857329807066), ('support_absolute_overall', 1725), ('support_squared_overall', 1725), ('support_ssim_overall', 1725), ('support_psnr_overall', 1725), ('conf_mat_absolute_overall', '1037,221,338,129'), ('conf_mat_squared_overall', '462,796,107,360'), ('conf_mat_ssim_overall', '1248,10,442,25'), ('conf_mat_psnr_overall', '462,796,107,360')])
# ========================================
# ----------------------------------------
# ----------------------------------------
# [INFO]: COMPLETED: MV_TEC
# ----------------------------------------
# ----------------------------------------
# [INFO]: SUBWAY_ENTRANCE
# ----------------------------------------
# ../../ATTN_PPR_MODELS/SUBWAY_ENTRANCE/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C1_ADAM_MSE_SUBWAY_ENTRANCE_NORMAL-{APE}
# 0it [00:00, ?it/s]
# Subway Entrance: Last few frames dropped
# 24344
# 21344
# 21344
# 1it [01:57, 117.40s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.7368177847600954), ('auc_roc_score_agg_psnr', 0.7431726994333694), ('auc_roc_score_agg_squared', 0.7487706674018029), ('auc_roc_score_agg_ssim', 0.7295580381163685), ('auc_roc_score_mean_absolute', 0.7368177847600954), ('auc_roc_score_mean_psnr', 0.7431726994333694), ('auc_roc_score_mean_squared', 0.7487706674018029), ('auc_roc_score_mean_ssim', 0.7295580381163685), ('auc_roc_score_overall_absolute', 0.7368177847600954), ('auc_roc_score_overall_psnr', 0.7431726994333694), ('auc_roc_score_overall_squared', 0.7487706674018029), ('auc_roc_score_overall_ssim', 0.7295580381163685), ('eer_agg_absolute', 0.33001212961358517), ('eer_agg_psnr', 0.31689462531304163), ('eer_agg_squared', 0.31414948950106014), ('eer_agg_ssim', 0.3551724137927437), ('eer_overall_absolute', 0.33001212961358517), ('eer_overall_psnr', 0.31689462531304163), ('eer_overall_squared', 0.31414948950106014), ('eer_overall_ssim', 0.3551724137927437), ('pr_roc_score_agg_absolute', 0.9905807446770315), ('pr_roc_score_agg_psnr', 0.9910003793970332), ('pr_roc_score_agg_squared', 0.9912464846457455), ('pr_roc_score_agg_ssim', 0.989570212036442), ('pr_roc_score_mean_absolute', 0.9905807446770315), ('pr_roc_score_mean_psnr', 0.9910003793970332), ('pr_roc_score_mean_squared', 0.9912464846457455), ('pr_roc_score_mean_ssim', 0.989570212036442), ('pr_roc_score_overall_absolute', 0.9905807446770315), ('pr_roc_score_overall_psnr', 0.9910003793970332), ('pr_roc_score_overall_squared', 0.9912464846457455), ('pr_roc_score_overall_ssim', 0.989570212036442), ('precision_absolute_agg', 0.9660529411210185), ('precision_squared_agg', 0.9653329277380278), ('precision_ssim_agg', 0.9584784636360497), ('precision_psnr_agg', 0.9651654690351171), ('recall_absolute_agg', 0.5576274362818591), ('recall_squared_agg', 0.6446308095952024), ('recall_ssim_agg', 0.8069246626686657), ('recall_psnr_agg', 0.6356821589205398), ('f1-score_absolute_agg', 0.6907806458839445), ('f1-score_squared_agg', 0.7599359398433537), ('f1-score_ssim_agg', 0.8706513542404825), ('f1-score_psnr_agg', 0.7531950353722702), ('support_absolute_agg', 21344), ('support_squared_agg', 21344), ('support_ssim_agg', 21344), ('support_psnr_agg', 21344), ('conf_mat_absolute_agg', '484,96,9346,11418'), ('conf_mat_squared_agg', '455,125,7460,13304'), ('conf_mat_ssim_agg', '292,288,3833,16931'), ('conf_mat_psnr_agg', '455,125,7651,13113'), ('precision_absolute_overall', 0.9660529411210185), ('precision_squared_overall', 0.9653329277380278), ('precision_ssim_overall', 0.9584784636360497), ('precision_psnr_overall', 0.9651654690351171), ('recall_absolute_overall', 0.5576274362818591), ('recall_squared_overall', 0.6446308095952024), ('recall_ssim_overall', 0.8069246626686657), ('recall_psnr_overall', 0.6356821589205398), ('f1-score_absolute_overall', 0.6907806458839445), ('f1-score_squared_overall', 0.7599359398433537), ('f1-score_ssim_overall', 0.8706513542404825), ('f1-score_psnr_overall', 0.7531950353722702), ('support_absolute_overall', 21344), ('support_squared_overall', 21344), ('support_ssim_overall', 21344), ('support_psnr_overall', 21344), ('conf_mat_absolute_overall', '484,96,9346,11418'), ('conf_mat_squared_overall', '455,125,7460,13304'), ('conf_mat_ssim_overall', '292,288,3833,16931'), ('conf_mat_psnr_overall', '455,125,7651,13113')])
# ----------------------------------------
# [INFO]: Device set to GPU
# ----------------------------------------
#   2%|▏         | 127/7509 [00:00<00:05, 1262.02it/s]
# ----------------------------------------
# [INFO]: Created Dataset
# ----------------------------------------
# 100%|██████████| 7509/7509 [00:05<00:00, 1411.37it/s]
# ----------------------------------------
# [INFO]: Created Encodings
# ----------------------------------------
# INFO: SVDD C Initialized torch.Size([1, 1536])
# INFO: SVDD Initialized
# ----------------------------------------
# [INFO]: SVDD Ready
# ----------------------------------------
# ----------------------------------------
# [INFO]: Data Loaders Ready. Starting the training
# ----------------------------------------
# ========================================
# Testing: For epochs = 1 and model: ../../ATTN_PPR_MODELS/SUBWAY_ENTRANCE/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C1_ADAM_MSE_SUBWAY_ENTRANCE_NORMAL-{APE}/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C1_ADAM_MSE_SUBWAY_ENTRANCE_NORMAL-{APE}.pth.tar
# 0it [00:00, ?it/s]
# Epoch [0/1] | Train Loss: 1878.958610 | Val Loss: 1534.639957 | Time: (3) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 1it [02:01, 121.06s/it]
# OrderedDict([('auc_roc_score_agg_absolute', 0.6251563548316383), ('auc_roc_score_agg_psnr', 0.5707214160450116), ('auc_roc_score_agg_squared', 0.5734439248301105), ('auc_roc_score_agg_ssim', 0.7358092006058231), ('auc_roc_score_mean_absolute', 0.6251563548316383), ('auc_roc_score_mean_psnr', 0.5707214160450116), ('auc_roc_score_mean_squared', 0.5734439248301105), ('auc_roc_score_mean_ssim', 0.7358092006058231), ('auc_roc_score_overall_absolute', 0.6251563548316383), ('auc_roc_score_overall_psnr', 0.5707214160450116), ('auc_roc_score_overall_squared', 0.5734439248301105), ('auc_roc_score_overall_ssim', 0.7358092006058231), ('eer_agg_absolute', 0.4068256967406497), ('eer_agg_psnr', 0.4362068965515458), ('eer_agg_squared', 0.4344827586211752), ('eer_agg_ssim', 0.32756538397459134), ('eer_overall_absolute', 0.4068256967406497), ('eer_overall_psnr', 0.4362068965515458), ('eer_overall_squared', 0.4344827586211752), ('eer_overall_ssim', 0.32756538397459134), ('pr_roc_score_agg_absolute', 0.978944117527496), ('pr_roc_score_agg_psnr', 0.9752813277289714), ('pr_roc_score_agg_squared', 0.9754556000103654), ('pr_roc_score_agg_ssim', 0.990600818020581), ('pr_roc_score_mean_absolute', 0.978944117527496), ('pr_roc_score_mean_psnr', 0.9752813277289714), ('pr_roc_score_mean_squared', 0.9754556000103654), ('pr_roc_score_mean_ssim', 0.990600818020581), ('pr_roc_score_overall_absolute', 0.978944117527496), ('pr_roc_score_overall_psnr', 0.9752813277289714), ('pr_roc_score_overall_squared', 0.9754556000103654), ('pr_roc_score_overall_ssim', 0.990600818020581), ('precision_absolute_agg', 0.9587510569572625), ('precision_squared_agg', 0.9537178680262046), ('precision_ssim_agg', 0.9699200364954573), ('precision_psnr_agg', 0.9536241945177063), ('recall_absolute_agg', 0.5200993253373314), ('recall_squared_agg', 0.7360382308845578), ('recall_ssim_agg', 0.44598013493253374), ('recall_psnr_agg', 0.7370689655172413), ('f1-score_absolute_agg', 0.6597368752638179), ('f1-score_squared_agg', 0.8251012363039446), ('f1-score_ssim_agg', 0.5888065768962631), ('f1-score_psnr_agg', 0.8257845208696533), ('support_absolute_agg', 21344), ('support_squared_agg', 21344), ('support_ssim_agg', 21344), ('support_psnr_agg', 21344), ('conf_mat_absolute_agg', '411,169,10074,10690'), ('conf_mat_squared_agg', '250,330,5304,15460'), ('conf_mat_ssim_agg', '542,38,11787,8977'), ('conf_mat_psnr_agg', '248,332,5280,15484'), ('precision_absolute_overall', 0.9587510569572625), ('precision_squared_overall', 0.9537178680262046), ('precision_ssim_overall', 0.9699200364954573), ('precision_psnr_overall', 0.9536241945177063), ('recall_absolute_overall', 0.5200993253373314), ('recall_squared_overall', 0.7360382308845578), ('recall_ssim_overall', 0.44598013493253374), ('recall_psnr_overall', 0.7370689655172413), ('f1-score_absolute_overall', 0.6597368752638179), ('f1-score_squared_overall', 0.8251012363039446), ('f1-score_ssim_overall', 0.5888065768962631), ('f1-score_psnr_overall', 0.8257845208696533), ('support_absolute_overall', 21344), ('support_squared_overall', 21344), ('support_ssim_overall', 21344), ('support_psnr_overall', 21344), ('conf_mat_absolute_overall', '411,169,10074,10690'), ('conf_mat_squared_overall', '250,330,5304,15460'), ('conf_mat_ssim_overall', '542,38,11787,8977'), ('conf_mat_psnr_overall', '248,332,5280,15484')])
# ========================================
# ========================================
# Testing: For epochs = 2 and model: ../../ATTN_PPR_MODELS/SUBWAY_ENTRANCE/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C1_ADAM_MSE_SUBWAY_ENTRANCE_NORMAL-{APE}/C2D_AE_128_3X3-_SOFTMAX_ATTENTION_P64_C1_ADAM_MSE_SUBWAY_ENTRANCE_NORMAL-{APE}.pth.tar
# 0it [00:00, ?it/s]
# Epoch [0/1] | Train Loss: 655.636073 | Val Loss: 653.562135 | Time: (3) s
# ----------------------------------------
# [INFO]: Training Completed. Testing the model now...
# ----------------------------------------
# 0it [01:19, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-7703538add3c> in <module>
#      26                     lr = lr,
#      27                     testOriginal = True,
# ---> 28                     returnResults = True,
#      29                 )
#      30                 SVDD_RESULTS[DATASET][MODEL_NAME] = svdd_ft.results
#
# ~/Documents/PROJECTS/THESIS_WORK/VideoAnomalyDetection/AutoEncoders/SVDD_fine_tuning.py in __init__(self, model, model_path, dataset_type, lr, batch_size, epochs, dataset_kwargs, tester_kwargs, testOriginal, returnResults, useGPU)
#     116                             **tester_kwargs
#     117                     )
# --> 118             results = self.tester.test(return_results = self.returnResults)
#     119             if self.returnResults: self.results[e] = results
#     120             print("="*40)
#
# ~/Documents/PROJECTS/THESIS_WORK/VideoAnomalyDetection/AutoEncoders/test_autoencoder.py in test(self, return_results)
#     456
#     457                 # process reconstructions, encodings and reference inputs-labels
# --> 458                 test_inputs, test_labels, reconstructions, encodings = self.predict_process(frame_idx, test_inputs, test_labels, n_frames)
#     459
#     460                 if len(test_inputs)!=len(reconstructions):
#
# ~/Documents/PROJECTS/THESIS_WORK/VideoAnomalyDetection/AutoEncoders/test_autoencoder.py in predict_process(self, frame_idx, test_inputs, test_labels, n_frames)
#     329         # use only 3 channels - for PatchWise models
#     330         test_inputs = to_cpu(test_inputs[:, :3, :, :])
# --> 331         reconstructions = to_cpu(reconstructions[:, :3, :, :])
#     332
#     333         # return everything new or that is changed
#
# ~/Documents/PROJECTS/THESIS_WORK/VideoAnomalyDetection/general/utils.py in to_cpu(x)
#     117
#     118 def to_cpu(x):
# --> 119     return x.detach().cpu()
#     120
#     121 def tensor_to_numpy(x):
#
# KeyboardInterrupt:

# %%
print("DONE")

# %% [markdown]
# ---------------------------------------------------------------------

# %% [markdown]
# # SVDD models Baseline graph

# %%
svdd_results = OrderedDict()

for key in [1e-7, 5e-7, 1e-6, 5e-6, 1e-5, 5e-5, 1e-4]:
    try:
        svdd_results[("%s"%(key))] = load_pickle(join_paths([SAVE_PATH, "Baseline_SVDD/SVDD_results_LR_%s.pkl"%(key)]))
    except:
        if key == 1e-4:
            svdd_results[("%s"%(key))] = load_pickle(join_paths([SAVE_PATH, "Baseline_SVDD/SVDD_results_LR_1e-04.pkl"]))

# %%
svdd_auc_roc = dict()
svdd_f1_score = dict()
for lr in svdd_results.keys():
    svdd_auc_roc[lr] = dict()
    svdd_f1_score[lr] = dict()
    for dataset in svdd_results[lr].keys():
        svdd_auc_roc[lr][dataset] = dict()
        svdd_f1_score[lr][dataset] = dict()
        for model in svdd_results[lr][dataset].keys():
            for epoch in svdd_results[lr][dataset][model].keys():
                svdd_auc_roc[lr][dataset][epoch] = svdd_results[lr][dataset][model][epoch]["squared"]["auc_roc_score"]["agg"]
                svdd_f1_score[lr][dataset][epoch] = svdd_results[lr][dataset][model][epoch]["squared"]["best"]["agg"]["classification_report"]["weighted avg"]["f1-score"]

# %%
for dataset in svdd_auc_roc["1e-05"].keys():
    for lr in svdd_auc_roc.keys():
        plt.plot(list(svdd_auc_roc[lr][dataset].keys()), list(svdd_auc_roc[lr][dataset].values()), linestyle='--', marker='^', label = "LR = %s"%(lr))
    plt.plot([0], [svdd_auc_roc[lr][dataset][0]], "o", color='black')
    plt.legend()
    plt.xlabel("Number of Epochs - Fine Tuning")
    plt.ylabel("Anomaly Detection AUC-ROC")
    plt.title("%s AUC-ROC"%(dataset))
    plt.legend()
    plt.savefig("../../ATTN_PPR_RESULTS/Baseline_SVDD/SVDD_EpochsVsAUC_ROC/%s_auc_roc2.png"%(dataset))
    plt.clf()
    plt.close()

# %%
for dataset in svdd_f1_score["1e-05"].keys():
    for lr in svdd_f1_score.keys():
        plt.plot(list(svdd_f1_score[lr][dataset].keys()), list(svdd_f1_score[lr][dataset].values()), linestyle='--', marker='^', label = "LR = %s"%(lr))
    plt.plot([0], [svdd_f1_score[lr][dataset][0]], "o", color='black')
    plt.legend()
    plt.xlabel("Number of Epochs - Fine Tuning")
    plt.ylabel("Anomaly Detection F1-Score")
    plt.title("%s AUC-ROC"%(dataset))
    plt.legend()
    plt.savefig("../../ATTN_PPR_RESULTS/Baseline_SVDD/SVDD_EpochsVsF1_Score/%s_f1_score2.png"%(dataset))
    plt.clf()
    plt.close()

# %% [markdown]
# # Joint plot

# %%
# %matplotlib inline

# %%
for svdd_type, svdd_type_label in zip([svdd_auc_roc, svdd_f1_score], ["AUC ROC", "F1-Score"]):
    try:
        plt.clf()
        plt.clear()
    except:
        pass

    fig, ax = plt.subplots(3, 3, figsize=(10,15))
    plt.subplots_adjust(bottom=0.08,wspace=0.3, hspace=0.3)
    IAD_DATASETS = ["IR_DISTRACTION"]
    count = 0

    line_labels = dict([(x, "LR = %s"%("1e-04" if x == "0.0001" else x)) for x in list(svdd_type.keys())])

    for idx, dataset in enumerate(svdd_type["1e-05"].keys()):
        if dataset in IAD_DATASETS: continue
        for lr in svdd_type.keys():
            ax[count//3][count%3].plot(list(svdd_type[lr][dataset].keys()), list(svdd_type[lr][dataset].values()), linestyle='-', marker='.', label = line_labels[lr])
        ax[count//3][count%3].plot([0], [svdd_type[lr][dataset][0]], "o", color='black')
        ax[count//3][count%3].set_title(dataset)
        ax[count//3][count%3].set_xticks(ticks = list(svdd_type["1e-07"]["AVENUE"].keys()))
        ax[count//3][count%3].set(xlabel='Number of Epochs', ylabel=svdd_type_label)
        count += 1
    ax[-1, -1].axis('off')
    # for axi in ax.flat: axi.label_outer()
    # plt.supxlabel("Number of Epochs - Fine Tuning")
    plt.ylabel("Anomaly Detection %s"%svdd_type_label)
    plt.suptitle("%s after SVDD Fine Tuning"%svdd_type_label, x = 0.5, y = 0.92, fontsize=14)

    # lines_labels = [ax.get_legend_handles_labels() for ax in fig.axes]
    # print(zip(*lines_labels))
    # lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
    # fig.legend(lines, labels, loc = "lower right")

    fig.legend(labels=list(line_labels.values()),   # The labels for each line
               loc="lower right",   # Position of legend
               borderaxespad=0.1,    # Small spacing around legend box
               title="Learning Rates",  # Title for the legend
               ncol=7
               )

    plt.savefig("../../ATTN_PPR_RESULTS/Baseline_SVDD/SVDD_EpochsVs%s/SVDD_EpochsVs%s_VAD.png"%(svdd_type_label.replace(" ", "_").replace("-", "_"), svdd_type_label.replace(" ", "_").replace("-", "_")))

# %%
svdd_auc_best = dict()

for dataset in svdd_auc_roc["1e-05"].keys():
    best_per_lr = list()
    for lr in svdd_auc_roc.keys():
        ep = np.array(list(svdd_auc_roc[lr][dataset].items()))
        best_per_lr.append([lr] + ep[np.argmax(ep[:,1])].tolist())
    best_per_lr = np.array(best_per_lr)
    svdd_auc_best[dataset] = best_per_lr[np.argmax(best_per_lr[:,2])]

# %%
dump_pickle(svdd_auc_best, "../ATTN_PPR_RESULTS/SVDD_best_AUC_ROC_Baseline.pkl")
# Out:
# True

# %%
svdd_auc_best = load_pickle("../ATTN_PPR_RESULTS/Baseline_SVDD/SVDD_best_AUC_ROC_Baseline.pkl")

# %%
model = C2D_AE_128_3x3()
for dataset, params in svdd_auc_best.items():
    lr, e, auc = params
    e = int(e[:1])
    svdd_r = get_results_att_ppr(model, dataset, svdd_results[lr][dataset]['C2D_AE_128_3x3-'][e], "absolute", "agg")
    items = list()
    for idx,(k,v) in enumerate(svdd_r.items()):
        if idx == 0: continue
        if idx == 1:
            v = replace_model_name(v) + " + SVDD"
            items.append(str(v))
        else:
            items.append(str(float(v) * 100)[:5])
    print(dataset)
    print("& " + " & ".join(items) + "\\\\")
    print()
# Out:
# AVENUE
# & Baseline CAE + SVDD & 71.36 & 33.7 & 61.73 & 67.24 & 67.25 & 67.24\\
#
# HAM10000
# & Baseline CAE + SVDD & 68.49 & 35.51 & 61.86 & 72.16 & 70.67 & 71.3\\
#
# IR_DISTRACTION
# & Baseline CAE + SVDD & 85.42 & 23.73 & 85.08 & 78.47 & 77.83 & 77.71\\
#
# MV_TEC
# & Baseline CAE + SVDD & 66.36 & 38.33 & 62.96 & 70.25 & 67.58 & 68.62\\
#
# SUBWAY_ENTRANCE
# & Baseline CAE + SVDD & 79.67 & 29.63 & 99.3 & 96.72 & 61.36 & 73.59\\
#
# SUBWAY_EXIT
# & Baseline CAE + SVDD & 97.53 & 10.73 & 100.0 & 99.92 & 89.28 & 94.26\\
#
# UCSD1
# & Baseline CAE + SVDD & 70.05 & 35.25 & 63.87 & 67.91 & 68.14 & 67.83\\
#
# UCSD2
# & Baseline CAE + SVDD & 92.7 & 14.14 & 67.02 & 89.72 & 81.84 & 83.66\\
